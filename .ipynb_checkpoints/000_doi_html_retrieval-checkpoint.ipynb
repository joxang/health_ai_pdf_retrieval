# %%
import urllib
import pandas as pd
import time
from tqdm.notebook import tqdm
import re
import wget
import random

# %%
from lxml import html
from random import randint
from random import sample
from time import sleep
import requests
import urllib.request
from urllib.request import urlopen

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions() 
options.add_experimental_option("excludeSwitches", ["enable-logging"])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # extract doi list

# %%
#all_abstracts = pd.read_csv('data/included_abstracts.csv', index_col = 0)
#len(all_abstracts)

# %%
#all_abstracts['article_date'] = pd.to_datetime(all_abstracts['article_date'])
#decade_df = all_abstracts[(all_abstracts['article_date'] > '2012-01-01') & (all_abstracts['article_date'] <'2022-01-01')]
#len(decade_df)

# %%
#decade_df.sort_values(by='article_date',  ascending=False, inplace=True)
#decade_df.head(50)

# %%
retrieval_1 = pd.read_csv('output/failed_link_retrieval.csv', index_col = 0)
#retrieval_2 = pd.read_csv('output/no_links_for_open_access.csv', index_col = 0)

# %%
#extra_df = pd.concat([retrieval_1, retrieval_2]).reset_index(drop=True)

# %%
#scrape_df = extra_df[['pmid', 'doi']].copy()
scrape_df = retrieval_1[['pmid', 'doi']].copy()

# %%
doi_df = scrape_df[~scrape_df['doi'].isnull()]
doi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3437 entries, 3 to 28677
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pmid    3437 non-null   int64
#  1   doi     3437 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 80.6+ KB

# %%
id_dict = dict(zip(doi_df['pmid'], doi_df['doi']))
pmid_list = doi_df['pmid'].tolist()
doi_list = doi_df['doi'].tolist()

# %% [markdown]
# # create urls for dois

# %%
url_list = []

for doi in doi_list:
    link = "https://doi.org/{}".format(doi)
    url_list.append(link)

len(url_list)
# Out:
# 3437

# %%
#for manual download!
#url_df = pd.DataFrame(url_list, columns=['url'])
#url_df.to_csv('output/manual_url_1.csv')

# %% [markdown]
# # get re-direct urls into new list

# %%
scrape_list = []

for url in tqdm(url_list):
    
    driver = webdriver.Chrome(options=options)
    
    try:
        driver.get(url)
        link = driver.current_url
        driver.quit()
        
        print(link)
        scrape_list.append(link)
        
    except Exception:
        scrape_list.append("error")
        print("error")
        pass
    
len(scrape_list)
# Out:
#   0%|          | 0/3437 [00:00<?, ?it/s]
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12264
# https://iopscience.iop.org/article/10.1088/1361-6560/ac4316
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/trc2.12229
# https://journals.sagepub.com/doi/10.1177/03009858211067478
# https://onlinelibrary.wiley.com/doi/10.1002/emp2.12595
# https://ieeexplore.ieee.org/document/9663415
# https://onlinelibrary.wiley.com/doi/10.1111/ejn.15537
# https://onlinelibrary.wiley.com/doi/10.1002/cnm.3559
# https://www.sciendo.com/article/10.2478/joeb-2021-0018
# https://www.frontiersin.org/articles/10.3389/fmed.2021.793230/full
# http://www.aimspress.com/article/doi/10.3934/mbe.2022093
# https://onlinelibrary.wiley.com/doi/10.1002/clc.23762
# https://onlinelibrary.wiley.com/doi/10.1111/cns.13773
# https://www.science.org/doi/10.1126/sciadv.abh2724
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13506
# https://www.science.org/doi/10.1126/sciadv.abl4146
# https://journals.lww.com/jcnjournal/Abstract/9000/The_Utility_of_Nursing_Notes_Among_Medicare.99142.aspx
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-13-1-426&id=466261
# https://onlinelibrary.wiley.com/doi/10.1111/jocn.16182
# http://www.aimspress.com/article/doi/10.3934/mbe.2022090
# https://onlinelibrary.wiley.com/doi/10.1002/path.5858
# https://www.hindawi.com/journals/jhe/2021/1302989/
# https://peerj.com/articles/12572/
# https://www.spiedigitallibrary.org/journals/journal-of-medical-imaging/volume-8/issue-06/067501/Deep-learning-segmentation-of-glomeruli-on-kidney-donor-frozen-sections/10.1117/1.JMI.8.6.067501.full?SSO=1
# https://journals.lww.com/apjoo/Abstract/9000/Validation_of_Soft_Labels_in_Developing_Deep.99655.aspx
# https://link.springer.com/article/10.1007/s11548-021-02539-2
# http://ies.ijo.cn/gjyken/ch/reader/view_abstract.aspx?file_no=20211213&flag=1
# https://www.hindawi.com/journals/jhe/2021/4272411/
# http://ies.ijo.cn/gjyken/ch/reader/view_abstract.aspx?file_no=20211220&flag=1
# https://onlinelibrary.wiley.com/doi/10.1002/jmri.27978
# https://journals.lww.com/jaaos/Fulltext/2022/02010/Supervised_Machine_Learning_for_Predicting_Length.6.aspx
# https://www.sciencedirect.com/science/article/pii/S1051044321015839?via%3Dihub
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25748
# https://peerj.com/articles/cs-751/
# http://www.aimspress.com/article/doi/10.3934/mbe.2022081
# http://www.aimspress.com/article/doi/10.3934/mbe.2022080
# https://journals.sagepub.com/doi/10.1177/0272989X211064604
# https://onlinelibrary.wiley.com/doi/10.1111/acps.13388
# https://onlinelibrary.wiley.com/doi/10.1111/cas.15217
# https://onlinelibrary.wiley.com/doi/10.1002/acr.24834
# https://journals.sagepub.com/doi/10.1177/21514593211062277
# https://www.liebertpub.com/doi/10.1089/heq.2021.0079
# https://peerj.com/articles/cs-806/
# https://www.tandfonline.com/doi/full/10.1080/17538157.2021.2007930
# https://www.tandfonline.com/doi/full/10.1080/10543406.2021.2009500
# https://academic.oup.com/mr/advance-article-abstract/doi/10.1093/mr/roab124/6458437?redirectedFrom=fulltext
# https://onlinelibrary.wiley.com/doi/10.1111/1753-0407.13241
# https://ascpt.onlinelibrary.wiley.com/doi/10.1002/psp4.12740
# https://ieeexplore.ieee.org/document/9622235
# https://academic.oup.com/braincomms/article/4/2/fcab284/6456301
# https://journals.sagepub.com/doi/10.1177/1759720X211059614
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15361
# https://medinform.jmir.org/2021/12/e25022
# https://www.mdpi.com/1424-8220/21/24/8174
# https://www.researchprotocols.org/2021/12/e29563
# https://www.mdpi.com/2227-9032/9/12/1695
# https://www.hindawi.com/journals/jhe/2021/1336762/
# https://www.mdpi.com/2072-6694/13/23/6138
# https://www.mdpi.com/1424-8220/21/23/8157
# https://www.hindawi.com/journals/dm/2021/8668978/
# https://www.mdpi.com/2227-9032/9/12/1687
# https://www.mdpi.com/1424-8220/21/23/8142
# https://www.mdpi.com/2079-6374/11/12/499
# https://www.mdpi.com/1424-8220/21/23/8131
# https://onlinelibrary.wiley.com/doi/10.1002/path.5828
# https://www.mdpi.com/2072-6694/13/23/6113
# https://medinform.jmir.org/2022/3/e32949
# https://www.mdpi.com/1660-4601/18/23/12807
# https://www.mdpi.com/1660-4601/18/23/12806
# https://www.mdpi.com/1424-8220/21/23/8118
# https://www.sciencedirect.com/science/article/pii/S1877050921021220?via%3Dihub
# https://www.tandfonline.com/doi/full/10.1080/00325481.2021.2003150
# https://www.mdpi.com/1424-8220/21/23/8091
# https://www.mdpi.com/2075-4418/11/12/2264
# https://www.mdpi.com/2075-4426/11/12/1288
# https://www.mdpi.com/1660-4601/18/23/12772
# https://www.mdpi.com/2075-4418/11/12/2267
# http://www.aimspress.com/article/doi/10.3934/mbe.2022060
# https://www.mdpi.com/1424-8220/21/23/8095
# https://www.mdpi.com/1424-8220/21/23/8099
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4465
# https://formative.jmir.org/2021/12/e23440
# https://medinform.jmir.org/2021/12/e22798
# https://www.mdpi.com/2077-0383/10/23/5688
# https://www.mdpi.com/2075-4418/11/12/2257
# https://www.mdpi.com/2306-7381/8/12/301
# https://mhealth.jmir.org/2021/12/e27024
# https://www.mdpi.com/2073-4425/12/12/1946
# https://www.researchprotocols.org/2021/12/e30304
# https://www.mdpi.com/1424-8220/21/23/8025
# https://www.mdpi.com/2072-6694/13/23/6054
# https://www.mdpi.com/2304-6767/9/12/141
# https://www.mdpi.com/2072-6694/13/23/6065
# https://onlinelibrary.wiley.com/doi/10.1111/aos.15071
# https://www.mdpi.com/2313-433X/7/12/258
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15362
# https://aacrjournals.org/cancerres/article/82/2/334/675486/Prostate-Cancer-Risk-Stratification-via
# https://pubs.rsna.org/doi/10.1148/ryai.210026
# https://www.mdpi.com/2075-4426/11/12/1268
# https://www.mdpi.com/2072-6694/13/23/6048
# https://www.mdpi.com/2075-4426/11/12/1271
# https://validate.perfdrive.com/?ssa=fb28bf3a-b4ad-45b8-aa14-2de66f6f1f27&ssb=46128236063&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac387f&ssi=6a2e8f33-8427-4220-a847-952d0eee6721&ssk=support@shieldsquare.com&ssm=68583038005381642104901317532902&ssn=3af34020a64de85bac4fdfb59f9c997015fcc3bbcb9e-73dd-4ca5-ae3afc&sso=82bf8d73-5acc016d0a65779b14df966a050f667cc53a4ddea806c260&ssp=12007327841654696443165469053897514&ssq=34183342381288738072023812702484268286203&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://journals.sagepub.com/doi/10.1177/0271678X211063802
# https://www.dovepress.com/supervised-learning-based-systemic-inflammatory-markers-enable-accurat-peer-reviewed-fulltext-article-CMAR
# https://www.mdpi.com/2075-4418/11/12/2242
# https://www.tandfonline.com/doi/full/10.1080/14767058.2021.2005573
# https://www.mdpi.com/1424-8220/21/23/8007
# http://www.aimspress.com/article/doi/10.3934/mbe.2022055
# https://onlinelibrary.wiley.com/doi/10.1002/acr2.11352
# https://onlinelibrary.wiley.com/doi/10.1111/jch.14397
# https://www.mdpi.com/1660-4601/18/23/12652
# https://www.mdpi.com/1424-8220/21/23/7996
# https://www.mdpi.com/1660-4601/18/23/12649
# https://www.mdpi.com/1424-8220/21/23/7975
# https://www.mdpi.com/1660-4601/18/23/12586
# https://journals.sagepub.com/doi/10.1177/20552076211060659
# https://www.mdpi.com/2218-273X/11/12/1786
# http://aboonline.org.br/previous-numbers
# https://www.mdpi.com/2072-6694/13/23/6002
# https://journals.sagepub.com/doi/10.1177/17562848211054710
# https://www.mdpi.com/2072-6694/13/23/6013
# https://www.jphres.org/index.php/jphres/article/view/2601
# https://www.mdpi.com/2073-4409/10/12/3353
# https://www.mdpi.com/2072-666X/12/12/1473
# https://onlinelibrary.wiley.com/doi/10.1111/ocr.12542
# https://www.mdpi.com/1424-8220/21/23/7972
# https://www.mdpi.com/2306-5354/8/12/193
# https://www.sciencedirect.com/science/article/abs/pii/S1064748121005509?via%3Dihub
# https://www.mdpi.com/1424-8220/21/23/7942
# https://www.mdpi.com/1424-8220/21/23/7943
# https://onlinelibrary.wiley.com/doi/10.1111/all.15192
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4460
# https://www.mdpi.com/1660-4601/18/23/12499
# https://www.mdpi.com/2075-1729/11/12/1305
# https://www.mdpi.com/1424-8220/21/23/7916
# https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/htl2.12018
# https://www.jmir.org/2021/11/e32900
# https://www.mdpi.com/2227-9059/9/12/1771
# https://www.nature.com/articles/s41588-021-00962-4
# https://www.mdpi.com/1424-8220/21/23/7877
# https://www.mdpi.com/1424-8220/21/23/7864
# https://www.mdpi.com/2073-4409/10/12/3318
# https://www.mdpi.com/2075-4418/11/12/2208
# https://www.mdpi.com/2075-4418/11/12/2209
# https://www.mdpi.com/2075-4418/11/12/2212
# https://www.mdpi.com/1424-8220/21/23/7851
# https://medinform.jmir.org/2021/11/e26456
# https://www.mdpi.com/2075-4418/11/12/2200
# https://www.mdpi.com/2075-4418/11/12/2197
# https://www.mdpi.com/2227-9032/9/12/1632
# https://onlinelibrary.wiley.com/doi/10.1002/lary.29960
# https://www.mdpi.com/2072-6694/13/23/5916
# https://www.mdpi.com/2076-3425/11/12/1555
# https://www.mdpi.com/1424-8220/21/23/7815
# https://www.mdpi.com/2075-4426/11/12/1248
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7790&id=465393
# https://pubs.rsna.org/doi/10.1148/ryai.210085
# https://journals.sagepub.com/doi/10.1177/17562864211060029
# https://journals.sagepub.com/doi/10.1177/23259671211046916
# https://www.mdpi.com/2075-4418/11/12/2184
# https://www.mdpi.com/1660-4601/18/23/12355
# https://onlinelibrary.wiley.com/doi/10.1002/path.5819
# https://onlinelibrary.wiley.com/doi/10.1111/iwj.13723
# https://www.nature.com/articles/s41374-021-00689-0
# https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.14246
# https://journals.sagepub.com/doi/10.1177/23259671211053326
# https://onlinelibrary.wiley.com/doi/10.1002/art.41899
# https://www.mdpi.com/2077-0383/10/23/5470
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13724
# https://onlinelibrary.wiley.com/doi/10.1111/add.15730
# https://www.mdpi.com/1424-8220/21/23/7782
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15327
# https://www.mdpi.com/2077-0383/10/23/5481
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4441
# https://www.tandfonline.com/doi/full/10.1080/20018525.2021.2004664
# https://www.mdpi.com/1424-8220/21/23/7784
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7765&id=465384
# https://onlinelibrary.wiley.com/doi/10.1111/apm.13190
# https://onlinelibrary.wiley.com/doi/10.1002/jcla.24122
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13470
# https://www.mdpi.com/2077-0383/10/22/5450
# https://www.mdpi.com/2075-1729/11/11/1281
# https://onlinelibrary.wiley.com/doi/10.1002/aur.2636
# https://www.nature.com/articles/s41598-021-01913-z
# https://www.mdpi.com/1424-8220/21/22/7751
# https://onlinelibrary.wiley.com/doi/10.1111/epi.17127
# https://www.mdpi.com/2075-4418/11/11/2150
# https://www.mdpi.com/1660-4601/18/22/12191
# https://www.mdpi.com/2227-9032/9/11/1596
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7732&id=465007
# https://link.springer.com/article/10.1007/s00401-021-02386-0
# https://onlinelibrary.wiley.com/doi/10.1002/cpe.6725
# https://www.mdpi.com/1424-8220/21/22/7709
# https://www.mdpi.com/2075-4418/11/11/2147
# https://www.jmir.org/2021/11/e29554
# https://www.science.org/doi/10.1126/sciadv.abj0852
# https://www.mdpi.com/1424-8220/21/22/7710
# https://www.mdpi.com/2077-0383/10/22/5400
# https://peerj.com/articles/cs-764/
# https://mhealth.jmir.org/2021/11/e27674
# https://www.mdpi.com/2077-0383/10/22/5399
# https://medinform.jmir.org/2021/11/e30079
# https://www.mdpi.com/1660-4601/18/22/12175
# https://onlinelibrary.wiley.com/doi/10.1111/cns.13758
# https://www.mdpi.com/2072-6694/13/22/5787
# https://www.mdpi.com/2227-9032/9/11/1579
# https://onlinelibrary.wiley.com/doi/10.1111/jocs.16076
# https://medinform.jmir.org/2021/11/e30066
# http://www.aimspress.com/article/doi/10.3934/mbe.2022028
# https://www.mdpi.com/2075-4418/11/11/2131
# https://www.frontiersin.org/articles/10.3389/fneur.2021.745475/full
# https://onlinelibrary.wiley.com/doi/10.1002/ijc.33860
# https://www.mdpi.com/2072-6694/13/22/5761
# https://www.frontiersin.org/articles/10.3389/fonc.2021.774248/full
# https://journals.asm.org/doi/10.1128/Spectrum.00802-21
# https://www.mdpi.com/2075-4418/11/11/2133
# https://journals.physiology.org/doi/full/10.1152/jn.00220.2021
# https://www.mdpi.com/1424-8220/21/22/7634
# https://www.mdpi.com/1424-8220/21/22/7628
# https://www.mdpi.com/1424-8220/21/22/7602
# https://www.mdpi.com/2075-4426/11/11/1213
# https://www.mdpi.com/1099-4300/23/11/1522
# https://www.mdpi.com/2072-6694/13/22/5731
# https://onlinelibrary.wiley.com/doi/10.1111/his.14571
# https://pubs.acs.org/doi/10.1021/acs.jproteome.1c00525
# https://www.frontiersin.org/articles/10.3389/fmed.2021.694520/full
# https://www.mdpi.com/1660-4601/18/22/12013
# https://www.mdpi.com/2077-0383/10/22/5326
# https://www.mdpi.com/2077-0383/10/22/5330
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15333
# https://www.frontiersin.org/articles/10.3389/fnsys.2021.716897/full
# https://www.frontiersin.org/articles/10.3389/fbioe.2021.761548/full
# https://www.mdpi.com/1424-8220/21/22/7584
# https://www.mdpi.com/2079-7737/10/11/1185
# https://www.mdpi.com/2075-4418/11/11/2119
# https://www.mdpi.com/1424-8220/21/22/7574
# https://www.mdpi.com/2075-4418/11/11/2109
# http://www.aimspress.com/article/doi/10.3934/mbe.2022017
# https://www.mdpi.com/2079-6374/11/11/453
# https://www.mdpi.com/2075-4418/11/11/2102
# https://www.mdpi.com/2079-7737/10/11/1174
# https://www.mdpi.com/1424-8220/21/22/7553
# https://www.mdpi.com/2075-4418/11/11/2103
# https://onlinelibrary.wiley.com/doi/10.1002/jsp2.1178
# https://www.mdpi.com/1424-8220/21/22/7540
# https://www.mdpi.com/1424-8220/21/22/7510
# https://www.mdpi.com/2075-4418/11/11/2091
# https://pubs.acs.org/doi/10.1021/acsomega.1c04204
# https://www.mdpi.com/1424-8220/21/22/7521
# https://www.mdpi.com/1424-8220/21/22/7528
# https://www.mdpi.com/1424-8220/21/22/7517
# https://academic.oup.com/comnet/article/9/6/cnab039/6426106
# https://www.mdpi.com/2072-6694/13/22/5670
# https://www.frontiersin.org/articles/10.3389/fgene.2021.784814/full
# https://obgyn.onlinelibrary.wiley.com/doi/10.1002/uog.24810
# https://www.mdpi.com/1424-8220/21/22/7500
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7500&id=464782
# https://onlinelibrary.wiley.com/doi/10.1111/cas.15173
# https://www.mdpi.com/2077-0383/10/22/5244
# https://www.mdpi.com/1648-9144/57/11/1230
# https://www.mdpi.com/2075-4418/11/11/2086
# https://www.mdpi.com/1660-4601/18/22/11816
# https://www.hindawi.com/journals/cin/2021/5478157/
# https://www.mdpi.com/1424-8220/21/22/7473
# https://www.mdpi.com/1424-8220/21/22/7458
# https://pubs.rsna.org/doi/10.1148/ryai.2021210015
# https://ieeexplore.ieee.org/document/9599660
# https://www.mdpi.com/2306-5354/8/11/181
# https://pubs.rsna.org/doi/10.1148/ryai.2021210211
# https://www.mdpi.com/1424-8220/21/22/7480
# https://formative.jmir.org/2021/11/e30313
# https://pubs.rsna.org/doi/10.1148/ryai.2021200152
# https://medinform.jmir.org/2021/11/e30277
# https://www.mdpi.com/2072-6643/13/11/4009
# https://journals.asm.org/doi/10.1128/Spectrum.00913-21
# https://onlinelibrary.wiley.com/doi/10.1111/his.14574
# https://www.mdpi.com/2075-4426/11/11/1163
# https://www.mdpi.com/2072-6694/13/22/5600
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7434&id=464725
# http://www.aimspress.com/article/doi/10.3934/mbe.2022007
# https://www.futuremedicine.com/doi/10.2217/fon-2021-0522
# https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e282
# https://www.hindawi.com/journals/ccrp/2021/6672603/
# https://onlinelibrary.wiley.com/doi/10.1111/den.14187
# https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/lt.26318
# https://www.jmir.org/2021/11/e28999
# https://onlinelibrary.wiley.com/doi/10.1111/opo.12909
# https://journals.sagepub.com/doi/10.1177/23259671211050613
# https://onlinelibrary.wiley.com/doi/10.1002/art.41885
# https://www.jmir.org/2021/11/e27875
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4383
# https://www.mdpi.com/2075-4418/11/11/2025
# https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/hep4.1846
# https://dnd.or.kr/DOIx.php?id=10.12779/dnd.2021.20.4.70
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15303
# https://www.hindawi.com/journals/jhe/2021/6024352/
# https://onlinelibrary.wiley.com/doi/10.1002/cjp2.249
# https://www.mdpi.com/1424-8220/21/21/7199
# https://ieeexplore.ieee.org/document/9570384
# https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.14140
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15295
# https://beva.onlinelibrary.wiley.com/doi/10.1111/evj.13528
# https://journals.sagepub.com/doi/10.1177/24715492211038172
# https://www.dovepress.com/health-data-driven-machine-learning-algorithms-applied-to-risk-indicat-peer-reviewed-fulltext-article-RMHP
# https://journals.lww.com/ctg/Fulltext/2021/11000/Automatic_Identification_of_Papillary_Projections.1.aspx
# https://pubs.rsna.org/doi/10.1148/ryai.2021210027
# https://www.dovepress.com/machine-learning-analysis-reveals-abnormal-static-and-dynamic-low-freq-peer-reviewed-fulltext-article-JPR
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25695
# https://www.hindawi.com/journals/jhe/2021/6382619/
# https://www.hindawi.com/journals/cmmm/2021/4622064/
# https://onlinelibrary.wiley.com/doi/10.1002/jcsm.12840
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15217
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15282
# https://mhealth.jmir.org/2021/10/e24872
# https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.13896
# https://www.mdpi.com/1424-8220/21/21/7036
# https://www.researchprotocols.org/2021/10/e26816
# https://onlinelibrary.wiley.com/doi/10.1002/path.5800
# https://www.mdpi.com/2075-4426/11/11/1062
# https://onlinelibrary.wiley.com/doi/10.1111/ane.13541
# https://www.mdpi.com/2079-7737/10/11/1083
# https://journals.sagepub.com/doi/10.1177/17562848211053114
# https://validate.perfdrive.com/?ssa=eeb6b5aa-ae5f-48dc-b97a-86aef063fe3b&ssb=45858286181&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1752-7163%2Fac2e57&ssi=f594920a-8427-4df6-8e5b-e8b24eb6ec93&ssk=support@shieldsquare.com&ssm=23958565776720790105859548476090&ssn=779ea6ce161788bfa167c9d13b85b39cd0daddd96774-2f39-4b41-8aba53&sso=8a1f894c-bae54916708e9503e42ad090f27e6c347b4ee867362b03ae&ssp=77268361441654619087165462709568295&ssq=66421062513642717239125136636773635764717&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://medinform.jmir.org/2021/10/e28039
# https://onlinelibrary.wiley.com/doi/10.1002/oca.2806
# https://onlinelibrary.wiley.com/doi/10.1002/jcla.24053
# https://www.mdpi.com/2075-4418/11/11/1943
# https://www.jmssjournal.net/article.asp?issn=2228-7477;year=2021;volume=11;issue=4;spage=237;epage=252;aulast=Mutepfe
# https://journals.physiology.org/doi/full/10.1152/ajplung.00198.2021
# https://rehab.jmir.org/2021/4/e29769
# https://onlinelibrary.wiley.com/doi/10.1002/mrm.29016
# https://www.jmir.org/2021/10/e26486
# https://onlinelibrary.wiley.com/doi/10.1111/jocs.16059
# https://ieeexplore.ieee.org/document/9570807
# https://www.jmir.org/2021/10/e26305
# https://onlinelibrary.wiley.com/doi/10.1111/exsy.12823
# https://journals.lww.com/ccejournal/Fulltext/2021/10000/Simplified_Pediatric_Index_of_Mortality_3_Score_by.21.aspx
# https://onlinelibrary.wiley.com/doi/10.1111/aos.15040
# https://physoc.onlinelibrary.wiley.com/doi/10.1113/JP281845
# https://onlinelibrary.wiley.com/doi/10.1111/jdv.17711
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-11-6969&id=460679
# https://www.jmir.org/2021/10/e24072
# https://onlinelibrary.wiley.com/doi/10.1111/ijcp.14961
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25679
# https://www.jmir.org/2021/10/e18403
# https://www.mdpi.com/2076-2607/9/10/2149
# https://journals.sagepub.com/doi/10.1177/23259671211046575
# https://onlinelibrary.wiley.com/doi/10.1002/jmv.27393
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/trc2.12212
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12246
# https://onlinelibrary.wiley.com/doi/10.1002/aur.2626
# https://onlinelibrary.wiley.com/doi/10.1111/ijpo.12859
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13440
# https://www.mdpi.com/1660-4601/18/20/10670
# https://www.mdpi.com/2072-6694/13/20/5109
# https://www.mdpi.com/2072-6694/13/20/5110
# https://www.hindawi.com/journals/jo/2021/1629318/
# https://www.liebertpub.com/doi/10.1089/wound.2021.0073
# https://www.mdpi.com/2075-4418/11/10/1870
# https://onlinelibrary.wiley.com/doi/10.1002/aur.2622
# https://onlinelibrary.wiley.com/doi/10.1002/jclp.23254
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22659
# https://www.mdpi.com/1660-4601/18/20/10603
# https://www.mdpi.com/2075-4418/11/10/1859
# https://www.mdpi.com/1424-8220/21/20/6708
# https://www.mdpi.com/2072-6694/13/20/5047
# https://www.mdpi.com/1422-0067/22/20/10903
# https://www.mdpi.com/1424-8220/21/20/6714
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25680
# https://www.mdpi.com/1424-8220/21/19/6682
# https://www.mdpi.com/1660-4601/18/19/10540
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13446
# https://www.cambridge.org/core/journals/public-health-nutrition/article/machine-learning-algorithms-for-predicting-undernutrition-among-underfive-children-in-ethiopia/6F72A5F339564946C2E16B27270849A8
# https://www.mdpi.com/2075-4418/11/10/1856
# https://www.hindawi.com/journals/jhe/2021/4405189/
# https://www.mdpi.com/1424-8220/21/19/6653
# https://www.mdpi.com/2075-4426/11/10/1008
# https://www.mdpi.com/1424-8220/21/19/6672
# https://www.mdpi.com/1424-8220/21/19/6652
# https://journals.sagepub.com/doi/10.1177/20556683211044640
# https://www.mdpi.com/2227-9032/9/10/1334
# https://www.mdpi.com/2075-1729/11/10/1052
# https://www.mdpi.com/1660-4601/18/19/10481
# https://pubs.rsna.org/doi/10.1148/ryai.2021200232
# https://www.mdpi.com/2075-4418/11/10/1844
# https://movementdisorders.onlinelibrary.wiley.com/doi/10.1002/mds.28814
# https://link.springer.com/article/10.1007/s11282-021-00572-0
# https://www.mdpi.com/2076-3425/11/10/1321
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13647
# https://onlinelibrary.wiley.com/doi/10.1111/bpa.13023
# https://www.hindawi.com/journals/cmmm/2021/3890988/
# https://www.mdpi.com/2072-6694/13/19/4976
# https://www.mdpi.com/2306-5354/8/10/138
# https://www.nature.com/articles/s41374-021-00647-w
# https://www.mdpi.com/2077-0383/10/19/4576
# https://www.mdpi.com/2075-4418/11/10/1824
# https://www.mdpi.com/1424-8220/21/19/6597
# https://www.mdpi.com/1660-4601/18/19/10391
# https://www.mdpi.com/1424-8220/21/19/6595
# https://www.mdpi.com/2227-9059/9/10/1377
# https://www.hindawi.com/journals/bmri/2021/2567202/
# https://kjronline.org/DOIx.php?id=10.3348/kjr.2020.1468
# https://www.mdpi.com/2072-6694/13/19/4961
# https://onlinelibrary.wiley.com/doi/10.1002/acr.24795
# https://www.mdpi.com/1660-4601/18/19/10357
# https://academic.oup.com/mr/advance-article-abstract/doi/10.1093/mr/roab073/6378620?redirectedFrom=fulltext
# https://medinform.jmir.org/2021/10/e27177
# https://www.mdpi.com/1424-8220/21/19/6584
# https://www.mdpi.com/1424-8220/21/19/6559
# https://www.mdpi.com/1424-8220/21/19/6558
# https://www.mdpi.com/2075-4418/11/10/1812
# https://www.mdpi.com/1424-8220/21/19/6570
# https://www.mdpi.com/2075-4426/11/10/991
# https://www.mdpi.com/2072-6694/13/19/4938
# https://www.mdpi.com/2227-9032/9/10/1306
# https://www.mdpi.com/2072-6694/13/19/4919
# https://formative.jmir.org/2021/9/e28000
# https://validate.perfdrive.com/?ssa=32751185-fd14-4edb-9436-2f6f491eb937&ssb=18023224515&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac23bf&ssi=810f66f4-8427-4d76-9e1b-60cdaeb1ec7d&ssk=support@shieldsquare.com&ssm=00466896854720562107681286218675&ssn=d8710440256b6efa493fdb94c38a6e64d4b7e1b21ba7-54ec-401d-b6f7ee&sso=9d650a9d-69a7d745cdbb012c2f389e249a47c3cfb9fbc448ba9fe46a&ssp=73506356731654640440165460793241138&ssq=06827092569774577049725697313227629615323&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://www.mdpi.com/1424-8220/21/19/6566
# https://www.mdpi.com/2075-4418/11/10/1810
# https://www.mdpi.com/2076-3425/11/10/1297
# https://www.mdpi.com/1424-8220/21/19/6511
# https://www.mdpi.com/2077-0383/10/19/4488
# https://www.mdpi.com/1424-8220/21/19/6513
# https://peerj.com/articles/cs-638/
# https://journals.lww.com/corneajrnl/Fulltext/2022/05000/Deep_Learning_for_Discrimination_Between_Fungal.13.aspx
# https://www.mdpi.com/2075-4426/11/10/981
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25656
# https://www.mdpi.com/2227-9059/9/10/1357
# https://www.mdpi.com/2073-4409/10/10/2587
# https://www.mdpi.com/1424-8220/21/19/6503
# https://www.mdpi.com/2075-4426/11/10/978
# https://www.mdpi.com/2077-0383/10/19/4508
# https://onlinelibrary.wiley.com/doi/10.1111/exsy.12842
# https://www.mdpi.com/2075-4418/11/10/1806
# https://www.tandfonline.com/doi/full/10.1080/02813432.2021.1973255
# https://www.mdpi.com/2072-6694/13/19/4875
# https://www.mdpi.com/2072-6694/13/19/4907
# https://pubs.rsna.org/doi/10.1148/ryai.2021200274
# https://journals.lww.com/ccejournal/Fulltext/2021/10000/Estimated_Pao2__A_Continuous_and_Noninvasive.5.aspx
# https://www.mdpi.com/2075-4418/11/10/1787
# https://www.mdpi.com/1424-8220/21/19/6481
# https://www.jhrsonline.org/article.asp?issn=0974-1208;year=2021;volume=14;issue=3;spage=288;epage=292;aulast=Geller
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13627
# https://www.mdpi.com/1424-8220/21/19/6485
# https://www.mdpi.com/2077-0383/10/19/4479
# https://www.mdpi.com/1424-8220/21/19/6484
# https://www.mdpi.com/2075-4418/11/10/1784
# https://www.mdpi.com/2075-4418/11/10/1785
# https://www.mdpi.com/2072-6694/13/19/4837
# https://www.mdpi.com/1660-4601/18/19/10150
# https://www.mdpi.com/2077-0383/10/19/4437
# https://www.mdpi.com/1660-4601/18/19/10147
# https://validate.perfdrive.com/?ssa=b7581cc8-8c5f-4c99-a22b-bbcf99a8f0b1&ssb=27414288652&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6579%2Fac2264&ssi=7aa81504-8427-4e9f-9ec1-414de9147c02&ssk=support@shieldsquare.com&ssm=23605924508097335104928297787681&ssn=063e1424ba3ebf33a81a5a7f6b69c61f5e82380fdda9-7daa-459b-8efe41&sso=fbbe76b7-02d75aa2284e7267b92d4e359b1cf3c67dbb4eabafffa3da&ssp=46114277251654646178165467991239476&ssq=23902552588147290686125881953433070089799&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://www.mdpi.com/1424-8220/21/19/6451
# https://www.mdpi.com/1424-8220/21/19/6459
# https://www.mdpi.com/2077-0383/10/19/4431
# https://www.mdpi.com/1424-8220/21/19/6446
# https://journals.lww.com/transplantationdirect/Fulltext/2021/10000/Machine_Learning_Prediction_of_Liver_Allograft.26.aspx
# https://www.mdpi.com/2077-0383/10/19/4441
# https://www.mdpi.com/2075-4418/11/10/1773
# https://www.mdpi.com/2077-0383/10/19/4393
# https://www.mdpi.com/2077-0383/10/19/4394
# https://www.mdpi.com/2075-4418/11/10/1767
# https://www.mdpi.com/2076-2615/11/10/2806
# https://www.mdpi.com/2075-1729/11/10/1013
# https://www.mdpi.com/1099-4300/23/10/1251
# https://www.mdpi.com/2227-9059/9/10/1319
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15231
# https://www.mdpi.com/2073-4409/10/10/2539
# https://www.mdpi.com/1424-8220/21/19/6401
# https://www.mdpi.com/1424-8220/21/19/6412
# https://onlinelibrary.wiley.com/doi/10.1002/jmv.27352
# https://www.mdpi.com/1099-4300/23/10/1248
# https://www.tandfonline.com/doi/full/10.1080/21681805.2021.1977845
# https://www.mdpi.com/1424-8220/21/19/6393
# https://www.mdpi.com/1660-4601/18/19/10048
# https://www.mdpi.com/1422-0067/22/19/10291
# https://www.mdpi.com/2075-4418/11/10/1759
# https://www.tandfonline.com/doi/full/10.1080/20008198.2021.1958471
# https://www.mdpi.com/1424-8220/21/19/6369
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6529&id=459854
# https://www.mdpi.com/2076-3425/11/10/1262
# https://www.mdpi.com/2077-0383/10/19/4354
# https://www.mdpi.com/2075-4418/11/10/1747
# https://www.mdpi.com/2072-6694/13/19/4751
# https://www.tandfonline.com/doi/full/10.1080/0284186X.2021.1979645
# https://onlinelibrary.wiley.com/doi/10.1002/jcla.24018
# https://onlinelibrary.wiley.com/doi/10.1002/art.41781
# https://journals.lww.com/jpho-online/Fulltext/2022/04000/Can_Machine_Learning_Models_Predict.14.aspx
# https://www.mdpi.com/1648-9144/57/10/996
# https://www.futuremedicine.com/doi/10.2217/nnm-2021-0076
# https://ieeexplore.ieee.org/document/9543467
# https://www.mdpi.com/1424-8220/21/18/6311
# https://www.mdpi.com/1424-8220/21/18/6323
# https://www.jmir.org/2021/9/e26025
# https://www.mdpi.com/2075-4418/11/9/1735
# https://link.springer.com/chapter/10.1007/978-3-030-87202-1_44
# https://onlinelibrary.wiley.com/doi/10.1111/ijlh.13681
# https://www.mdpi.com/2075-4418/11/9/1732
# https://www.hindawi.com/journals/cin/2021/8439655/
# https://asbmr.onlinelibrary.wiley.com/doi/10.1002/jbm4.10549
# https://www.mdpi.com/2077-0383/10/18/4281
# https://www.mdpi.com/2077-0383/10/18/4263
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6422&id=459635
# https://www.mdpi.com/2075-4418/11/9/1725
# https://www.mdpi.com/1099-4300/23/9/1232
# https://www.mdpi.com/1424-8220/21/18/6291
# https://www.mdpi.com/1660-4601/18/18/9873
# https://www.mdpi.com/2075-4418/11/9/1714
# https://www.mdpi.com/2075-4418/11/9/1718
# https://www.mdpi.com/2075-4426/11/9/934
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22654
# https://www.mdpi.com/2313-433X/7/9/189
# https://www.mdpi.com/2075-4418/11/9/1712
# https://www.mdpi.com/1424-8220/21/18/6263
# https://www.mdpi.com/1424-8220/21/18/6264
# https://www.mdpi.com/2075-4426/11/9/928
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12227
# https://www.mdpi.com/2077-0383/10/18/4245
# https://www.mdpi.com/1424-8220/21/18/6274
# https://www.mdpi.com/1424-8220/21/18/6246
# https://www.mdpi.com/1424-8220/21/18/6230
# https://www.mdpi.com/2079-6374/11/9/343
# https://www.mdpi.com/1424-8220/21/18/6249
# https://www.mdpi.com/2072-6694/13/18/4674
# https://www.mdpi.com/2072-6694/13/18/4671
# https://www.mdpi.com/1424-8220/21/18/6210
# https://www.mdpi.com/1660-4601/18/18/9768
# https://www.mdpi.com/1424-8220/21/18/6202
# https://www.mdpi.com/1718-7729/28/5/307
# https://www.mdpi.com/2075-4418/11/9/1690
# https://onlinelibrary.wiley.com/doi/10.1002/ags3.12504
# https://peerj.com/articles/cs-671/
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6326&id=458783
# https://www.mdpi.com/1422-0067/22/18/9970
# https://www.mdpi.com/2072-6694/13/18/4635
# https://www.mdpi.com/1424-8220/21/18/6189
# https://www.mdpi.com/2075-4418/11/9/1686
# https://www.mdpi.com/2073-4409/10/9/2430
# https://www.birpublications.org/doi/10.1259/bjr.20210221
# https://formative.jmir.org/2021/9/e28028
# https://www.mdpi.com/2075-4418/11/9/1676
# https://onlinelibrary.wiley.com/doi/10.1111/iwj.13691
# https://www.mdpi.com/2075-4418/11/9/1678
# https://www.mdpi.com/2075-4418/11/9/1677
# https://www.reed.es/Artificial-intelligence-and-capsule-endoscopy-automatic-detection-of-enteric-protruding-lesions-using-a-convolutional-neural-network6036?AspxAutoDetectCookieSupport=1
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25660
# https://www.mdpi.com/1424-8220/21/18/6147
# https://onlinelibrary.wiley.com/doi/10.1111/sltb.12800
# https://www.mdpi.com/2072-6694/13/18/4585
# https://www.jmir.org/2021/9/e27798
# https://www.mdpi.com/2072-6694/13/18/4593
# https://www.mdpi.com/2075-4418/11/9/1672
# https://www.hindawi.com/journals/cmmm/2021/8036304/
# https://www.mdpi.com/2072-6694/13/18/4559
# https://www.mdpi.com/2075-4418/11/9/1664
# https://www.mdpi.com/1648-9144/57/9/956
# https://onlinelibrary.wiley.com/doi/10.1111/jon.12927
# https://journals.lww.com/ccejournal/Fulltext/2021/09000/Explainable_Machine_Learning_on_AmsterdamUMCdb_for.13.aspx
# https://www.mdpi.com/1424-8220/21/18/6049
# https://www.mdpi.com/2075-1729/11/9/940
# https://www.mdpi.com/2073-4360/13/18/3041
# https://www.mdpi.com/1424-8220/21/18/6043
# https://www.mdpi.com/2077-0383/10/18/4074
# https://www.mdpi.com/1424-8220/21/18/6033
# https://www.mdpi.com/2306-5354/8/9/122
# https://www.mdpi.com/2075-4426/11/9/902
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4054
# https://www.mdpi.com/1424-8220/21/18/6008
# https://www.jcvjs.com/article.asp?issn=0974-8237;year=2021;volume=12;issue=3;spage=223;epage=227;aulast=Siemionow
# https://journals.sagepub.com/doi/10.1177/19476035211042406
# https://onlinelibrary.wiley.com/doi/10.1002/jso.26668
# https://www.mdpi.com/2072-6694/13/17/4468
# https://onlinelibrary.wiley.com/doi/10.1111/his.14438
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4261
# https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/nbm.4606
# https://onlinelibrary.wiley.com/doi/10.1111/ajt.16807
# https://onlinelibrary.wiley.com/doi/10.1111/ejn.15423
# https://journals.lww.com/cmj/Fulltext/2021/10050/Development_and_validation_of_a_deep_learning.11.aspx
# https://validate.perfdrive.com/?ssa=218d634c-c9b6-498f-8db5-c896002a96e1&ssb=03483244872&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac1d32&ssi=616b0164-8427-40a6-aad9-c5cfb71918b4&ssk=support@shieldsquare.com&ssm=49481585642023675108851768063385&ssn=e2f70d2408b35ff6418eb1f002c37f8cecefa47e261a-8ed2-4de9-9e5792&sso=f494a2a5-5cef9e3c5eed0446d05e14620840ca14faf69adff61518e3&ssp=10443795411654602672165469207410111&ssq=02435082655284157295426552369173712932890&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://www.liebertpub.com/doi/10.1089/wound.2021.0073
# https://onlinelibrary.wiley.com/doi/10.1002/iid3.506
# https://pubs.rsna.org/doi/10.1148/ryai.2021200299
# https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/syb2.12033
# https://www.jehp.net/article.asp?issn=2277-9531;year=2021;volume=10;issue=1;spage=285;epage=285;aulast=Shanbehzadeh
# https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/htl2.12017
# https://www.medicaljournals.se/acta/content/abstract/10.2340/00015555-3893
# https://kjronline.org/DOIx.php?id=10.3348/kjr.2021.0348
# https://www.tandfonline.com/doi/full/10.1080/07391102.2021.1966509
# https://onlinelibrary.wiley.com/doi/10.1111/nan.12759
# https://onlinelibrary.wiley.com/doi/10.1111/ene.15071
# https://onlinelibrary.wiley.com/doi/10.1111/ijcp.14746
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4092
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4230
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15017
# https://link.springer.com/article/10.1007/s10654-021-00797-7
# https://www.mdpi.com/1660-4601/18/17/9091
# https://validate.perfdrive.com/?ssa=18092be7-ed7c-474d-bb7f-9dea93ad20b2&ssb=69994249584&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6560%2Fac176d&ssi=fe19880d-8427-46dd-817b-fee158b4821e&ssk=support@shieldsquare.com&ssm=92545470598580196101000880765807&ssn=f94eee0deac257251477cf3d1735650937f7256a2e1f-6474-4896-b571dc&sso=a3cca505-443b20de503d27eb39b4d1789db20b27094e047e6a197b81&ssp=35446970761654612578165469629901064&ssq=42946172669362637502126693957489322798372&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/jemt.23913
# https://peerj.com/articles/11988/
# https://pubs.asha.org/doi/10.1044/2021_JSLHR-21-00134
# https://onlinelibrary.wiley.com/doi/10.1111/srt.13086
# https://journals.sagepub.com/doi/10.1177/00220345211032524
# https://journals.sagepub.com/doi/10.1177/00034894211041222
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25629
# https://journals.lww.com/ccejournal/Fulltext/2021/08000/Machine_Learning_Prediction_of_Death_in_Critically.18.aspx
# https://onlinelibrary.wiley.com/doi/10.1111/jocs.15917
# https://validate.perfdrive.com/?ssa=d733efc6-c700-4f5f-a734-71e87f6a8e4f&ssb=29558292802&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac1adc&ssi=9a704500-8427-435c-b930-4492b13a0768&ssk=support@shieldsquare.com&ssm=95873137491372695104672279976011&ssn=add7c7c386c206682ffa0044457fe56588542931da31-7844-4a7d-b4b979&sso=79ddcc30-1eb55c9b07dee3fa26061797afaaf3ab5adda933067767f1&ssp=06259170711654639554165466003218240&ssq=32752972676012747189626760084376483129126&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://www.frontiersin.org/articles/10.3389/fmed.2021.688986/full
# https://www.science.org/doi/10.1126/sciadv.abh0693?cookieSet=1
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5658&id=457264
# https://www.frontiersin.org/articles/10.3389/fped.2021.710720/full
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13556
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5559&id=457142
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25620
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22644
# https://onlinelibrary.wiley.com/doi/10.1111/dmcn.15010
# https://link.springer.com/article/10.1007/s10840-021-01045-4
# https://medinform.jmir.org/2021/8/e28287
# https://journals.sagepub.com/doi/10.1177/07067437211037141
# https://journals.asm.org/doi/10.1128/JCM.00971-21
# https://pubs.rsna.org/doi/10.1148/ryai.2021200278
# https://www.mdpi.com/2077-0383/10/16/3523
# https://www.mdpi.com/2075-4418/11/8/1449
# https://www.hindawi.com/journals/bmri/2021/1337558/
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15126
# https://link.springer.com/article/10.1007/s10278-021-00500-y
# https://bmcmedimaging.biomedcentral.com/articles/10.1186/s12880-021-00653-w
# https://www.mdpi.com/2072-6694/13/16/4030
# https://www.mdpi.com/1424-8220/21/16/5406
# https://www.mdpi.com/2075-4418/11/8/1446
# https://www.mdpi.com/2075-4418/11/8/1445
# https://onlinelibrary.wiley.com/doi/10.1002/jmv.27252
# https://journals.lww.com/ccejournal/Fulltext/2021/08000/Predicting_Future_Care_Requirements_Using_Machine.10.aspx
# https://www.mdpi.com/1424-8220/21/16/5371
# https://www.mdpi.com/1424-8220/21/16/5383
# https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e198
# https://www.mdpi.com/1424-8220/21/16/5385
# https://www.mdpi.com/2079-6374/11/8/269
# https://onlinelibrary.wiley.com/doi/10.1002/emp2.12534
# https://www.nature.com/articles/s42256-021-00377-0
# https://www.mdpi.com/2075-4418/11/8/1437
# https://www.mdpi.com/1424-8220/21/16/5381
# https://onlinelibrary.wiley.com/doi/10.1002/jmri.27879
# https://www.mdpi.com/1424-8220/21/16/5361
# https://www.mdpi.com/2072-6694/13/16/3998
# https://www.jmp.org.in/article.asp?issn=0971-6203;year=2021;volume=46;issue=2;spage=80;epage=87;aulast=Amarsee
# https://www.mdpi.com/1424-8220/21/16/5334
# https://www.mdpi.com/2075-4418/11/8/1429
# https://www.mdpi.com/2076-3425/11/8/1049
# https://www.mdpi.com/1424-8220/21/16/5327
# https://www.mdpi.com/1424-8220/21/16/5315
# https://onlinelibrary.wiley.com/doi/10.1002/art.41735
# https://www.tandfonline.com/doi/full/10.1080/20002297.2021.1962125
# https://onlinelibrary.wiley.com/doi/10.1002/art.41708
# https://www.mdpi.com/2072-6694/13/16/3976
# https://www.mdpi.com/1424-8220/21/16/5328
# https://www.mdpi.com/1424-8220/21/16/5309
# https://www.mdpi.com/2075-4418/11/8/1416
# https://ieeexplore.ieee.org/document/9336225
# https://www.mdpi.com/1424-8220/21/16/5289
# https://www.mdpi.com/1424-8220/21/16/5302
# https://www.mdpi.com/1424-8220/21/16/5304
# https://www.mdpi.com/2379-139X/7/3/31
# https://www.mdpi.com/1424-8220/21/16/5283
# https://www.mdpi.com/2075-4418/11/8/1409
# https://www.mdpi.com/2075-4418/11/8/1405
# https://www.mdpi.com/1424-8220/21/16/5273
# https://www.mdpi.com/2076-3425/11/8/1037
# https://www.mdpi.com/2313-433X/7/8/131
# https://journals.lww.com/ctg/Fulltext/2021/08000/A_Novel_Deep_Learning_System_for_Diagnosing_Early.7.aspx
# https://www.mdpi.com/1424-8220/21/16/5270
# https://onlinelibrary.wiley.com/doi/10.1002/clc.23687
# https://royalsocietypublishing.org/doi/10.1098/rsif.2021.0284
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5401&id=454003
# https://www.mdpi.com/1424-8220/21/16/5256
# https://www.mdpi.com/1424-8220/21/16/5253
# https://academic.oup.com/oncolo/article/26/10/e1822/6513521
# https://peerj.com/articles/cs-614/
# https://journals.lww.com/ctg/Fulltext/2021/08000/Simultaneous_Recognition_of_Atrophic_Gastritis_and.5.aspx
# https://www.hindawi.com/journals/cin/2021/9996737/
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13381
# https://www.mdpi.com/1424-8220/21/15/5239
# https://www.mdpi.com/2075-4418/11/8/1398
# https://www.mdpi.com/1424-8220/21/15/5236
# https://medscimonit.com/abstract/full/idArt/934171
# https://peerj.com/articles/cs-654/
# https://onlinelibrary.wiley.com/doi/10.1002/ajh.26295
# https://www.mdpi.com/2072-6694/13/15/3903
# https://www.mdpi.com/2072-6694/13/15/3891
# https://www.mdpi.com/1424-8220/21/15/5222
# https://www.mdpi.com/2079-9721/9/3/54
# https://www.mdpi.com/2218-1989/11/8/507
# https://dl.acm.org/doi/10.1145/3459930.3469564
# https://www.mdpi.com/1424-8220/21/15/5192
# https://www.mdpi.com/2075-4418/11/8/1385
# https://www.mdpi.com/2075-4418/11/8/1386
# https://www.mdpi.com/1424-8220/21/15/5207
# https://onlinelibrary.wiley.com/doi/10.1111/cea.13993
# https://www.mdpi.com/2227-9032/9/8/971
# https://www.mdpi.com/1424-8220/21/15/5212
# https://www.mdpi.com/2075-4418/11/8/1383
# https://www.mdpi.com/2077-0383/10/15/3398
# https://www.mdpi.com/1424-8220/21/15/5172
# https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-021-01450-9
# https://www.dovepress.com/early-prediction-of-covid-19-ventilation-requirement-and-mortality-fro-peer-reviewed-fulltext-article-JMDH
# https://www.mdpi.com/2075-4418/11/8/1380
# https://www.mdpi.com/2072-6694/13/15/3851
# https://www.mdpi.com/1099-4300/23/8/984
# https://journals.sagepub.com/doi/10.1177/01455613211029749
# https://www.frontiersin.org/articles/10.3389/fphys.2021.704122/full
# https://bmjopen.bmj.com/content/11/7/e046716
# https://peerj.com/articles/cs-655/
# https://onlinelibrary.wiley.com/doi/10.1111/exsy.12776
# https://www.mdpi.com/1424-8220/21/15/5135
# https://www.mdpi.com/1424-8220/21/15/5130
# https://onlinelibrary.wiley.com/doi/10.1002/jor.25150
# https://www.mdpi.com/2075-4426/11/8/748
# https://www.mdpi.com/2073-4409/10/8/1930
# https://www.mdpi.com/2379-139X/7/3/27
# https://www.hindawi.com/journals/jhe/2021/2603842/
# https://www.dovepress.com/machine-learning-algorithms-are-superior-to-conventional-regression-mo-peer-reviewed-fulltext-article-RMHP
# https://www.mdpi.com/1660-4601/18/15/8059
# https://www.mdpi.com/1424-8220/21/15/5145
# https://www.hindawi.com/journals/jhe/2021/9687591/
# https://www.mdpi.com/2072-6694/13/15/3811
# https://www.mdpi.com/1660-4601/18/15/8052
# https://onlinelibrary.wiley.com/doi/10.1002/advs.202101333
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25574
# https://www.mdpi.com/2072-6694/13/15/3825
# https://onlinelibrary.wiley.com/doi/10.1002/clc.23688
# https://www.hindawi.com/journals/jhe/2021/1730158/
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-8-5305&id=453796
# https://peerj.com/articles/cs-646/
# https://www.mdpi.com/2075-4426/11/8/739
# https://www.mdpi.com/2072-6694/13/15/3795
# https://www.mdpi.com/2227-9032/9/8/948
# https://www.mdpi.com/1424-8220/21/15/5105
# https://journals.sagepub.com/doi/10.1177/11769351211035137
# https://www.dovepress.com/machine-learning-in-an-elderly-man-with-heart-failure-peer-reviewed-fulltext-article-IMCRJ
# https://www.mdpi.com/2075-4426/11/8/727
# https://www.mdpi.com/2072-6694/13/15/3760
# https://www.mdpi.com/2072-6694/13/15/3768
# https://www.mdpi.com/2075-4426/11/8/725
# https://journals.lww.com/prsgo/Fulltext/2021/07000/A_Novel_Artificial_Intelligence_assisted_Risk.50.aspx
# https://www.mdpi.com/1424-8220/21/15/5092
# https://www.hindawi.com/journals/cmmm/2021/2464821/
# https://www.mdpi.com/2227-9032/9/8/941
# https://www.mdpi.com/2075-1729/11/8/747
# https://onlinelibrary.wiley.com/doi/10.1111/liv.14999
# https://www.mdpi.com/2072-6694/13/15/3723
# https://www.hindawi.com/journals/jhe/2021/4963361/
# https://www.mdpi.com/2076-3425/11/8/977
# https://www.mdpi.com/2072-6694/13/15/3709
# https://www.mdpi.com/1424-8220/21/15/5006
# https://www.mdpi.com/2075-4418/11/8/1324
# https://onlinelibrary.wiley.com/doi/10.1002/acr2.11289
# https://www.mdpi.com/1099-4300/23/8/936
# https://peerj.com/articles/cs-547/
# https://www.mdpi.com/2072-6694/13/15/3689
# https://www.mdpi.com/2077-0383/10/15/3238
# https://www.mdpi.com/2077-0383/10/15/3231
# https://www.mdpi.com/2075-1729/11/8/730
# https://www.mdpi.com/2075-4426/11/8/695
# https://www.tandfonline.com/doi/full/10.1080/07448481.2021.1947841
# https://www.mdpi.com/2077-0383/10/15/3198
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22627
# https://onlinelibrary.wiley.com/doi/10.1111/cas.15052
# https://www.mdpi.com/1424-8220/21/15/4960
# https://www.mdpi.com/2075-4418/11/8/1309
# https://validate.perfdrive.com/?ssa=c390a30d-d991-4a25-8ccc-b21091157a17&ssb=20064207389&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac0d60&ssi=0afb6738-8427-442d-af6b-fe553b023a31&ssk=support@shieldsquare.com&ssm=45797022799250631102658711723324&ssn=19c72bdb1ee432bb76a6a5ba1635a14fd13d3bb9fc2b-57c2-40d8-99aeb0&sso=952adea6-022422c6f3a0020a18fdfec392d383640c3ad81026297bcd&ssp=04123622601654639319165467046625323&ssq=40480012767679196243827676985994996137228&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://www.mdpi.com/1424-8220/21/15/4949
# https://medinform.jmir.org/2021/7/e27955
# https://www.hindawi.com/journals/ije/2021/3984463/
# https://onlinelibrary.wiley.com/doi/10.1002/epi4.12520
# https://www.mdpi.com/2075-4418/11/7/1299
# https://www.mdpi.com/1424-8220/21/14/4928
# https://www.mdpi.com/1424-8220/21/14/4926
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-8-4997&id=453427
# https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e187
# https://www.mdpi.com/2072-6694/13/14/3616
# https://www.mdpi.com/2072-6694/13/14/3611
# https://www.mdpi.com/2227-9032/9/7/911
# https://www.mdpi.com/1660-4601/18/14/7625
# https://www.mdpi.com/1660-4601/18/14/7635
# https://preprints.jmir.org/preprint/26769/accepted
# https://onlinelibrary.wiley.com/doi/10.1002/advs.202101129
# https://www.thieme-connect.de/DOI/DOI?10.1055/a-1490-8960
# https://journals.sagepub.com/doi/10.1177/17562864211029551
# https://onlinelibrary.wiley.com/doi/10.1111/epi.16967
# https://onlinelibrary.wiley.com/doi/10.1002/brb3.2238
# https://peerj.com/articles/cs-622/
# https://bjui-journals.onlinelibrary.wiley.com/doi/10.1111/bju.15515
# https://journals.sagepub.com/doi/10.1177/13524585211029860
# https://www.mdpi.com/2075-4418/11/7/1255
# https://isdent.org/DOIx.php?id=10.5624/isd.20210077
# https://journals.lww.com/ccejournal/Fulltext/2021/07000/A_Full_Stack_Application_for_Detecting_Seizures.14.aspx
# https://www.mdpi.com/1424-8220/21/14/4785
# https://www.hindawi.com/journals/cin/2021/9523039/
# https://www.tandfonline.com/doi/full/10.1080/2162402X.2021.1947665
# https://mhealth.jmir.org/2021/7/e26540
# https://www.nature.com/articles/s43587-021-00082-y
# https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e175
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13350
# https://www.tandfonline.com/doi/full/10.1080/21678421.2021.1927102
# https://journals.sagepub.com/doi/10.1177/09544119211028380
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14834
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15044
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25565
# https://onlinelibrary.wiley.com/doi/10.1111/epi.16990
# https://www.ahajournals.org/doi/10.1161/STROKEAHA.120.030950
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-8-4713&id=453098
# https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/hep4.1768
# https://academic.oup.com/oncolo/article/26/9/751/6512110
# https://www.tandfonline.com/doi/full/10.1080/14767058.2021.1918670
# https://journals.sagepub.com/doi/10.1177/15353702211018970
# https://www.mdpi.com/1424-8220/21/14/4638
# https://peerj.com/articles/11692/
# https://journals.sagepub.com/doi/10.1177/21925682211026910
# https://link.springer.com/article/10.1007/s00330-021-08146-8
# https://www.birpublications.org/doi/10.1259/bjro.20200073
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25575
# http://www.annalsgastro.gr/files/journals/1/earlyview/2021/ev-07-2021-07-AG_5972-0653.pdf
# https://anndermatol.org/DOIx.php?id=10.5021/ad.2021.33.4.345
# https://onlinelibrary.wiley.com/doi/10.1111/1754-9485.13278
# https://journals.lww.com/cmj/Fulltext/2021/08050/Establish_a_normal_fetal_lung_gestational_age.11.aspx
# https://onlinelibrary.wiley.com/doi/10.1111/hepr.13681
# https://onlinelibrary.wiley.com/doi/10.1002/cpe.6434
# ...
# https://onlinelibrary.wiley.com/doi/10.1111/iwj.13644
# https://www.hindawi.com/journals/cmmm/2021/5569458/
# https://journals.sagepub.com/doi/10.1177/26317745211020277
# https://www.future-science.com/doi/10.2144/fsoa-2020-0207
# https://www.tandfonline.com/doi/full/10.1080/17538157.2021.1939355
# https://journals.lww.com/ccejournal/Fulltext/2021/06000/Impact_of_Different_Approaches_to_Preparing_Notes.7.aspx
# https://www.mdpi.com/2075-4426/11/6/541
# https://www.frontiersin.org/articles/10.3389/frai.2021.684609/full
# https://www.hindawi.com/journals/cmmi/2021/5572470/
# https://www.aging-us.com/article/203122/text
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4044
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-7-3965&id=451756
# https://validate.perfdrive.com/?ssa=43585baf-efdb-4f82-83b2-12466ade9ccc&ssb=14717206203&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac0584&ssi=c5a9443b-8427-46c2-baab-b5dffe824ced&ssk=support@shieldsquare.com&ssm=07908168235411695108536823563728&ssn=36386faecffc69068af3ec9014f78685ec0a14407ccc-294b-4b85-aee34b&sso=860425c0-80e76bb6e43efaab0c82409a8d725217f7d72da0c32f9259&ssp=59126111021654667410165464775925115&ssq=76733922865381230652228653382682640681128&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/alz.12387
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12207
# https://www.birpublications.org/doi/10.1259/bjr.20201444
# https://onlinelibrary.wiley.com/doi/10.1002/mrm.28852
# https://onlinelibrary.wiley.com/doi/10.1111/iwj.13623
# https://www.oncotarget.com/article/27979/text/
# https://link.springer.com/chapter/10.1007/978-3-030-77211-6_29
# https://journals.asm.org/doi/10.1128/mSystems.01367-20
# https://onlinelibrary.wiley.com/doi/10.1111/ddg.14510
# https://www.mdpi.com/1424-8220/21/11/3878
# https://onlinelibrary.wiley.com/doi/10.1111/ocr.12501
# https://onlinelibrary.wiley.com/doi/10.1002/acr2.11266
# https://www.mdpi.com/1424-8220/21/11/3883
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22611
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13398
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13358
# https://movementdisorders.onlinelibrary.wiley.com/doi/10.1002/mds.28661
# https://www.aging-us.com/article/203071/text
# https://www.hindawi.com/journals/cmmm/2021/6656942/
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.4048
# https://link.springer.com/article/10.1007/s10143-021-01573-7
# https://onlinelibrary.wiley.com/doi/10.1002/cjp2.227
# https://onlinelibrary.wiley.com/doi/10.1111/exsy.12742
# https://www.hindawi.com/journals/cmmm/2021/9928899/
# https://medinform.jmir.org/2021/5/e28868
# https://onlinelibrary.wiley.com/doi/10.1002/brb3.2201
# https://onlinelibrary.wiley.com/doi/10.1111/ics.12706
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13375
# https://www.hindawi.com/journals/joph/2021/6694784/
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14903
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3671&id=451450
# https://www.hindawi.com/journals/cin/2021/5540186/
# https://peerj.com/articles/cs-555/
# https://onlinelibrary.wiley.com/doi/10.1002/jcla.23833
# https://journals.sagepub.com/doi/10.1177/21925682211019361
# https://peerj.com/articles/cs-551/
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14927
# https://peerj.com/articles/cs-511/
# https://ieeexplore.ieee.org/document/9434127
# https://journals.lww.com/jaaosglobal/Fulltext/2021/05000/Machine_Learning_Algorithms_Predict_Prolonged.17.aspx
# https://ieeexplore.ieee.org/document/9434018
# https://onlinelibrary.wiley.com/doi/10.1002/jmri.27741
# https://ieeexplore.ieee.org/document/9434034
# https://ieeexplore.ieee.org/document/9433879
# https://peerj.com/articles/cs-560/
# https://www.aging-us.com/article/203082/text
# https://www.nature.com/articles/s41591-021-01339-0
# https://medinform.jmir.org/2021/5/e25237
# https://www.sciencedirect.com/science/article/abs/pii/S0002962921001129?via%3Dihub
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25534
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12201
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3584&id=451276
# https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-021-01510-0
# https://onlinelibrary.wiley.com/doi/10.1002/lci2.25
# https://onlinelibrary.wiley.com/doi/10.1002/aur.2540
# https://www.futuremedicine.com/doi/10.2217/fon-2020-1254
# https://pubs.rsna.org/doi/10.1148/ryai.2021200172
# https://journals.asm.org/doi/10.1128/JCM.02959-20
# https://onlinelibrary.wiley.com/doi/10.1111/bpa.12974
# https://www.sciencedirect.com/science/article/pii/S187705092100702X?via%3Dihub
# https://onlinelibrary.wiley.com/doi/10.1002/gcc.22956
# https://peerj.com/articles/cs-541/
# https://www.aging-us.com/article/203032/text
# https://journals.lww.com/ccejournal/Fulltext/2021/05000/A_Machine_Learning_Classifier_Improves_Mortality.24.aspx
# https://onlinelibrary.wiley.com/doi/10.1111/bjh.17524
# https://www.tandfonline.com/doi/full/10.1080/17461391.2021.1921041
# https://link.springer.com/article/10.1007/s00330-021-08014-5
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14907
# https://onlinelibrary.wiley.com/doi/10.1111/eip.13175
# https://onlinelibrary.wiley.com/doi/10.1002/ams2.666
# https://onlinelibrary.wiley.com/doi/10.1111/jsr.13386
# https://www.nature.com/articles/s41591-021-01342-5
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12140
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14624
# https://www.aging-us.com/article/203033/text
# https://www.futuremedicine.com/doi/10.2217/cer-2020-0230
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.3965
# https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12187
# https://www.tandfonline.com/doi/full/10.1080/20002297.2021.1921486
# https://ieeexplore.ieee.org/document/9413538
# https://ieeexplore.ieee.org/document/9414041
# https://onlinelibrary.wiley.com/doi/10.1002/ima.22595
# https://pubs.rsna.org/doi/10.1148/ryai.2021200127
# https://journals.lww.com/ccejournal/Fulltext/2021/05000/Prediction_of_Acute_Respiratory_Failure_Requiring.6.aspx
# https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.13991
# https://onlinelibrary.wiley.com/doi/10.1002/ca.23742
# https://onlinelibrary.wiley.com/doi/10.1111/ddg.14384
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25529
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.3957
# https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/jemt.23779
# https://onlinelibrary.wiley.com/doi/10.1002/advs.202100104
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3228&id=450880
# https://journals.sagepub.com/doi/10.1177/15533506211018671
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25436
# https://journals.lww.com/ctg/Fulltext/2021/05000/A_Novel_5_Cytokine_Panel_Outperforms_Conventional.9.aspx
# https://peerj.com/articles/cs-537/
# https://bjui-journals.onlinelibrary.wiley.com/doi/10.1111/bju.15386
# https://onlinelibrary.wiley.com/doi/10.1111/jgh.15522
# https://onlinelibrary.wiley.com/doi/10.1111/ene.14859
# https://ieeexplore.ieee.org/document/9417103
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3103&id=450751
# https://onlinelibrary.wiley.com/doi/10.1002/rth2.12505
# https://onlinelibrary.wiley.com/doi/10.1002/epi4.12488
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25437
# https://aacrjournals.org/cebp/article/30/7/1397/671007/Tumor-Associated-Stromal-Cellular-Density-as-a
# https://onlinelibrary.wiley.com/doi/10.1111/cas.14927
# https://journals.asm.org/doi/10.1128/mSystems.00112-21
# https://opg.optica.org/optica/fulltext.cfm?uri=optica-8-5-642&id=450700
# https://onlinelibrary.wiley.com/doi/10.1111/iwj.13603
# https://www.aging-us.com/article/202954/text
# https://onlinelibrary.wiley.com/doi/10.1111/1556-4029.14704
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3066&id=450678
# https://onlinelibrary.wiley.com/doi/10.1002/ajmg.a.62227
# https://mhealth.jmir.org/2021/5/e23681
# https://www.thno.org/v11p6703.htm
# https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e122
# https://ascpt.onlinelibrary.wiley.com/doi/10.1111/cts.13035
# https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14855
# https://obgyn.onlinelibrary.wiley.com/doi/10.1002/ijgo.13644
# https://onlinelibrary.wiley.com/doi/10.1002/cam4.3872
# https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/htl2.12010
# https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13344
# https://ascpt.onlinelibrary.wiley.com/doi/10.1111/cts.13030
# https://onlinelibrary.wiley.com/doi/10.1002/hbm.25460
# https://www.science.org/doi/10.1126/sciadv.abf9405
# https://validate.perfdrive.com/?ssa=9ec44926-b825-48c3-a6be-a6c21ef49123&ssb=51355287896&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fabf68a&ssi=9df7e1f9-8427-4f29-a5eb-c325b062bd6d&ssk=support@shieldsquare.com&ssm=59010847050098640106608108614477&ssn=4a6bf586284f81d536ec05c98ef8e0d5d5e5b481c774-ba90-45d3-9803a0&sso=680844f0-fa236900423d71879d0ffd476581d5e3bd2292200f8f1a33&ssp=21511302441654629287165466755853524&ssq=92049002951518428801829515973425705235401&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-5-3021&id=450594
# https://diabetes.jmir.org/2021/2/e26909
# https://www.xiahepublishing.com/2310-8819/JCTH-2020-00184
# https://validate.perfdrive.com/?ssa=08ae7731-e46c-45ab-a652-37cadb474242&ssb=08901254180&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fabf772&ssi=a2d99ff6-8427-4a3e-ac1e-c703e3b882b9&ssk=support@shieldsquare.com&ssm=86080484586668345102654823661814&ssn=d407b4098fc48f183801f8d475bd76ce635a47f935ef-e5c5-4c42-a6a5c9&sso=5403a4bf-c962cc2feb0b4d34c1442081b474da6f1b8896de75a3f34e&ssp=65384029781654635141165464070788371&ssq=49599312954042087107829540288230049612934&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=
# https://pubs.rsna.org/doi/10.1148/ryai.2021200229
# https://pubs.rsna.org/doi/10.1148/ryai.2021200260
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10600\2064208209.py in <module>
#       6
#       7     try:
# ----> 8         driver.get(url)
#       9         link = driver.current_url
#      10         driver.quit()
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     421
#     422         params = self._wrap_value(params)
# --> 423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
#     425             self.error_handler.check_response(response)
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     331         data = utils.dump_json(params)
#     332         url = f"{self._url}{path}"
# --> 333         return self._request(command_info[0], url, body=data)
#     334
#     335     def _request(self, method, url, body=None):
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     353
#     354         if self.keep_alive:
# --> 355             resp = self._conn.request(method, url, body=body, headers=headers)
#     356             statuscode = resp.status
#     357         else:
#
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\anaconda3\envs\scraper\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\anaconda3\envs\scraper\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\anaconda3\envs\scraper\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\anaconda3\envs\scraper\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\anaconda3\envs\scraper\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
scrape_list
# Out:
# ['https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12264',
#  'https://iopscience.iop.org/article/10.1088/1361-6560/ac4316',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/trc2.12229',
#  'https://journals.sagepub.com/doi/10.1177/03009858211067478',
#  'https://onlinelibrary.wiley.com/doi/10.1002/emp2.12595',
#  'https://ieeexplore.ieee.org/document/9663415',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ejn.15537',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cnm.3559',
#  'https://www.sciendo.com/article/10.2478/joeb-2021-0018',
#  'https://www.frontiersin.org/articles/10.3389/fmed.2021.793230/full',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022093',
#  'https://onlinelibrary.wiley.com/doi/10.1002/clc.23762',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cns.13773',
#  'https://www.science.org/doi/10.1126/sciadv.abh2724',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13506',
#  'https://www.science.org/doi/10.1126/sciadv.abl4146',
#  'https://journals.lww.com/jcnjournal/Abstract/9000/The_Utility_of_Nursing_Notes_Among_Medicare.99142.aspx',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-13-1-426&id=466261',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jocn.16182',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022090',
#  'https://onlinelibrary.wiley.com/doi/10.1002/path.5858',
#  'https://www.hindawi.com/journals/jhe/2021/1302989/',
#  'https://peerj.com/articles/12572/',
#  'https://www.spiedigitallibrary.org/journals/journal-of-medical-imaging/volume-8/issue-06/067501/Deep-learning-segmentation-of-glomeruli-on-kidney-donor-frozen-sections/10.1117/1.JMI.8.6.067501.full?SSO=1',
#  'https://journals.lww.com/apjoo/Abstract/9000/Validation_of_Soft_Labels_in_Developing_Deep.99655.aspx',
#  'https://link.springer.com/article/10.1007/s11548-021-02539-2',
#  'http://ies.ijo.cn/gjyken/ch/reader/view_abstract.aspx?file_no=20211213&flag=1',
#  'https://www.hindawi.com/journals/jhe/2021/4272411/',
#  'http://ies.ijo.cn/gjyken/ch/reader/view_abstract.aspx?file_no=20211220&flag=1',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmri.27978',
#  'https://journals.lww.com/jaaos/Fulltext/2022/02010/Supervised_Machine_Learning_for_Predicting_Length.6.aspx',
#  'https://www.sciencedirect.com/science/article/pii/S1051044321015839?via%3Dihub',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25748',
#  'https://peerj.com/articles/cs-751/',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022081',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022080',
#  'https://journals.sagepub.com/doi/10.1177/0272989X211064604',
#  'https://onlinelibrary.wiley.com/doi/10.1111/acps.13388',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cas.15217',
#  'https://onlinelibrary.wiley.com/doi/10.1002/acr.24834',
#  'https://journals.sagepub.com/doi/10.1177/21514593211062277',
#  'https://www.liebertpub.com/doi/10.1089/heq.2021.0079',
#  'https://peerj.com/articles/cs-806/',
#  'https://www.tandfonline.com/doi/full/10.1080/17538157.2021.2007930',
#  'https://www.tandfonline.com/doi/full/10.1080/10543406.2021.2009500',
#  'https://academic.oup.com/mr/advance-article-abstract/doi/10.1093/mr/roab124/6458437?redirectedFrom=fulltext',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1753-0407.13241',
#  'https://ascpt.onlinelibrary.wiley.com/doi/10.1002/psp4.12740',
#  'https://ieeexplore.ieee.org/document/9622235',
#  'https://academic.oup.com/braincomms/article/4/2/fcab284/6456301',
#  'https://journals.sagepub.com/doi/10.1177/1759720X211059614',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15361',
#  'https://medinform.jmir.org/2021/12/e25022',
#  'https://www.mdpi.com/1424-8220/21/24/8174',
#  'https://www.researchprotocols.org/2021/12/e29563',
#  'https://www.mdpi.com/2227-9032/9/12/1695',
#  'https://www.hindawi.com/journals/jhe/2021/1336762/',
#  'https://www.mdpi.com/2072-6694/13/23/6138',
#  'https://www.mdpi.com/1424-8220/21/23/8157',
#  'https://www.hindawi.com/journals/dm/2021/8668978/',
#  'https://www.mdpi.com/2227-9032/9/12/1687',
#  'https://www.mdpi.com/1424-8220/21/23/8142',
#  'https://www.mdpi.com/2079-6374/11/12/499',
#  'https://www.mdpi.com/1424-8220/21/23/8131',
#  'https://onlinelibrary.wiley.com/doi/10.1002/path.5828',
#  'https://www.mdpi.com/2072-6694/13/23/6113',
#  'https://medinform.jmir.org/2022/3/e32949',
#  'https://www.mdpi.com/1660-4601/18/23/12807',
#  'https://www.mdpi.com/1660-4601/18/23/12806',
#  'https://www.mdpi.com/1424-8220/21/23/8118',
#  'https://www.sciencedirect.com/science/article/pii/S1877050921021220?via%3Dihub',
#  'https://www.tandfonline.com/doi/full/10.1080/00325481.2021.2003150',
#  'https://www.mdpi.com/1424-8220/21/23/8091',
#  'https://www.mdpi.com/2075-4418/11/12/2264',
#  'https://www.mdpi.com/2075-4426/11/12/1288',
#  'https://www.mdpi.com/1660-4601/18/23/12772',
#  'https://www.mdpi.com/2075-4418/11/12/2267',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022060',
#  'https://www.mdpi.com/1424-8220/21/23/8095',
#  'https://www.mdpi.com/1424-8220/21/23/8099',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4465',
#  'https://formative.jmir.org/2021/12/e23440',
#  'https://medinform.jmir.org/2021/12/e22798',
#  'https://www.mdpi.com/2077-0383/10/23/5688',
#  'https://www.mdpi.com/2075-4418/11/12/2257',
#  'https://www.mdpi.com/2306-7381/8/12/301',
#  'https://mhealth.jmir.org/2021/12/e27024',
#  'https://www.mdpi.com/2073-4425/12/12/1946',
#  'https://www.researchprotocols.org/2021/12/e30304',
#  'https://www.mdpi.com/1424-8220/21/23/8025',
#  'https://www.mdpi.com/2072-6694/13/23/6054',
#  'https://www.mdpi.com/2304-6767/9/12/141',
#  'https://www.mdpi.com/2072-6694/13/23/6065',
#  'https://onlinelibrary.wiley.com/doi/10.1111/aos.15071',
#  'https://www.mdpi.com/2313-433X/7/12/258',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15362',
#  'https://aacrjournals.org/cancerres/article/82/2/334/675486/Prostate-Cancer-Risk-Stratification-via',
#  'https://pubs.rsna.org/doi/10.1148/ryai.210026',
#  'https://www.mdpi.com/2075-4426/11/12/1268',
#  'https://www.mdpi.com/2072-6694/13/23/6048',
#  'https://www.mdpi.com/2075-4426/11/12/1271',
#  'https://validate.perfdrive.com/?ssa=fb28bf3a-b4ad-45b8-aa14-2de66f6f1f27&ssb=46128236063&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac387f&ssi=6a2e8f33-8427-4220-a847-952d0eee6721&ssk=support@shieldsquare.com&ssm=68583038005381642104901317532902&ssn=3af34020a64de85bac4fdfb59f9c997015fcc3bbcb9e-73dd-4ca5-ae3afc&sso=82bf8d73-5acc016d0a65779b14df966a050f667cc53a4ddea806c260&ssp=12007327841654696443165469053897514&ssq=34183342381288738072023812702484268286203&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://journals.sagepub.com/doi/10.1177/0271678X211063802',
#  'https://www.dovepress.com/supervised-learning-based-systemic-inflammatory-markers-enable-accurat-peer-reviewed-fulltext-article-CMAR',
#  'https://www.mdpi.com/2075-4418/11/12/2242',
#  'https://www.tandfonline.com/doi/full/10.1080/14767058.2021.2005573',
#  'https://www.mdpi.com/1424-8220/21/23/8007',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022055',
#  'https://onlinelibrary.wiley.com/doi/10.1002/acr2.11352',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jch.14397',
#  'https://www.mdpi.com/1660-4601/18/23/12652',
#  'https://www.mdpi.com/1424-8220/21/23/7996',
#  'https://www.mdpi.com/1660-4601/18/23/12649',
#  'https://www.mdpi.com/1424-8220/21/23/7975',
#  'https://www.mdpi.com/1660-4601/18/23/12586',
#  'https://journals.sagepub.com/doi/10.1177/20552076211060659',
#  'https://www.mdpi.com/2218-273X/11/12/1786',
#  'http://aboonline.org.br/previous-numbers',
#  'https://www.mdpi.com/2072-6694/13/23/6002',
#  'https://journals.sagepub.com/doi/10.1177/17562848211054710',
#  'https://www.mdpi.com/2072-6694/13/23/6013',
#  'https://www.jphres.org/index.php/jphres/article/view/2601',
#  'https://www.mdpi.com/2073-4409/10/12/3353',
#  'https://www.mdpi.com/2072-666X/12/12/1473',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ocr.12542',
#  'https://www.mdpi.com/1424-8220/21/23/7972',
#  'https://www.mdpi.com/2306-5354/8/12/193',
#  'https://www.sciencedirect.com/science/article/abs/pii/S1064748121005509?via%3Dihub',
#  'https://www.mdpi.com/1424-8220/21/23/7942',
#  'https://www.mdpi.com/1424-8220/21/23/7943',
#  'https://onlinelibrary.wiley.com/doi/10.1111/all.15192',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4460',
#  'https://www.mdpi.com/1660-4601/18/23/12499',
#  'https://www.mdpi.com/2075-1729/11/12/1305',
#  'https://www.mdpi.com/1424-8220/21/23/7916',
#  'https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/htl2.12018',
#  'https://www.jmir.org/2021/11/e32900',
#  'https://www.mdpi.com/2227-9059/9/12/1771',
#  'https://www.nature.com/articles/s41588-021-00962-4',
#  'https://www.mdpi.com/1424-8220/21/23/7877',
#  'https://www.mdpi.com/1424-8220/21/23/7864',
#  'https://www.mdpi.com/2073-4409/10/12/3318',
#  'https://www.mdpi.com/2075-4418/11/12/2208',
#  'https://www.mdpi.com/2075-4418/11/12/2209',
#  'https://www.mdpi.com/2075-4418/11/12/2212',
#  'https://www.mdpi.com/1424-8220/21/23/7851',
#  'https://medinform.jmir.org/2021/11/e26456',
#  'https://www.mdpi.com/2075-4418/11/12/2200',
#  'https://www.mdpi.com/2075-4418/11/12/2197',
#  'https://www.mdpi.com/2227-9032/9/12/1632',
#  'https://onlinelibrary.wiley.com/doi/10.1002/lary.29960',
#  'https://www.mdpi.com/2072-6694/13/23/5916',
#  'https://www.mdpi.com/2076-3425/11/12/1555',
#  'https://www.mdpi.com/1424-8220/21/23/7815',
#  'https://www.mdpi.com/2075-4426/11/12/1248',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7790&id=465393',
#  'https://pubs.rsna.org/doi/10.1148/ryai.210085',
#  'https://journals.sagepub.com/doi/10.1177/17562864211060029',
#  'https://journals.sagepub.com/doi/10.1177/23259671211046916',
#  'https://www.mdpi.com/2075-4418/11/12/2184',
#  'https://www.mdpi.com/1660-4601/18/23/12355',
#  'https://onlinelibrary.wiley.com/doi/10.1002/path.5819',
#  'https://onlinelibrary.wiley.com/doi/10.1111/iwj.13723',
#  'https://www.nature.com/articles/s41374-021-00689-0',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.14246',
#  'https://journals.sagepub.com/doi/10.1177/23259671211053326',
#  'https://onlinelibrary.wiley.com/doi/10.1002/art.41899',
#  'https://www.mdpi.com/2077-0383/10/23/5470',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13724',
#  'https://onlinelibrary.wiley.com/doi/10.1111/add.15730',
#  'https://www.mdpi.com/1424-8220/21/23/7782',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15327',
#  'https://www.mdpi.com/2077-0383/10/23/5481',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4441',
#  'https://www.tandfonline.com/doi/full/10.1080/20018525.2021.2004664',
#  'https://www.mdpi.com/1424-8220/21/23/7784',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7765&id=465384',
#  'https://onlinelibrary.wiley.com/doi/10.1111/apm.13190',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcla.24122',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13470',
#  'https://www.mdpi.com/2077-0383/10/22/5450',
#  'https://www.mdpi.com/2075-1729/11/11/1281',
#  'https://onlinelibrary.wiley.com/doi/10.1002/aur.2636',
#  'https://www.nature.com/articles/s41598-021-01913-z',
#  'https://www.mdpi.com/1424-8220/21/22/7751',
#  'https://onlinelibrary.wiley.com/doi/10.1111/epi.17127',
#  'https://www.mdpi.com/2075-4418/11/11/2150',
#  'https://www.mdpi.com/1660-4601/18/22/12191',
#  'https://www.mdpi.com/2227-9032/9/11/1596',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7732&id=465007',
#  'https://link.springer.com/article/10.1007/s00401-021-02386-0',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cpe.6725',
#  'https://www.mdpi.com/1424-8220/21/22/7709',
#  'https://www.mdpi.com/2075-4418/11/11/2147',
#  'https://www.jmir.org/2021/11/e29554',
#  'https://www.science.org/doi/10.1126/sciadv.abj0852',
#  'https://www.mdpi.com/1424-8220/21/22/7710',
#  'https://www.mdpi.com/2077-0383/10/22/5400',
#  'https://peerj.com/articles/cs-764/',
#  'https://mhealth.jmir.org/2021/11/e27674',
#  'https://www.mdpi.com/2077-0383/10/22/5399',
#  'https://medinform.jmir.org/2021/11/e30079',
#  'https://www.mdpi.com/1660-4601/18/22/12175',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cns.13758',
#  'https://www.mdpi.com/2072-6694/13/22/5787',
#  'https://www.mdpi.com/2227-9032/9/11/1579',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jocs.16076',
#  'https://medinform.jmir.org/2021/11/e30066',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022028',
#  'https://www.mdpi.com/2075-4418/11/11/2131',
#  'https://www.frontiersin.org/articles/10.3389/fneur.2021.745475/full',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ijc.33860',
#  'https://www.mdpi.com/2072-6694/13/22/5761',
#  'https://www.frontiersin.org/articles/10.3389/fonc.2021.774248/full',
#  'https://journals.asm.org/doi/10.1128/Spectrum.00802-21',
#  'https://www.mdpi.com/2075-4418/11/11/2133',
#  'https://journals.physiology.org/doi/full/10.1152/jn.00220.2021',
#  'https://www.mdpi.com/1424-8220/21/22/7634',
#  'https://www.mdpi.com/1424-8220/21/22/7628',
#  'https://www.mdpi.com/1424-8220/21/22/7602',
#  'https://www.mdpi.com/2075-4426/11/11/1213',
#  'https://www.mdpi.com/1099-4300/23/11/1522',
#  'https://www.mdpi.com/2072-6694/13/22/5731',
#  'https://onlinelibrary.wiley.com/doi/10.1111/his.14571',
#  'https://pubs.acs.org/doi/10.1021/acs.jproteome.1c00525',
#  'https://www.frontiersin.org/articles/10.3389/fmed.2021.694520/full',
#  'https://www.mdpi.com/1660-4601/18/22/12013',
#  'https://www.mdpi.com/2077-0383/10/22/5326',
#  'https://www.mdpi.com/2077-0383/10/22/5330',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15333',
#  'https://www.frontiersin.org/articles/10.3389/fnsys.2021.716897/full',
#  'https://www.frontiersin.org/articles/10.3389/fbioe.2021.761548/full',
#  'https://www.mdpi.com/1424-8220/21/22/7584',
#  'https://www.mdpi.com/2079-7737/10/11/1185',
#  'https://www.mdpi.com/2075-4418/11/11/2119',
#  'https://www.mdpi.com/1424-8220/21/22/7574',
#  'https://www.mdpi.com/2075-4418/11/11/2109',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022017',
#  'https://www.mdpi.com/2079-6374/11/11/453',
#  'https://www.mdpi.com/2075-4418/11/11/2102',
#  'https://www.mdpi.com/2079-7737/10/11/1174',
#  'https://www.mdpi.com/1424-8220/21/22/7553',
#  'https://www.mdpi.com/2075-4418/11/11/2103',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jsp2.1178',
#  'https://www.mdpi.com/1424-8220/21/22/7540',
#  'https://www.mdpi.com/1424-8220/21/22/7510',
#  'https://www.mdpi.com/2075-4418/11/11/2091',
#  'https://pubs.acs.org/doi/10.1021/acsomega.1c04204',
#  'https://www.mdpi.com/1424-8220/21/22/7521',
#  'https://www.mdpi.com/1424-8220/21/22/7528',
#  'https://www.mdpi.com/1424-8220/21/22/7517',
#  'https://academic.oup.com/comnet/article/9/6/cnab039/6426106',
#  'https://www.mdpi.com/2072-6694/13/22/5670',
#  'https://www.frontiersin.org/articles/10.3389/fgene.2021.784814/full',
#  'https://obgyn.onlinelibrary.wiley.com/doi/10.1002/uog.24810',
#  'https://www.mdpi.com/1424-8220/21/22/7500',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7500&id=464782',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cas.15173',
#  'https://www.mdpi.com/2077-0383/10/22/5244',
#  'https://www.mdpi.com/1648-9144/57/11/1230',
#  'https://www.mdpi.com/2075-4418/11/11/2086',
#  'https://www.mdpi.com/1660-4601/18/22/11816',
#  'https://www.hindawi.com/journals/cin/2021/5478157/',
#  'https://www.mdpi.com/1424-8220/21/22/7473',
#  'https://www.mdpi.com/1424-8220/21/22/7458',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021210015',
#  'https://ieeexplore.ieee.org/document/9599660',
#  'https://www.mdpi.com/2306-5354/8/11/181',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021210211',
#  'https://www.mdpi.com/1424-8220/21/22/7480',
#  'https://formative.jmir.org/2021/11/e30313',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200152',
#  'https://medinform.jmir.org/2021/11/e30277',
#  'https://www.mdpi.com/2072-6643/13/11/4009',
#  'https://journals.asm.org/doi/10.1128/Spectrum.00913-21',
#  'https://onlinelibrary.wiley.com/doi/10.1111/his.14574',
#  'https://www.mdpi.com/2075-4426/11/11/1163',
#  'https://www.mdpi.com/2072-6694/13/22/5600',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-12-7434&id=464725',
#  'http://www.aimspress.com/article/doi/10.3934/mbe.2022007',
#  'https://www.futuremedicine.com/doi/10.2217/fon-2021-0522',
#  'https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e282',
#  'https://www.hindawi.com/journals/ccrp/2021/6672603/',
#  'https://onlinelibrary.wiley.com/doi/10.1111/den.14187',
#  'https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/lt.26318',
#  'https://www.jmir.org/2021/11/e28999',
#  'https://onlinelibrary.wiley.com/doi/10.1111/opo.12909',
#  'https://journals.sagepub.com/doi/10.1177/23259671211050613',
#  'https://onlinelibrary.wiley.com/doi/10.1002/art.41885',
#  'https://www.jmir.org/2021/11/e27875',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4383',
#  'https://www.mdpi.com/2075-4418/11/11/2025',
#  'https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/hep4.1846',
#  'https://dnd.or.kr/DOIx.php?id=10.12779/dnd.2021.20.4.70',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15303',
#  'https://www.hindawi.com/journals/jhe/2021/6024352/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cjp2.249',
#  'https://www.mdpi.com/1424-8220/21/21/7199',
#  'https://ieeexplore.ieee.org/document/9570384',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.14140',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15295',
#  'https://beva.onlinelibrary.wiley.com/doi/10.1111/evj.13528',
#  'https://journals.sagepub.com/doi/10.1177/24715492211038172',
#  'https://www.dovepress.com/health-data-driven-machine-learning-algorithms-applied-to-risk-indicat-peer-reviewed-fulltext-article-RMHP',
#  'https://journals.lww.com/ctg/Fulltext/2021/11000/Automatic_Identification_of_Papillary_Projections.1.aspx',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021210027',
#  'https://www.dovepress.com/machine-learning-analysis-reveals-abnormal-static-and-dynamic-low-freq-peer-reviewed-fulltext-article-JPR',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25695',
#  'https://www.hindawi.com/journals/jhe/2021/6382619/',
#  'https://www.hindawi.com/journals/cmmm/2021/4622064/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcsm.12840',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15217',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15282',
#  'https://mhealth.jmir.org/2021/10/e24872',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1475-6773.13896',
#  'https://www.mdpi.com/1424-8220/21/21/7036',
#  'https://www.researchprotocols.org/2021/10/e26816',
#  'https://onlinelibrary.wiley.com/doi/10.1002/path.5800',
#  'https://www.mdpi.com/2075-4426/11/11/1062',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ane.13541',
#  'https://www.mdpi.com/2079-7737/10/11/1083',
#  'https://journals.sagepub.com/doi/10.1177/17562848211053114',
#  'https://validate.perfdrive.com/?ssa=eeb6b5aa-ae5f-48dc-b97a-86aef063fe3b&ssb=45858286181&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1752-7163%2Fac2e57&ssi=f594920a-8427-4df6-8e5b-e8b24eb6ec93&ssk=support@shieldsquare.com&ssm=23958565776720790105859548476090&ssn=779ea6ce161788bfa167c9d13b85b39cd0daddd96774-2f39-4b41-8aba53&sso=8a1f894c-bae54916708e9503e42ad090f27e6c347b4ee867362b03ae&ssp=77268361441654619087165462709568295&ssq=66421062513642717239125136636773635764717&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://medinform.jmir.org/2021/10/e28039',
#  'https://onlinelibrary.wiley.com/doi/10.1002/oca.2806',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcla.24053',
#  'https://www.mdpi.com/2075-4418/11/11/1943',
#  'https://www.jmssjournal.net/article.asp?issn=2228-7477;year=2021;volume=11;issue=4;spage=237;epage=252;aulast=Mutepfe',
#  'https://journals.physiology.org/doi/full/10.1152/ajplung.00198.2021',
#  'https://rehab.jmir.org/2021/4/e29769',
#  'https://onlinelibrary.wiley.com/doi/10.1002/mrm.29016',
#  'https://www.jmir.org/2021/10/e26486',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jocs.16059',
#  'https://ieeexplore.ieee.org/document/9570807',
#  'https://www.jmir.org/2021/10/e26305',
#  'https://onlinelibrary.wiley.com/doi/10.1111/exsy.12823',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/10000/Simplified_Pediatric_Index_of_Mortality_3_Score_by.21.aspx',
#  'https://onlinelibrary.wiley.com/doi/10.1111/aos.15040',
#  'https://physoc.onlinelibrary.wiley.com/doi/10.1113/JP281845',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jdv.17711',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-11-6969&id=460679',
#  'https://www.jmir.org/2021/10/e24072',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ijcp.14961',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25679',
#  'https://www.jmir.org/2021/10/e18403',
#  'https://www.mdpi.com/2076-2607/9/10/2149',
#  'https://journals.sagepub.com/doi/10.1177/23259671211046575',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmv.27393',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/trc2.12212',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12246',
#  'https://onlinelibrary.wiley.com/doi/10.1002/aur.2626',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ijpo.12859',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13440',
#  'https://www.mdpi.com/1660-4601/18/20/10670',
#  'https://www.mdpi.com/2072-6694/13/20/5109',
#  'https://www.mdpi.com/2072-6694/13/20/5110',
#  'https://www.hindawi.com/journals/jo/2021/1629318/',
#  'https://www.liebertpub.com/doi/10.1089/wound.2021.0073',
#  'https://www.mdpi.com/2075-4418/11/10/1870',
#  'https://onlinelibrary.wiley.com/doi/10.1002/aur.2622',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jclp.23254',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22659',
#  'https://www.mdpi.com/1660-4601/18/20/10603',
#  'https://www.mdpi.com/2075-4418/11/10/1859',
#  'https://www.mdpi.com/1424-8220/21/20/6708',
#  'https://www.mdpi.com/2072-6694/13/20/5047',
#  'https://www.mdpi.com/1422-0067/22/20/10903',
#  'https://www.mdpi.com/1424-8220/21/20/6714',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25680',
#  'https://www.mdpi.com/1424-8220/21/19/6682',
#  'https://www.mdpi.com/1660-4601/18/19/10540',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13446',
#  'https://www.cambridge.org/core/journals/public-health-nutrition/article/machine-learning-algorithms-for-predicting-undernutrition-among-underfive-children-in-ethiopia/6F72A5F339564946C2E16B27270849A8',
#  'https://www.mdpi.com/2075-4418/11/10/1856',
#  'https://www.hindawi.com/journals/jhe/2021/4405189/',
#  'https://www.mdpi.com/1424-8220/21/19/6653',
#  'https://www.mdpi.com/2075-4426/11/10/1008',
#  'https://www.mdpi.com/1424-8220/21/19/6672',
#  'https://www.mdpi.com/1424-8220/21/19/6652',
#  'https://journals.sagepub.com/doi/10.1177/20556683211044640',
#  'https://www.mdpi.com/2227-9032/9/10/1334',
#  'https://www.mdpi.com/2075-1729/11/10/1052',
#  'https://www.mdpi.com/1660-4601/18/19/10481',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200232',
#  'https://www.mdpi.com/2075-4418/11/10/1844',
#  'https://movementdisorders.onlinelibrary.wiley.com/doi/10.1002/mds.28814',
#  'https://link.springer.com/article/10.1007/s11282-021-00572-0',
#  'https://www.mdpi.com/2076-3425/11/10/1321',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13647',
#  'https://onlinelibrary.wiley.com/doi/10.1111/bpa.13023',
#  'https://www.hindawi.com/journals/cmmm/2021/3890988/',
#  'https://www.mdpi.com/2072-6694/13/19/4976',
#  'https://www.mdpi.com/2306-5354/8/10/138',
#  'https://www.nature.com/articles/s41374-021-00647-w',
#  'https://www.mdpi.com/2077-0383/10/19/4576',
#  'https://www.mdpi.com/2075-4418/11/10/1824',
#  'https://www.mdpi.com/1424-8220/21/19/6597',
#  'https://www.mdpi.com/1660-4601/18/19/10391',
#  'https://www.mdpi.com/1424-8220/21/19/6595',
#  'https://www.mdpi.com/2227-9059/9/10/1377',
#  'https://www.hindawi.com/journals/bmri/2021/2567202/',
#  'https://kjronline.org/DOIx.php?id=10.3348/kjr.2020.1468',
#  'https://www.mdpi.com/2072-6694/13/19/4961',
#  'https://onlinelibrary.wiley.com/doi/10.1002/acr.24795',
#  'https://www.mdpi.com/1660-4601/18/19/10357',
#  'https://academic.oup.com/mr/advance-article-abstract/doi/10.1093/mr/roab073/6378620?redirectedFrom=fulltext',
#  'https://medinform.jmir.org/2021/10/e27177',
#  'https://www.mdpi.com/1424-8220/21/19/6584',
#  'https://www.mdpi.com/1424-8220/21/19/6559',
#  'https://www.mdpi.com/1424-8220/21/19/6558',
#  'https://www.mdpi.com/2075-4418/11/10/1812',
#  'https://www.mdpi.com/1424-8220/21/19/6570',
#  'https://www.mdpi.com/2075-4426/11/10/991',
#  'https://www.mdpi.com/2072-6694/13/19/4938',
#  'https://www.mdpi.com/2227-9032/9/10/1306',
#  'https://www.mdpi.com/2072-6694/13/19/4919',
#  'https://formative.jmir.org/2021/9/e28000',
#  'https://validate.perfdrive.com/?ssa=32751185-fd14-4edb-9436-2f6f491eb937&ssb=18023224515&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac23bf&ssi=810f66f4-8427-4d76-9e1b-60cdaeb1ec7d&ssk=support@shieldsquare.com&ssm=00466896854720562107681286218675&ssn=d8710440256b6efa493fdb94c38a6e64d4b7e1b21ba7-54ec-401d-b6f7ee&sso=9d650a9d-69a7d745cdbb012c2f389e249a47c3cfb9fbc448ba9fe46a&ssp=73506356731654640440165460793241138&ssq=06827092569774577049725697313227629615323&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.mdpi.com/1424-8220/21/19/6566',
#  'https://www.mdpi.com/2075-4418/11/10/1810',
#  'https://www.mdpi.com/2076-3425/11/10/1297',
#  'https://www.mdpi.com/1424-8220/21/19/6511',
#  'https://www.mdpi.com/2077-0383/10/19/4488',
#  'https://www.mdpi.com/1424-8220/21/19/6513',
#  'https://peerj.com/articles/cs-638/',
#  'https://journals.lww.com/corneajrnl/Fulltext/2022/05000/Deep_Learning_for_Discrimination_Between_Fungal.13.aspx',
#  'https://www.mdpi.com/2075-4426/11/10/981',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25656',
#  'https://www.mdpi.com/2227-9059/9/10/1357',
#  'https://www.mdpi.com/2073-4409/10/10/2587',
#  'https://www.mdpi.com/1424-8220/21/19/6503',
#  'https://www.mdpi.com/2075-4426/11/10/978',
#  'https://www.mdpi.com/2077-0383/10/19/4508',
#  'https://onlinelibrary.wiley.com/doi/10.1111/exsy.12842',
#  'https://www.mdpi.com/2075-4418/11/10/1806',
#  'https://www.tandfonline.com/doi/full/10.1080/02813432.2021.1973255',
#  'https://www.mdpi.com/2072-6694/13/19/4875',
#  'https://www.mdpi.com/2072-6694/13/19/4907',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200274',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/10000/Estimated_Pao2__A_Continuous_and_Noninvasive.5.aspx',
#  'https://www.mdpi.com/2075-4418/11/10/1787',
#  'https://www.mdpi.com/1424-8220/21/19/6481',
#  'https://www.jhrsonline.org/article.asp?issn=0974-1208;year=2021;volume=14;issue=3;spage=288;epage=292;aulast=Geller',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13627',
#  'https://www.mdpi.com/1424-8220/21/19/6485',
#  'https://www.mdpi.com/2077-0383/10/19/4479',
#  'https://www.mdpi.com/1424-8220/21/19/6484',
#  'https://www.mdpi.com/2075-4418/11/10/1784',
#  'https://www.mdpi.com/2075-4418/11/10/1785',
#  'https://www.mdpi.com/2072-6694/13/19/4837',
#  'https://www.mdpi.com/1660-4601/18/19/10150',
#  'https://www.mdpi.com/2077-0383/10/19/4437',
#  'https://www.mdpi.com/1660-4601/18/19/10147',
#  'https://validate.perfdrive.com/?ssa=b7581cc8-8c5f-4c99-a22b-bbcf99a8f0b1&ssb=27414288652&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6579%2Fac2264&ssi=7aa81504-8427-4e9f-9ec1-414de9147c02&ssk=support@shieldsquare.com&ssm=23605924508097335104928297787681&ssn=063e1424ba3ebf33a81a5a7f6b69c61f5e82380fdda9-7daa-459b-8efe41&sso=fbbe76b7-02d75aa2284e7267b92d4e359b1cf3c67dbb4eabafffa3da&ssp=46114277251654646178165467991239476&ssq=23902552588147290686125881953433070089799&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.mdpi.com/1424-8220/21/19/6451',
#  'https://www.mdpi.com/1424-8220/21/19/6459',
#  'https://www.mdpi.com/2077-0383/10/19/4431',
#  'https://www.mdpi.com/1424-8220/21/19/6446',
#  'https://journals.lww.com/transplantationdirect/Fulltext/2021/10000/Machine_Learning_Prediction_of_Liver_Allograft.26.aspx',
#  'https://www.mdpi.com/2077-0383/10/19/4441',
#  'https://www.mdpi.com/2075-4418/11/10/1773',
#  'https://www.mdpi.com/2077-0383/10/19/4393',
#  'https://www.mdpi.com/2077-0383/10/19/4394',
#  'https://www.mdpi.com/2075-4418/11/10/1767',
#  'https://www.mdpi.com/2076-2615/11/10/2806',
#  'https://www.mdpi.com/2075-1729/11/10/1013',
#  'https://www.mdpi.com/1099-4300/23/10/1251',
#  'https://www.mdpi.com/2227-9059/9/10/1319',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15231',
#  'https://www.mdpi.com/2073-4409/10/10/2539',
#  'https://www.mdpi.com/1424-8220/21/19/6401',
#  'https://www.mdpi.com/1424-8220/21/19/6412',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmv.27352',
#  'https://www.mdpi.com/1099-4300/23/10/1248',
#  'https://www.tandfonline.com/doi/full/10.1080/21681805.2021.1977845',
#  'https://www.mdpi.com/1424-8220/21/19/6393',
#  'https://www.mdpi.com/1660-4601/18/19/10048',
#  'https://www.mdpi.com/1422-0067/22/19/10291',
#  'https://www.mdpi.com/2075-4418/11/10/1759',
#  'https://www.tandfonline.com/doi/full/10.1080/20008198.2021.1958471',
#  'https://www.mdpi.com/1424-8220/21/19/6369',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6529&id=459854',
#  'https://www.mdpi.com/2076-3425/11/10/1262',
#  'https://www.mdpi.com/2077-0383/10/19/4354',
#  'https://www.mdpi.com/2075-4418/11/10/1747',
#  'https://www.mdpi.com/2072-6694/13/19/4751',
#  'https://www.tandfonline.com/doi/full/10.1080/0284186X.2021.1979645',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcla.24018',
#  'https://onlinelibrary.wiley.com/doi/10.1002/art.41781',
#  'https://journals.lww.com/jpho-online/Fulltext/2022/04000/Can_Machine_Learning_Models_Predict.14.aspx',
#  'https://www.mdpi.com/1648-9144/57/10/996',
#  'https://www.futuremedicine.com/doi/10.2217/nnm-2021-0076',
#  'https://ieeexplore.ieee.org/document/9543467',
#  'https://www.mdpi.com/1424-8220/21/18/6311',
#  'https://www.mdpi.com/1424-8220/21/18/6323',
#  'https://www.jmir.org/2021/9/e26025',
#  'https://www.mdpi.com/2075-4418/11/9/1735',
#  'https://link.springer.com/chapter/10.1007/978-3-030-87202-1_44',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ijlh.13681',
#  'https://www.mdpi.com/2075-4418/11/9/1732',
#  'https://www.hindawi.com/journals/cin/2021/8439655/',
#  'https://asbmr.onlinelibrary.wiley.com/doi/10.1002/jbm4.10549',
#  'https://www.mdpi.com/2077-0383/10/18/4281',
#  'https://www.mdpi.com/2077-0383/10/18/4263',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6422&id=459635',
#  'https://www.mdpi.com/2075-4418/11/9/1725',
#  'https://www.mdpi.com/1099-4300/23/9/1232',
#  'https://www.mdpi.com/1424-8220/21/18/6291',
#  'https://www.mdpi.com/1660-4601/18/18/9873',
#  'https://www.mdpi.com/2075-4418/11/9/1714',
#  'https://www.mdpi.com/2075-4418/11/9/1718',
#  'https://www.mdpi.com/2075-4426/11/9/934',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22654',
#  'https://www.mdpi.com/2313-433X/7/9/189',
#  'https://www.mdpi.com/2075-4418/11/9/1712',
#  'https://www.mdpi.com/1424-8220/21/18/6263',
#  'https://www.mdpi.com/1424-8220/21/18/6264',
#  'https://www.mdpi.com/2075-4426/11/9/928',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12227',
#  'https://www.mdpi.com/2077-0383/10/18/4245',
#  'https://www.mdpi.com/1424-8220/21/18/6274',
#  'https://www.mdpi.com/1424-8220/21/18/6246',
#  'https://www.mdpi.com/1424-8220/21/18/6230',
#  'https://www.mdpi.com/2079-6374/11/9/343',
#  'https://www.mdpi.com/1424-8220/21/18/6249',
#  'https://www.mdpi.com/2072-6694/13/18/4674',
#  'https://www.mdpi.com/2072-6694/13/18/4671',
#  'https://www.mdpi.com/1424-8220/21/18/6210',
#  'https://www.mdpi.com/1660-4601/18/18/9768',
#  'https://www.mdpi.com/1424-8220/21/18/6202',
#  'https://www.mdpi.com/1718-7729/28/5/307',
#  'https://www.mdpi.com/2075-4418/11/9/1690',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ags3.12504',
#  'https://peerj.com/articles/cs-671/',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-10-6326&id=458783',
#  'https://www.mdpi.com/1422-0067/22/18/9970',
#  'https://www.mdpi.com/2072-6694/13/18/4635',
#  'https://www.mdpi.com/1424-8220/21/18/6189',
#  'https://www.mdpi.com/2075-4418/11/9/1686',
#  'https://www.mdpi.com/2073-4409/10/9/2430',
#  'https://www.birpublications.org/doi/10.1259/bjr.20210221',
#  'https://formative.jmir.org/2021/9/e28028',
#  'https://www.mdpi.com/2075-4418/11/9/1676',
#  'https://onlinelibrary.wiley.com/doi/10.1111/iwj.13691',
#  'https://www.mdpi.com/2075-4418/11/9/1678',
#  'https://www.mdpi.com/2075-4418/11/9/1677',
#  'https://www.reed.es/Artificial-intelligence-and-capsule-endoscopy-automatic-detection-of-enteric-protruding-lesions-using-a-convolutional-neural-network6036?AspxAutoDetectCookieSupport=1',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25660',
#  'https://www.mdpi.com/1424-8220/21/18/6147',
#  'https://onlinelibrary.wiley.com/doi/10.1111/sltb.12800',
#  'https://www.mdpi.com/2072-6694/13/18/4585',
#  'https://www.jmir.org/2021/9/e27798',
#  'https://www.mdpi.com/2072-6694/13/18/4593',
#  'https://www.mdpi.com/2075-4418/11/9/1672',
#  'https://www.hindawi.com/journals/cmmm/2021/8036304/',
#  'https://www.mdpi.com/2072-6694/13/18/4559',
#  'https://www.mdpi.com/2075-4418/11/9/1664',
#  'https://www.mdpi.com/1648-9144/57/9/956',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jon.12927',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/09000/Explainable_Machine_Learning_on_AmsterdamUMCdb_for.13.aspx',
#  'https://www.mdpi.com/1424-8220/21/18/6049',
#  'https://www.mdpi.com/2075-1729/11/9/940',
#  'https://www.mdpi.com/2073-4360/13/18/3041',
#  'https://www.mdpi.com/1424-8220/21/18/6043',
#  'https://www.mdpi.com/2077-0383/10/18/4074',
#  'https://www.mdpi.com/1424-8220/21/18/6033',
#  'https://www.mdpi.com/2306-5354/8/9/122',
#  'https://www.mdpi.com/2075-4426/11/9/902',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4054',
#  'https://www.mdpi.com/1424-8220/21/18/6008',
#  'https://www.jcvjs.com/article.asp?issn=0974-8237;year=2021;volume=12;issue=3;spage=223;epage=227;aulast=Siemionow',
#  'https://journals.sagepub.com/doi/10.1177/19476035211042406',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jso.26668',
#  'https://www.mdpi.com/2072-6694/13/17/4468',
#  'https://onlinelibrary.wiley.com/doi/10.1111/his.14438',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4261',
#  'https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/nbm.4606',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ajt.16807',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ejn.15423',
#  'https://journals.lww.com/cmj/Fulltext/2021/10050/Development_and_validation_of_a_deep_learning.11.aspx',
#  'https://validate.perfdrive.com/?ssa=218d634c-c9b6-498f-8db5-c896002a96e1&ssb=03483244872&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac1d32&ssi=616b0164-8427-40a6-aad9-c5cfb71918b4&ssk=support@shieldsquare.com&ssm=49481585642023675108851768063385&ssn=e2f70d2408b35ff6418eb1f002c37f8cecefa47e261a-8ed2-4de9-9e5792&sso=f494a2a5-5cef9e3c5eed0446d05e14620840ca14faf69adff61518e3&ssp=10443795411654602672165469207410111&ssq=02435082655284157295426552369173712932890&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.liebertpub.com/doi/10.1089/wound.2021.0073',
#  'https://onlinelibrary.wiley.com/doi/10.1002/iid3.506',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200299',
#  'https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/syb2.12033',
#  'https://www.jehp.net/article.asp?issn=2277-9531;year=2021;volume=10;issue=1;spage=285;epage=285;aulast=Shanbehzadeh',
#  'https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/htl2.12017',
#  'https://www.medicaljournals.se/acta/content/abstract/10.2340/00015555-3893',
#  'https://kjronline.org/DOIx.php?id=10.3348/kjr.2021.0348',
#  'https://www.tandfonline.com/doi/full/10.1080/07391102.2021.1966509',
#  'https://onlinelibrary.wiley.com/doi/10.1111/nan.12759',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ene.15071',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ijcp.14746',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4092',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4230',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15017',
#  'https://link.springer.com/article/10.1007/s10654-021-00797-7',
#  'https://www.mdpi.com/1660-4601/18/17/9091',
#  'https://validate.perfdrive.com/?ssa=18092be7-ed7c-474d-bb7f-9dea93ad20b2&ssb=69994249584&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6560%2Fac176d&ssi=fe19880d-8427-46dd-817b-fee158b4821e&ssk=support@shieldsquare.com&ssm=92545470598580196101000880765807&ssn=f94eee0deac257251477cf3d1735650937f7256a2e1f-6474-4896-b571dc&sso=a3cca505-443b20de503d27eb39b4d1789db20b27094e047e6a197b81&ssp=35446970761654612578165469629901064&ssq=42946172669362637502126693957489322798372&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/jemt.23913',
#  'https://peerj.com/articles/11988/',
#  'https://pubs.asha.org/doi/10.1044/2021_JSLHR-21-00134',
#  'https://onlinelibrary.wiley.com/doi/10.1111/srt.13086',
#  'https://journals.sagepub.com/doi/10.1177/00220345211032524',
#  'https://journals.sagepub.com/doi/10.1177/00034894211041222',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25629',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/08000/Machine_Learning_Prediction_of_Death_in_Critically.18.aspx',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jocs.15917',
#  'https://validate.perfdrive.com/?ssa=d733efc6-c700-4f5f-a734-71e87f6a8e4f&ssb=29558292802&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac1adc&ssi=9a704500-8427-435c-b930-4492b13a0768&ssk=support@shieldsquare.com&ssm=95873137491372695104672279976011&ssn=add7c7c386c206682ffa0044457fe56588542931da31-7844-4a7d-b4b979&sso=79ddcc30-1eb55c9b07dee3fa26061797afaaf3ab5adda933067767f1&ssp=06259170711654639554165466003218240&ssq=32752972676012747189626760084376483129126&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.frontiersin.org/articles/10.3389/fmed.2021.688986/full',
#  'https://www.science.org/doi/10.1126/sciadv.abh0693?cookieSet=1',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5658&id=457264',
#  'https://www.frontiersin.org/articles/10.3389/fped.2021.710720/full',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13556',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5559&id=457142',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25620',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22644',
#  'https://onlinelibrary.wiley.com/doi/10.1111/dmcn.15010',
#  'https://link.springer.com/article/10.1007/s10840-021-01045-4',
#  'https://medinform.jmir.org/2021/8/e28287',
#  'https://journals.sagepub.com/doi/10.1177/07067437211037141',
#  'https://journals.asm.org/doi/10.1128/JCM.00971-21',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200278',
#  'https://www.mdpi.com/2077-0383/10/16/3523',
#  'https://www.mdpi.com/2075-4418/11/8/1449',
#  'https://www.hindawi.com/journals/bmri/2021/1337558/',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15126',
#  'https://link.springer.com/article/10.1007/s10278-021-00500-y',
#  'https://bmcmedimaging.biomedcentral.com/articles/10.1186/s12880-021-00653-w',
#  'https://www.mdpi.com/2072-6694/13/16/4030',
#  'https://www.mdpi.com/1424-8220/21/16/5406',
#  'https://www.mdpi.com/2075-4418/11/8/1446',
#  'https://www.mdpi.com/2075-4418/11/8/1445',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmv.27252',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/08000/Predicting_Future_Care_Requirements_Using_Machine.10.aspx',
#  'https://www.mdpi.com/1424-8220/21/16/5371',
#  'https://www.mdpi.com/1424-8220/21/16/5383',
#  'https://jkms.org/DOIx.php?id=10.3346/jkms.2021.36.e198',
#  'https://www.mdpi.com/1424-8220/21/16/5385',
#  'https://www.mdpi.com/2079-6374/11/8/269',
#  'https://onlinelibrary.wiley.com/doi/10.1002/emp2.12534',
#  'https://www.nature.com/articles/s42256-021-00377-0',
#  'https://www.mdpi.com/2075-4418/11/8/1437',
#  'https://www.mdpi.com/1424-8220/21/16/5381',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmri.27879',
#  'https://www.mdpi.com/1424-8220/21/16/5361',
#  'https://www.mdpi.com/2072-6694/13/16/3998',
#  'https://www.jmp.org.in/article.asp?issn=0971-6203;year=2021;volume=46;issue=2;spage=80;epage=87;aulast=Amarsee',
#  'https://www.mdpi.com/1424-8220/21/16/5334',
#  'https://www.mdpi.com/2075-4418/11/8/1429',
#  'https://www.mdpi.com/2076-3425/11/8/1049',
#  'https://www.mdpi.com/1424-8220/21/16/5327',
#  'https://www.mdpi.com/1424-8220/21/16/5315',
#  'https://onlinelibrary.wiley.com/doi/10.1002/art.41735',
#  'https://www.tandfonline.com/doi/full/10.1080/20002297.2021.1962125',
#  'https://onlinelibrary.wiley.com/doi/10.1002/art.41708',
#  'https://www.mdpi.com/2072-6694/13/16/3976',
#  'https://www.mdpi.com/1424-8220/21/16/5328',
#  'https://www.mdpi.com/1424-8220/21/16/5309',
#  'https://www.mdpi.com/2075-4418/11/8/1416',
#  'https://ieeexplore.ieee.org/document/9336225',
#  'https://www.mdpi.com/1424-8220/21/16/5289',
#  'https://www.mdpi.com/1424-8220/21/16/5302',
#  'https://www.mdpi.com/1424-8220/21/16/5304',
#  'https://www.mdpi.com/2379-139X/7/3/31',
#  'https://www.mdpi.com/1424-8220/21/16/5283',
#  'https://www.mdpi.com/2075-4418/11/8/1409',
#  'https://www.mdpi.com/2075-4418/11/8/1405',
#  'https://www.mdpi.com/1424-8220/21/16/5273',
#  'https://www.mdpi.com/2076-3425/11/8/1037',
#  'https://www.mdpi.com/2313-433X/7/8/131',
#  'https://journals.lww.com/ctg/Fulltext/2021/08000/A_Novel_Deep_Learning_System_for_Diagnosing_Early.7.aspx',
#  'https://www.mdpi.com/1424-8220/21/16/5270',
#  'https://onlinelibrary.wiley.com/doi/10.1002/clc.23687',
#  'https://royalsocietypublishing.org/doi/10.1098/rsif.2021.0284',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-9-5401&id=454003',
#  'https://www.mdpi.com/1424-8220/21/16/5256',
#  'https://www.mdpi.com/1424-8220/21/16/5253',
#  'https://academic.oup.com/oncolo/article/26/10/e1822/6513521',
#  'https://peerj.com/articles/cs-614/',
#  'https://journals.lww.com/ctg/Fulltext/2021/08000/Simultaneous_Recognition_of_Atrophic_Gastritis_and.5.aspx',
#  'https://www.hindawi.com/journals/cin/2021/9996737/',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13381',
#  'https://www.mdpi.com/1424-8220/21/15/5239',
#  'https://www.mdpi.com/2075-4418/11/8/1398',
#  'https://www.mdpi.com/1424-8220/21/15/5236',
#  'https://medscimonit.com/abstract/full/idArt/934171',
#  'https://peerj.com/articles/cs-654/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ajh.26295',
#  'https://www.mdpi.com/2072-6694/13/15/3903',
#  'https://www.mdpi.com/2072-6694/13/15/3891',
#  'https://www.mdpi.com/1424-8220/21/15/5222',
#  'https://www.mdpi.com/2079-9721/9/3/54',
#  'https://www.mdpi.com/2218-1989/11/8/507',
#  'https://dl.acm.org/doi/10.1145/3459930.3469564',
#  'https://www.mdpi.com/1424-8220/21/15/5192',
#  'https://www.mdpi.com/2075-4418/11/8/1385',
#  'https://www.mdpi.com/2075-4418/11/8/1386',
#  'https://www.mdpi.com/1424-8220/21/15/5207',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cea.13993',
#  'https://www.mdpi.com/2227-9032/9/8/971',
#  'https://www.mdpi.com/1424-8220/21/15/5212',
#  'https://www.mdpi.com/2075-4418/11/8/1383',
#  'https://www.mdpi.com/2077-0383/10/15/3398',
#  'https://www.mdpi.com/1424-8220/21/15/5172',
#  'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-021-01450-9',
#  'https://www.dovepress.com/early-prediction-of-covid-19-ventilation-requirement-and-mortality-fro-peer-reviewed-fulltext-article-JMDH',
#  'https://www.mdpi.com/2075-4418/11/8/1380',
#  'https://www.mdpi.com/2072-6694/13/15/3851',
#  'https://www.mdpi.com/1099-4300/23/8/984',
#  'https://journals.sagepub.com/doi/10.1177/01455613211029749',
#  'https://www.frontiersin.org/articles/10.3389/fphys.2021.704122/full',
#  'https://bmjopen.bmj.com/content/11/7/e046716',
#  'https://peerj.com/articles/cs-655/',
#  'https://onlinelibrary.wiley.com/doi/10.1111/exsy.12776',
#  'https://www.mdpi.com/1424-8220/21/15/5135',
#  'https://www.mdpi.com/1424-8220/21/15/5130',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jor.25150',
#  'https://www.mdpi.com/2075-4426/11/8/748',
#  'https://www.mdpi.com/2073-4409/10/8/1930',
#  'https://www.mdpi.com/2379-139X/7/3/27',
#  'https://www.hindawi.com/journals/jhe/2021/2603842/',
#  'https://www.dovepress.com/machine-learning-algorithms-are-superior-to-conventional-regression-mo-peer-reviewed-fulltext-article-RMHP',
#  'https://www.mdpi.com/1660-4601/18/15/8059',
#  'https://www.mdpi.com/1424-8220/21/15/5145',
#  'https://www.hindawi.com/journals/jhe/2021/9687591/',
#  'https://www.mdpi.com/2072-6694/13/15/3811',
#  'https://www.mdpi.com/1660-4601/18/15/8052',
#  'https://onlinelibrary.wiley.com/doi/10.1002/advs.202101333',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25574',
#  'https://www.mdpi.com/2072-6694/13/15/3825',
#  'https://onlinelibrary.wiley.com/doi/10.1002/clc.23688',
#  'https://www.hindawi.com/journals/jhe/2021/1730158/',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-8-5305&id=453796',
#  'https://peerj.com/articles/cs-646/',
#  'https://www.mdpi.com/2075-4426/11/8/739',
#  'https://www.mdpi.com/2072-6694/13/15/3795',
#  'https://www.mdpi.com/2227-9032/9/8/948',
#  'https://www.mdpi.com/1424-8220/21/15/5105',
#  'https://journals.sagepub.com/doi/10.1177/11769351211035137',
#  'https://www.dovepress.com/machine-learning-in-an-elderly-man-with-heart-failure-peer-reviewed-fulltext-article-IMCRJ',
#  'https://www.mdpi.com/2075-4426/11/8/727',
#  'https://www.mdpi.com/2072-6694/13/15/3760',
#  'https://www.mdpi.com/2072-6694/13/15/3768',
#  'https://www.mdpi.com/2075-4426/11/8/725',
#  'https://journals.lww.com/prsgo/Fulltext/2021/07000/A_Novel_Artificial_Intelligence_assisted_Risk.50.aspx',
#  'https://www.mdpi.com/1424-8220/21/15/5092',
#  'https://www.hindawi.com/journals/cmmm/2021/2464821/',
#  'https://www.mdpi.com/2227-9032/9/8/941',
#  'https://www.mdpi.com/2075-1729/11/8/747',
#  'https://onlinelibrary.wiley.com/doi/10.1111/liv.14999',
#  'https://www.mdpi.com/2072-6694/13/15/3723',
#  'https://www.hindawi.com/journals/jhe/2021/4963361/',
#  'https://www.mdpi.com/2076-3425/11/8/977',
#  'https://www.mdpi.com/2072-6694/13/15/3709',
#  'https://www.mdpi.com/1424-8220/21/15/5006',
#  'https://www.mdpi.com/2075-4418/11/8/1324',
#  'https://onlinelibrary.wiley.com/doi/10.1002/acr2.11289',
#  'https://www.mdpi.com/1099-4300/23/8/936',
#  'https://peerj.com/articles/cs-547/',
#  'https://www.mdpi.com/2072-6694/13/15/3689',
#  'https://www.mdpi.com/2077-0383/10/15/3238',
#  'https://www.mdpi.com/2077-0383/10/15/3231',
#  'https://www.mdpi.com/2075-1729/11/8/730',
#  'https://www.mdpi.com/2075-4426/11/8/695',
#  'https://www.tandfonline.com/doi/full/10.1080/07448481.2021.1947841',
#  'https://www.mdpi.com/2077-0383/10/15/3198',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22627',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cas.15052',
#  'https://www.mdpi.com/1424-8220/21/15/4960',
#  'https://www.mdpi.com/2075-4418/11/8/1309',
#  'https://validate.perfdrive.com/?ssa=c390a30d-d991-4a25-8ccc-b21091157a17&ssb=20064207389&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac0d60&ssi=0afb6738-8427-442d-af6b-fe553b023a31&ssk=support@shieldsquare.com&ssm=45797022799250631102658711723324&ssn=19c72bdb1ee432bb76a6a5ba1635a14fd13d3bb9fc2b-57c2-40d8-99aeb0&sso=952adea6-022422c6f3a0020a18fdfec392d383640c3ad81026297bcd&ssp=04123622601654639319165467046625323&ssq=40480012767679196243827676985994996137228&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.mdpi.com/1424-8220/21/15/4949',
#  'https://medinform.jmir.org/2021/7/e27955',
#  'https://www.hindawi.com/journals/ije/2021/3984463/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/epi4.12520',
# ...
#  'https://www.tandfonline.com/doi/full/10.1080/21678421.2021.1927102',
#  'https://journals.sagepub.com/doi/10.1177/09544119211028380',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14834',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.15044',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25565',
#  'https://onlinelibrary.wiley.com/doi/10.1111/epi.16990',
#  'https://www.ahajournals.org/doi/10.1161/STROKEAHA.120.030950',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-8-4713&id=453098',
#  'https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/hep4.1768',
#  'https://academic.oup.com/oncolo/article/26/9/751/6512110',
#  'https://www.tandfonline.com/doi/full/10.1080/14767058.2021.1918670',
#  'https://journals.sagepub.com/doi/10.1177/15353702211018970',
#  'https://www.mdpi.com/1424-8220/21/14/4638',
#  'https://peerj.com/articles/11692/',
#  'https://journals.sagepub.com/doi/10.1177/21925682211026910',
#  'https://link.springer.com/article/10.1007/s00330-021-08146-8',
#  'https://www.birpublications.org/doi/10.1259/bjro.20200073',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25575',
#  'http://www.annalsgastro.gr/files/journals/1/earlyview/2021/ev-07-2021-07-AG_5972-0653.pdf',
#  'https://anndermatol.org/DOIx.php?id=10.5021/ad.2021.33.4.345',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1754-9485.13278',
#  'https://journals.lww.com/cmj/Fulltext/2021/08050/Establish_a_normal_fetal_lung_gestational_age.11.aspx',
#  'https://onlinelibrary.wiley.com/doi/10.1111/hepr.13681',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cpe.6434',
#  'https://validate.perfdrive.com/?ssa=9aa4dc05-13f2-4a12-a9e2-a0a08ceb90b7&ssb=19136244251&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6579%2Fac08e6&ssi=a11d6b1e-8427-4918-9964-49b41a9e6798&ssk=support@shieldsquare.com&ssm=97848132730953176109066645700035&ssn=2d76a600ebcddf7a146626525495655192bea1c02e69-1fc3-417a-8b50f3&sso=b5c0b1db-1a484299304d8ffccc76f35a688cf2442e77d9c242d02523&ssp=17680350321654672982165466858080584&ssq=31006342821107251967228211043157373916992&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://journals.sagepub.com/doi/10.1177/26317745211014698',
#  'https://peerj.com/articles/cs-607/',
#  'https://ietresearch.onlinelibrary.wiley.com/doi/10.1049/syb2.12031',
#  'https://jpbs.hapres.com/htmls/JPBS_1407_Detail.html',
#  'https://www.jhrsonline.org/article.asp?issn=0974-1208;year=2021;volume=14;issue=2;spage=129;epage=136;aulast=Shemshaki',
#  'https://www.frontiersin.org/articles/10.3389/fimmu.2021.700782/full',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-7-4510&id=452860',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13327',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14987',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ocr.12493',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/07000/Generalization_in_Clinical_Prediction_Models__The.3.aspx',
#  'https://www.mdpi.com/2075-4418/11/7/1156',
#  'https://erj.ersjournals.com/content/57/6/2002591',
#  'https://onlinelibrary.wiley.com/doi/10.1002/spe.3011',
#  'https://dl.acm.org/doi/10.1145/3463494',
#  'https://pubs.rsna.org/doi/10.1148/ryct.2021200580',
#  'https://aasldpubs.onlinelibrary.wiley.com/doi/10.1002/hep.31750',
#  'https://www.tandfonline.com/doi/full/10.1080/21645515.2021.1940651',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-7-4438&id=452754',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/acm2.13320',
#  'https://validate.perfdrive.com/?ssa=ce4fbe03-59a2-4d79-b314-04bc22a72df2&ssb=32073275258&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6560%2Fac09a2&ssi=63a68924-8427-4fe1-98e1-2e6343a1904c&ssk=support@shieldsquare.com&ssm=36973881750789200105474934410149&ssn=747a6e1d177ac0d4a51ea57be880c77339e085eff86f-b91b-44df-9eb1b1&sso=acf47960-51451ae5e07fb551e2cc2b7e3126368f7b2682a85895d402&ssp=12907697751654644168165465855902360&ssq=32625282835947834077628359132804638768106&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.mdpi.com/2072-6694/13/13/3106',
#  'https://pubs.acs.org/doi/10.1021/acs.analchem.1c01061',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14827',
#  'https://onlinelibrary.wiley.com/doi/10.1002/joa3.12555',
#  'https://www.mdpi.com/2075-4418/11/7/1136',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cyto.a.24467',
#  'https://validate.perfdrive.com/?ssa=ab360347-e2b1-45e2-88b4-f6f416108ec7&ssb=96078211295&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6560%2Fabfff0&ssi=adbbd6b5-8427-4465-b978-d9954901d01f&ssk=support@shieldsquare.com&ssm=06779368017572611101937980401638&ssn=c7a908f971635d174dab99fd44063a419744a13550d5-dfc2-4ed7-9be1bb&sso=1b602474-72236fcda65db46827bba7b6827568996663dcb901fe25cc&ssp=84059904711654698929165467026057573&ssq=90414532839730322330128397310099960087220&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://www.mdpi.com/2072-6694/13/13/3109',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14774',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jbio.202100078',
#  'https://www.xiahepublishing.com/2310-8819/JCTH-2021-00023',
#  'https://aacrjournals.org/cancerres/article/81/18/4849/670325/Multiparametric-Photoacoustic-Analysis-of-Human',
#  'https://febs.onlinelibrary.wiley.com/doi/10.1002/1878-0261.13014',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcsm.12733',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcsm.12731',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcsm.12747',
#  'https://validate.perfdrive.com/?ssa=4d5c8da9-1561-4900-b0f8-c6b8fe965885&ssb=38576234332&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6579%2Fabf9f3&ssi=3257c22d-8427-4544-b6d0-9d976395937d&ssk=support@shieldsquare.com&ssm=27198321123381065107340033771239&ssn=b4f7777ad35fc2833a23b2f524faf7af05a03c4752a6-9ef7-4085-aa4cb1&sso=58260266-7f27a5e267c01ac3c9986c53da4df03140c3dfac896fce05&ssp=26376729801654648462165460154202348&ssq=30680372845893789327928458335291261073415&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://journals.physiology.org/doi/full/10.1152/japplphysiol.00150.2021',
#  'https://journals.asm.org/doi/10.1128/AAC.00063-21',
#  'https://pubs.rsna.org/doi/10.1148/ryct.2021200486',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jcmm.16671',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmri.27776',
#  'https://www.science.org/doi/10.1126/sciadv.abf5695',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4042',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/06000/Machine_Learning_Based_Discovery_of_a_Gene.19.aspx',
#  'https://aes.amegroups.com/article/view/5900/html',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/06000/Prediction_of_Impending_Septic_Shock_in_Children.21.aspx',
#  'https://www.frontiersin.org/articles/10.3389/fgene.2021.665469/full',
#  'https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/jemt.23713',
#  'https://validate.perfdrive.com/?ssa=2b43b7e2-ec52-41ca-99b3-1846513976cf&ssb=84019202650&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1361-6560%2Fac01f4&ssi=6bb77109-8427-4dc8-af06-c4d494fafc77&ssk=support@shieldsquare.com&ssm=80038061871156572100056771683121&ssn=5d3a6edf1c7405e43099930170c9ddff553a14302096-cba8-42b8-8b05f9&sso=19d51c78-6b3c44febfef32baa182a4fd7289dc4bd2634467c16cd52f&ssp=92665174931654602018165467490762201&ssq=62908442857095932493828570753064218115119&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://onlinelibrary.wiley.com/doi/10.1111/iwj.13644',
#  'https://www.hindawi.com/journals/cmmm/2021/5569458/',
#  'https://journals.sagepub.com/doi/10.1177/26317745211020277',
#  'https://www.future-science.com/doi/10.2144/fsoa-2020-0207',
#  'https://www.tandfonline.com/doi/full/10.1080/17538157.2021.1939355',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/06000/Impact_of_Different_Approaches_to_Preparing_Notes.7.aspx',
#  'https://www.mdpi.com/2075-4426/11/6/541',
#  'https://www.frontiersin.org/articles/10.3389/frai.2021.684609/full',
#  'https://www.hindawi.com/journals/cmmi/2021/5572470/',
#  'https://www.aging-us.com/article/203122/text',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4044',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-7-3965&id=451756',
#  'https://validate.perfdrive.com/?ssa=43585baf-efdb-4f82-83b2-12466ade9ccc&ssb=14717206203&ssc=https%3A%2F%2Fiopscience.iop.org%2Farticle%2F10.1088%2F1741-2552%2Fac0584&ssi=c5a9443b-8427-46c2-baab-b5dffe824ced&ssk=support@shieldsquare.com&ssm=07908168235411695108536823563728&ssn=36386faecffc69068af3ec9014f78685ec0a14407ccc-294b-4b85-aee34b&sso=860425c0-80e76bb6e43efaab0c82409a8d725217f7d72da0c32f9259&ssp=59126111021654667410165464775925115&ssq=76733922865381230652228653382682640681128&ssr=MTI5LjMxLjI0MC4yNA==&sst=Mozilla/5.0%20(Windows%20NT%2010.0;%20Win64;%20x64)%20AppleWebKit/537.36%20(KHTML,%20like%20Gecko)%20Chrome/102.0.5005.63%20Safari/537.36&ssv=&ssw=&ssx=W10=',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/alz.12387',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12207',
#  'https://www.birpublications.org/doi/10.1259/bjr.20201444',
#  'https://onlinelibrary.wiley.com/doi/10.1002/mrm.28852',
#  'https://onlinelibrary.wiley.com/doi/10.1111/iwj.13623',
#  'https://www.oncotarget.com/article/27979/text/',
#  'https://link.springer.com/chapter/10.1007/978-3-030-77211-6_29',
#  'https://journals.asm.org/doi/10.1128/mSystems.01367-20',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ddg.14510',
#  'https://www.mdpi.com/1424-8220/21/11/3878',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ocr.12501',
#  'https://onlinelibrary.wiley.com/doi/10.1002/acr2.11266',
#  'https://www.mdpi.com/1424-8220/21/11/3883',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22611',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13398',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13358',
#  'https://movementdisorders.onlinelibrary.wiley.com/doi/10.1002/mds.28661',
#  'https://www.aging-us.com/article/203071/text',
#  'https://www.hindawi.com/journals/cmmm/2021/6656942/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.4048',
#  'https://link.springer.com/article/10.1007/s10143-021-01573-7',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cjp2.227',
#  'https://onlinelibrary.wiley.com/doi/10.1111/exsy.12742',
#  'https://www.hindawi.com/journals/cmmm/2021/9928899/',
#  'https://medinform.jmir.org/2021/5/e28868',
#  'https://onlinelibrary.wiley.com/doi/10.1002/brb3.2201',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ics.12706',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ehf2.13375',
#  'https://www.hindawi.com/journals/joph/2021/6694784/',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14903',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3671&id=451450',
#  'https://www.hindawi.com/journals/cin/2021/5540186/',
#  'https://peerj.com/articles/cs-555/',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jcla.23833',
#  'https://journals.sagepub.com/doi/10.1177/21925682211019361',
#  'https://peerj.com/articles/cs-551/',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14927',
#  'https://peerj.com/articles/cs-511/',
#  'https://ieeexplore.ieee.org/document/9434127',
#  'https://journals.lww.com/jaaosglobal/Fulltext/2021/05000/Machine_Learning_Algorithms_Predict_Prolonged.17.aspx',
#  'https://ieeexplore.ieee.org/document/9434018',
#  'https://onlinelibrary.wiley.com/doi/10.1002/jmri.27741',
#  'https://ieeexplore.ieee.org/document/9434034',
#  'https://ieeexplore.ieee.org/document/9433879',
#  'https://peerj.com/articles/cs-560/',
#  'https://www.aging-us.com/article/203082/text',
#  'https://www.nature.com/articles/s41591-021-01339-0',
#  'https://medinform.jmir.org/2021/5/e25237',
#  'https://www.sciencedirect.com/science/article/abs/pii/S0002962921001129?via%3Dihub',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25534',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12201',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3584&id=451276',
#  'https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/s12911-021-01510-0',
#  'https://onlinelibrary.wiley.com/doi/10.1002/lci2.25',
#  'https://onlinelibrary.wiley.com/doi/10.1002/aur.2540',
#  'https://www.futuremedicine.com/doi/10.2217/fon-2020-1254',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200172',
#  'https://journals.asm.org/doi/10.1128/JCM.02959-20',
#  'https://onlinelibrary.wiley.com/doi/10.1111/bpa.12974',
#  'https://www.sciencedirect.com/science/article/pii/S187705092100702X?via%3Dihub',
#  'https://onlinelibrary.wiley.com/doi/10.1002/gcc.22956',
#  'https://peerj.com/articles/cs-541/',
#  'https://www.aging-us.com/article/203032/text',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/05000/A_Machine_Learning_Classifier_Improves_Mortality.24.aspx',
#  'https://onlinelibrary.wiley.com/doi/10.1111/bjh.17524',
#  'https://www.tandfonline.com/doi/full/10.1080/17461391.2021.1921041',
#  'https://link.springer.com/article/10.1007/s00330-021-08014-5',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14907',
#  'https://onlinelibrary.wiley.com/doi/10.1111/eip.13175',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ams2.666',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jsr.13386',
#  'https://www.nature.com/articles/s41591-021-01342-5',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12140',
#  'https://aapm.onlinelibrary.wiley.com/doi/10.1002/mp.14624',
#  'https://www.aging-us.com/article/203033/text',
#  'https://www.futuremedicine.com/doi/10.2217/cer-2020-0230',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.3965',
#  'https://alz-journals.onlinelibrary.wiley.com/doi/10.1002/dad2.12187',
#  'https://www.tandfonline.com/doi/full/10.1080/20002297.2021.1921486',
#  'https://ieeexplore.ieee.org/document/9413538',
#  'https://ieeexplore.ieee.org/document/9414041',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ima.22595',
#  'https://pubs.rsna.org/doi/10.1148/ryai.2021200127',
#  'https://journals.lww.com/ccejournal/Fulltext/2021/05000/Prediction_of_Acute_Respiratory_Failure_Requiring.6.aspx',
#  'https://onlinelibrary.wiley.com/doi/10.1111/1759-7714.13991',
#  'https://onlinelibrary.wiley.com/doi/10.1002/ca.23742',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ddg.14384',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25529',
#  'https://onlinelibrary.wiley.com/doi/10.1002/cam4.3957',
#  'https://analyticalsciencejournals.onlinelibrary.wiley.com/doi/10.1002/jemt.23779',
#  'https://onlinelibrary.wiley.com/doi/10.1002/advs.202100104',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3228&id=450880',
#  'https://journals.sagepub.com/doi/10.1177/15533506211018671',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25436',
#  'https://journals.lww.com/ctg/Fulltext/2021/05000/A_Novel_5_Cytokine_Panel_Outperforms_Conventional.9.aspx',
#  'https://peerj.com/articles/cs-537/',
#  'https://bjui-journals.onlinelibrary.wiley.com/doi/10.1111/bju.15386',
#  'https://onlinelibrary.wiley.com/doi/10.1111/jgh.15522',
#  'https://onlinelibrary.wiley.com/doi/10.1111/ene.14859',
#  'https://ieeexplore.ieee.org/document/9417103',
#  'https://opg.optica.org/boe/fulltext.cfm?uri=boe-12-6-3103&id=450751',
#  'https://onlinelibrary.wiley.com/doi/10.1002/rth2.12505',
#  'https://onlinelibrary.wiley.com/doi/10.1002/epi4.12488',
#  'https://onlinelibrary.wiley.com/doi/10.1002/hbm.25437',
#  'https://aacrjournals.org/cebp/article/30/7/1397/671007/Tumor-Associated-Stromal-Cellular-Density-as-a',
#  'https://onlinelibrary.wiley.com/doi/10.1111/cas.14927',
#  ...]

# %% [markdown]
# # scrape urls - testing

# %%
driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver\chromedriver.exe')

#driver.get(random.choice(url_list))
driver.get("https://www.mdpi.com/2072-6694/13/23/6138/htm")

page = driver.page_source

tree = html.fromstring(page)

driver.quit()
# Out:
# C:\Users\Joe Z\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
body_text = tree.xpath('//body/descendant-or-self::*/text()')

# %%
print(body_text)
# Out:
# ['\n', '\n            ', '\n        ', '\n', '\n', '\n', '\n', '\n', '\nNext Article in Journal', '\n', 'Challenges for the Development of Extracellular Vesicle-Based Nucleic Acid Medicines', '\nNext Article in Special Issue', '\n', 'Raman Spectroscopy in Prostate Cancer: Techniques, Applications and Advancements', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\nPrevious Article in Journal', '\n', 'Promising Antigens for the New Frontier of Targeted Immunotherapy in Multiple Myeloma', '\nPrevious Article in Special Issue', '\n', 'Development of a Radiomic-Based Model Predicting Lymph Node Involvement in Prostate Cancer Patients', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'Journals', '\n', '\n', '\n', 'Topics', '\n', '\n', '\n', '\n', 'Information', '\n', '\n', '\n', '\n', '\n', 'For Authors', '\n', 'For Reviewers', '\n', 'For Editors', '\n', 'For Librarians', '\n', 'For Publishers', '\n', 'For Societies', '\n', 'For Conference Organizers', '\n', '\n', '\n', 'Article Processing Charges', '\n', 'Open Access Policy', '\n', 'Institutional Open Access Program', '\n', 'Editorial Process', '\n', 'Awards', '\n', 'Research and Publication Ethics', '\n', '\n', '\n', '\n', '\n', '\n', 'Author Services', '\n', '\n', '\n', '\n', 'Initiatives', '\n', '\n', '\n', '\n', '\n', 'Sciforum', '\n', 'MDPI Books', '\n', 'Preprints', '\n', 'Scilit', '\n', 'SciProfiles', '\n', 'Encyclopedia', '\n', 'JAMS', '\n', 'Proceedings Series', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'About', '\n', '\n', '\n', '\n', '\n', 'Overview', '\n', 'Contact', '\n', 'Careers', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'Sign In / Sign Up', '\n', '\n', '\n', '\n', '\n', '\n', 'Notice', '\n', '\n', '\n', '\n', '\n', '\nYou can make submissions to other journals\n', 'here', '.\n', '\n', '\n', '\n', '\n', 'clear', '\n', '\n', '\n', '\n', '\n', '\n', 'Notice', '\n', '\nYou are accessing a machine-readable page. In order to be human-readable, please install an RSS reader.\n', '\n', '\n', '\n', '\n', '\n', 'Continue', '\n', 'Cancel', '\n', '\n', '\n', '\n', 'clear', '\n', '\n', '\n', '\n', '\nAll articles published by MDPI are made immediately available worldwide under an open access license. No special\npermission is required to reuse all or part of the article published by MDPI, including figures and tables. For\narticles published under an open access Creative Common CC BY license, any part of the article may be reused without\npermission provided that the original article is clearly cited.\n', '\n', '\n', '\n', '\nFeature Papers represent the most advanced research with significant potential for high impact in the field. Feature\nPapers are submitted upon individual invitation or recommendation by the scientific editors and undergo peer review\nprior to publication.\n', '\n', '\nThe Feature Paper can be either an original research article, a substantial novel research study that often involves\nseveral techniques or approaches, or a comprehensive review paper with concise and precise updates on the latest\nprogress in the field that systematically reviews the most exciting advances in scientific literature. This type of\npaper provides an outlook on future directions of research or possible applications.\n', '\n', '\n', '\n', '\nEditor’s Choice articles are based on recommendations by the scientific editors of MDPI journals from around the world.\nEditors select a small number of articles recently published in the journal that they believe will be particularly\ninteresting to authors, or important in this field. The aim is to provide a snapshot of some of the most exciting work\npublished in the various research areas of the journal.\n', '\n', '\n', '\n', '\n                    ', "\n                        You seem to have javascript disabled. Please note that many of the page functionalities won't work as expected without javascript enabled.\n                    ", '\n                ', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', '\n', 'clear', '\ ...

# %%
body_text = [x.replace('\n', ' ') for x in body_text]
body_text = [x.replace('    ', ' ') for x in body_text]
body_text = [x.replace('   ', ' ') for x in body_text]
body_text = [x.replace('  ', ' ') for x in body_text]
body_text = [x.lower() for x in body_text]

# %%
## conditions

def alphachars(x): return sum(a.isalpha() for a in x) > 4

def charchar(x): return bool(re.match(r".*[a-zA-Z][a-zA-Z].*", x)) == True

def istitle(x): return ((('ethod' in x) or ('aterial' in x) or ('esult' in x) or ('iscussion' in x) or ('onclusion' in x)) 
                        and (sum(l.isalpha() for l in x) < 30))

def istextblock(x): return sum(l.isalpha() for l in x) > 100

def methodtitle(x): return ((('ethod' in x) or ('aterial' in x)) and (sum(l.isalpha() for l in x) < 30))

# %%
keep_text = []

for x in body_text:
    if (charchar(x) and alphachars(x)) and (istitle(x) or istextblock(x)):
        keep_text.append(x)
    else:
        continue
        
keep_text
# Out:
# [' all articles published by mdpi are made immediately available worldwide under an open access license. no special permission is required to reuse all or part of the article published by mdpi, including figures and tables. for articles published under an open access creative common cc by license, any part of the article may be reused without permission provided that the original article is clearly cited. ',
#  ' feature papers represent the most advanced research with significant potential for high impact in the field. feature papers are submitted upon individual invitation or recommendation by the scientific editors and undergo peer review prior to publication. ',
#  ' the feature paper can be either an original research article, a substantial novel research study that often involves several techniques or approaches, or a comprehensive review paper with concise and precise updates on the latest progress in the field that systematically reviews the most exciting advances in scientific literature. this type of paper provides an outlook on future directions of research or possible applications. ',
#  ' editor’s choice articles are based on recommendations by the scientific editors of mdpi journals from around the world. editors select a small number of articles recently published in the journal that they believe will be particularly interesting to authors, or important in this field. the aim is to provide a snapshot of some of the most exciting work published in the various research areas of the journal. ',
#  "  you seem to have javascript disabled. please note that many of the page functionalities won't work as expected without javascript enabled. ",
#  ' construction materials ',
#  ' electronic materials ',
#  ' materials ',
#  ' materials proceedings ',
#  ' methods and protocols (mps) ',
#  ' nanomaterials ',
#  'discussion',
#  'supplementary material',
#  'division of surgery and interventional science, faculty of medical sciences, university college london, london wc1e 6bt, uk',
#  ' international guidelines recommend multiparametric magnetic resonance imaging (mpmri) of the prostate for use by radiologists to identify lesions containing clinically significant prostate cancer, prior to confirmatory biopsy. automatic assessment of prostate mpmri using artificial intelligence algorithms holds a currently unrealized potential to improve the diagnostic accuracy achievable by radiologists alone, improve the reporting consistency between radiologists, and enhance reporting quality. in this work, we introduce autoprostate: a deep learning-powered framework for automatic mri-based prostate cancer assessment. in particular, autoprostate utilizes patient data and biparametric mri to populate an automatic web-based report which includes segmentations of the whole prostate, prostatic zones, and candidate clinically significant prostate cancer lesions, and in addition, several derived characteristics with clinical value are presented. notably, autoprostate performed well in external validation using the picture study dataset, suggesting value in prospective multicentre validation, with a view towards future deployment into the prostate cancer diagnostic pathway. ',
#  ' multiparametric magnetic resonance imaging (mpmri) of the prostate is used by radiologists to identify, score, and stage abnormalities that may correspond to clinically significant prostate cancer (cspca). automatic assessment of prostate mpmri using artificial intelligence algorithms may facilitate a reduction in missed cancers and unnecessary biopsies, an increase in inter-observer agreement between radiologists, and an improvement in reporting quality. in this work, we introduce autoprostate, a deep learning-powered framework for automatic mri-based prostate cancer assessment. autoprostate comprises of three modules: zone-segmenter, cspca-segmenter, and report-generator. zone-segmenter segments the prostatic zones on t2-weighted imaging, cspca-segmenter detects and segments cspca lesions using biparametric mri, and report-generator generates an automatic web-based report containing four sections: ',
#  '. in our experiment, autoprostate was trained using the publicly available prostatex dataset, and externally validated using the picture dataset. moreover, the performance of autoprostate was compared to the performance of an experienced radiologist who prospectively read picture dataset cases. in comparison to the radiologist, autoprostate showed statistically significant improvements in prostate volume and prostate-specific antigen density estimation. furthermore, autoprostate matched the cspca lesion detection sensitivity of the radiologist, which is paramount, but produced more false positive detections. ',
#  'automatic report; computer-aided diagnosis; convolutional neural network; deep learning; lesion detection; lesion classification; magnetic resonance imaging; prostate cancer; segmentation',
#  'radiologists use prostate multiparametric magnetic resonance imaging (mpmri) to detect, score, and stage lesions that may correspond to clinically significant prostate cancer (cspca), whose status can later be confirmed using mr-guided targeted biopsy and histopathological grading [',
#  ']. however, the current diagnostic approach must be improved to reduce the small proportion of men with cspca who are missed by mpmri, to reduce the large number of men who undergo unnecessary biopsies, and to increase the inter-observer agreement between readers [',
#  ']. in addition to lesion assessment, radiologists use prostate mpmri to estimate prostate volume using the ellipsoid formula [',
#  ']. primarily, prostate volume is required for calculating prostate-specific antigen density (psad), which has been shown to be a predictor of cspca [',
#  '], therefore more accurate volume estimation methods are sought. computer-aided diagnosis (cad) systems that use mpmri for prostate volume estimation and cspca lesion detection and/or segmentation may provide the desired performance improvements over current clinical practice.',
#  'automatic segmentation of the prostate may enable accurate prostate volume estimation. several automatic methods for prostate segmentation have been published [',
#  ']. foremost, the promise12 challenge has driven consistent improvements in the performance of prostate segmentation algorithms over the past decade [',
#  ']; an unpublished deep learning method named msd-net currently tops the leader board with a mean dice coefficient of 0.92 for whole-prostate segmentation. to the best of our knowledge, only the work by lee et al. [',
#  '] has compared prostate volume estimation using an automatic segmentation method to the clinically utilized ellipsoid formula. on a 70-patient test set, their 3d cnn for whole-prostate segmentation achieved a mean dice coefficient of 0.87 and a mean absolute percentage error (abs%err) of 11.78% for volume estimation, while the mean abs%err for the ellipsoid formula was 11.92%. in the discussion section of their paper, lee et al. mention the potential benefit of more accurate volume estimation methods on the calculation of psad, but their study stopped short of providing a quantitative comparison.',
#  'cad systems for lesion detection and segmentation are actively being investigated, as demonstrated by a vast and growing literature [',
#  '] directly compared cad systems for cspca lesion detection against radiologist mpmri assessment. cao et al. showed that their proposed focalnet convolutional neural network (cnn), trained using biparametric mri (bpmri), had a cspca lesion detection sensitivity of 87.9%, which was only 1.5% lower than pi-rads v2 scoring by three experienced radiologists who read a subset of cases each. their result was obtained from a fivefold cross-validation of 417 preoperative patients who later underwent radical prostatectomy. similarly, the study by schelb et al. showed that a u-net cnn [',
#  '] produced similar cspca detection performance to pi-rads v2 scoring by eight radiologists who each read a subset of cases. on the held-out test cohort of 62 men sampled from the same study cohort as the training data, their method achieved a patient-level sensitivity of 92% and specificity of 47%, while radiologist assessment yielded a sensitivity of 88% and a specificity of 50%; differences in sensitivity and specificity between the proposed cnn approach and radiologist scoring were not statistically significant. while the studies by cao et al. and schelb et al. evaluated cad systems using test data sampled from the same study cohort as the training data, the study by thon et al. [',
#  ' did not perform satisfactorily on external test data due to differences in the instrumentation and acquisition parameters used to collect training and test data. moreover, they remarked that optimistic performances of cad systems reported in other studies may be dataset-specific, and therefore advocated for the necessity of external validation of cad systems.',
#  'this work has two aims. the first aim is to introduce autoprostate: a deep learning-powered framework for automatic mri-based prostate cancer detection and assessment that we have developed. in particular, autoprostate segments the prostatic zones on t2-weighted imaging (t2wi), detects and segments cspca lesions using bpmri, and generates a novel automatic web-based report containing four sections: ',
#  ', which posits it close to clinical deployment. notably, autoprostate uses up-to-date deep learning techniques for training and inference, such as hybrid losses [',
#  '], and model ensembling, to enhance performance. the second aim of this work is to perform a high-quality single-centre external validation of autoprostate, as a first step towards clinical deployment, ahead of multicentre external validation and prospective validation in a clinical setting. in our experiment, autoprostate is trained using the publicly available prostatex dataset [',
#  '], and externally validated using the prostate imaging compared to transperineal ultrasound-guided biopsy for significant prostate cancer risk evaluation (picture) trial dataset [',
#  ']. the external validation follows the key considerations for authors, reviewers, and readers of ai manuscripts in radiology by bluemke et al. [',
#  ']. in particular, the external test set contains mris acquired using scanners manufactured by a different vendor to the scanners used to acquire the training set and is confirmed using transperineal template prostate-mapping (ttpm) biopsy, which avoids the biases associated with mr-guided targeted biopsy and prostatectomy [',
#  ']. furthermore, we compare the performance of autoprostate to the performance of an experienced radiologist who, at the time of the picture trial, had 10 years’ experience in reading prostate mpmri.',
#  ' 2. methods',
#  ', consists of three modules: zone-segmenter, cspca-segmenter, and report-generator. methodological aspects of each module are described in detail in the subsections to follow, while specific experimental parameters used to collect results are described in ',
#  't2w images are first resampled to a common in-plane resolution and cropped to a common in-plane shape, and then normalized by whitening of image voxel intensities.',
#  'after pre-processing, each t2wi slice is segmented by an ensemble of 2d nnu-nets with task-specific hyperparameter modifications; we refer to each constituent 2d nnu-net as zone-u-net and the ensemble of zone-u-nets as zone-u-net-e. a detailed description of the zone-u-net architecture is given in ',
#  '. the output of each zone-u-net is slice-wise pz, cg, and background probability maps. per-voxel averaging is used to combine the probability map outputs of each zone-u-net ∈ zone-u-net-e, followed by restacking of slices to form pz, cg, and background probability map volumes.',
#  'the pz, cg, and background probability maps output by zone-u-net-e are transformed to the original t2wi shape and voxel resolution using padding and resampling operations. as a final step, a zonal segmentation map is obtained from the pz, cg, and background probability maps using a per-voxel argmax operation.',
#  'the cspca-segmenter module detects and segments cspca lesions using each patient’s t2wi, apparent diffusion coefficient (adc) map, low b-value diffusion-weighted imaging (dwi), and pz and cg probability maps output by zone-segmenter.',
#  'image registration is used to align adc maps and computed high b-value dwi to t2wi to account for voluntary/involuntary patient movement between t2wi and dwi acquisitions and differences in resolution. first, adc maps are affinely registered to t2wi using the symmetric block matching algorithm [',
#  '], with the convolution-based fast local normalized correlation coefficient (lncc) similarity measure to enable robustness to bias field inhomogeneity [',
#  ']. finally, the transformation obtained from the composition of both types of registration is used to register computed high b-value dwi to t2wi.',
#  't2wi, registered adc map and computed high b-value dwi, and pz and cg probability maps are resampled to a common in-plane resolution and cropped to a common in-plane shape, centred on the prostate; image cropping is used for memory efficiency. then, t2wi and computed high b-value dwi are normalized by dividing voxel intensities by the interquartile mean of cg voxel intensities. our approach is a modification of the normalization approach suggested by bonekamp et al. [',
#  '], where voxel intensities were divided by the mean of pz voxel intensities. we opt for normalization using cg voxel intensities since cg segmentations are typically more reliable than pz segmentations [',
#  '], and we opt for the interquartile mean of cg voxel intensities as opposed to the mean of all cg voxel intensities, to remove extremes that may correspond to abnormalities unique to a patient. adc maps were not normalized as they contain a quantitative measurement.',
#  'after pre-processing, each slice of a patient’s t2wi, adc map, computed high b-value dwi, and pz and cg probability maps are input channel-wise to an ensemble of 2d nnu-nets for cspca lesion segmentation; the addition of pz and cg guidance as input has been shown to increase cspca lesion detection performance as the occurrence and appearance of prostate cancer is dependent on its zonal location [',
#  ']. we refer to each constituent 2d nnu-net as cspca-u-net and the ensemble of cspca-u-nets as cspca-u-net-e. a detailed description of the cspca-u-net architecture is given in ',
#  '], i.e., dropout layers are inserted after the central three encoder units and two decoder units, with dropout probability equal to p. we model aleatoric uncertainty using test-time augmentation as in wang et al. [',
#  'the output of each cspca-u-net is slice-wise cspca probability maps. per-voxel averaging is used to combine the probability map outputs of each cspca-u-net ∈ cspca-u-net-e, followed by restacking of slices to form a probability map volume.',
#  'the cspca probability map output by cspca-u-net-e is transformed to the original t2wi shape and voxel resolution using padding and resampling operations. next, probabilities are calibrated using an isotonic regression calibration module [',
#  '], to allow more interpretable cspca likelihoods. cspca lesion segmentations are obtained by thresholding cspca probability maps using a cut-off value c; c is chosen during experimentation using training data to match autoprostate’s detection sensitivity and specificity to that of an experienced radiologist. finally, a false-positive reduction step is applied to remove connected components smaller than minsize mm',
#  'the report-generator module generates an automatic report using input bpmri and clinical data, and the outputs of the zone-segmenter and cspca-segmenter modules; the report template is shown in ',
#  'the left-hand pane contains interactive report elements including a patient selector and transverse, frontal, and sagittal views of zone and cspca lesion segmentation outputs overlaid on t2wi, with associated widgets for slice selection.',
#  ' lengths of the prostate, in cm, are calculated using the maximum extents of the prostate on the whole-prostate segmentation, where the whole-prostate segmentation is the union of the pz and cg segmentations. ',
#  ' (base, midgland, or apex) are determined based on the location of the lesion centroid; our region determination follows the methodology outlined by litjens et al. [',
#  '] for evaluating the promise12 challenge, where the apex is defined as the caudal-most third of the prostate, the base is the cranio-most third of the prostate, and the midgland is the remaining portion. the ',
#  'in this section, we describe the datasets used for training and testing autoprostate, the methodological settings employed, and the evaluation measures used to assess performance.',
#  '], and externally validated using the prostate imaging compared to transperineal ultrasound-guided biopsy for significant prostate cancer risk evaluation (picture) study dataset [',
#  'mpmri was acquired using two 3-tesla magnetic field scanners (magnetom trio and skyra, siemens) and a pelvic-phased array coil. sequences collected included t2wi, adc map computed from dwi acquired at multiple b-values (50, 400, 800), and dcei with a temporal resolution of 3.5 s. all mpmri studies were reported by an experienced radiologist with over 20 years’ experience in reading prostate mpmri, who highlighted areas of suspicion per modality with a point marker and scored them using pi-rads v1. mr-guided targeted biopsies of marked points with pi-rads v1 score ≥ 3 were performed, while marked points with pi-rads v1 score 3 (unlikely for cspca) were not biopsied and assumed to be clinically insignificant (5% incidence of cspca in pi-rads v1 3 lesions at radboud university medical center). subsequently, biopsy specimens were graded by a histopathologist. the marked point coordinate and a ground-truth label (clinically significant equal to true or false) for each marked lesion was released publicly for 204 of the 346 patients, hence only these 204 patients feature in our work; clinical and histopathological characteristics are shown in ',
#  ']. in summary, contours were produced in consensus by radiology residents (2 years’ experience in reading prostate mpmri) and board-certified radiologists (5 years’ experience in reading prostate mpmri) at the university of naples. radiology residents and board-certified radiologists worked in pairs for quality control and annotation. whole-prostate and zonal contours (pz and cg) were drawn for each patient. in addition, 299 lesions were delineated, including 76 cspca lesions and 223 low-grade or benign lesions (ncspca).',
#  ']. men were examined at university college london hospital between 2012 and 2014. inclusion criteria for the picture study were: (i) men who had undergone an initial standard transrectal ultrasound-guided (trus) biopsy, but concern remained over the accuracy of the subsequent diagnosis; and (ii) men suitable for further characterization using transperineal template prostate-mapping (ttpm) biopsy. exclusion criteria were: (i) previous history of prostate cancer treatment; and (ii) lack of complete gland sampling or inadequate sampling density at ttpm.',
#  'mpmri was acquired using a 3-tesla magnetic field scanner (achieva, philips healthcare) and a pelvic-phased array coil. sequences collected included t2wi, dwi with high b-value (2000), adc map computed from dwi acquired at multiple b-values (0, 150, 500, 1000), and dcei with a temporal resolution of 13 s.',
#  'all mpmri studies were reported by an experienced radiologist with 10 years’ experience in reading prostate mpmri, using a five-point likert impression scale for the likelihood of cspca [',
#  ']; cspca was defined as gleason score ≥ 3 + 4. scoring was completed at the lesion, sector, and patient-levels. clinical information, including the referral psa (ng/ml), was available to the radiologist during scoring to reflect clinical practice. men underwent mr-guided targeted biopsy of focal index lesions and ttpm biopsy with 5 mm sampling as the reference standard. ttpm biopsy was used to overcome the inaccuracies of trus biopsy [',
#  'in this work, two patients were removed due to missing mri data. clinical and histopathological characteristics for the 247 included patients are shown in ',
#  'whole-prostate and zonal contours were drawn by a board-certified radiologist (e.w.j., 3 years’ experience in the quantitative analysis of prostate mpmri), for 80 patients. lesions were delineated by two board-certified radiologists (s.s. and n.g., 5 and 4-years’ experience in scoring prostate mpmri using likert assessment and pi-rads v2, respectively), who drew contours on a subset of cases each. the protocol for lesion contouring was agreed between the radiologists beforehand. first, histopathology reports from mr-guided targeted and ttpm biopsies were reviewed alongside mpmri to locate the highest gleason grade focal lesion; if there were multiple focal lesions with the maximum gleason grade, the highest scoring focal lesion according to likert or pi-rads v2 was identified. next, a single axial t2wi slice was selected corresponding to the centre of the identified lesion. then, all focal lesions on the selected slice were contoured. additionally, focal benign lesions that were scored likert or pi-rads v2 ≥ 4 were contoured in patients that were biopsy-negative for cancer. a total of 210 lesions were delineated, including 147 cspca lesions and 63 ncspca lesions.',
#  ' 3.2. methodological settings',
#  'a tenfold cross-validation analysis of zone-u-net was conducted using the prostatex dataset to optimize training hyperparameters, loss function, and augmentations. fold splits are shown in ',
#  '. zone-u-net performed optimally when trained for 50 epochs with learning rate equal to 0.0001, batch size equal to eight, adam optimization [',
#  'following the tenfold cross-validation, the ten trained zone-u-nets were used to construct zone-u-net-e; cross-validation ensembles have been shown to be an effective ensembling strategy [',
#  'the registration of adc maps to t2wi employed default parameters for affine registration via symmetric block-matching. the subsequent non-rigid ffd registration used a gaussian kernel with standard deviation equal to 5 mm for lncc calculation, control point spacing equal to 10 mm, and bending energy constraint equal to 0.1. registrations were run using niftyreg (version 1.3; available online: ',
#  ' (accessed on 1 october 2018). through visual inspection, satisfactory registration was observed for the majority of prostatex and picture dataset cases. no manual steps were taken to correct any instances of misregistration, and cases with misregistration were not excluded from our analysis.',
#  't2wi, registered adc maps and computed b2000 (cb2000) dwi, and pz and cg probability maps, were resampled to a common in-plane resolution of 0.4018 mm × 0.4018 mm and cropped to a common in-plane shape of 256 × 256, centred on the prostate.',
#  'like zone-u-net, the training settings for cspca-u-net were determined through tenfold cross-validation using the prostatex dataset with the fold splits shown in ',
#  '. cspca-u-net performed optimally when trained for 50 epochs with learning rate equal to 0.0001, batch size equal to 12, adam optimization, a dropout probability of ',
#  ' for central dropout, a hybrid loss composed of the sum of dice loss multiplied by 0.5 and focal loss multiplied by 1.0, and horizontal flip (probability = 0.5), rotation (−20°, 20°), and scaling (−10%, +20%) augmentations. the same dropout probability and augmentation settings were used for test-time dropout and test-time augmentation.',
#  'cspca probability maps output by cspca-u-net for each fold were calibrated using separate isotonic calibration modules for each fold. following calibration, cspca probability maps were thresholded using cut-off values determined for each fold, corresponding to a lesion-level sensitivity of 93% and specificity of 37%, in the fold’s training set. the aforementioned sensitivity and specificity correspond to reference radiologist performance at pi-rads v1 cut-off ≥ 4 on a separate patient cohort from radboud medical center, reported on in litjens et al. [',
#  '], which was used since prospective radiologist performance was not available for the prostatex dataset. as a final post-processing step, connected components smaller than 40 mm',
#  'following the tenfold cross-validation, the ten trained cspca-u-nets were used to construct cspca-u-net-e. cspca-u-net-e was calibrated using isotonic calibration. for thresholding, a cut-off value c = 4.5% was determined to match radiologist performance in the training set for cspca-u-net-e i.e., the entire prostatex dataset. for false-positive reduction, connected components smaller than 40 mm',
#  'whole-prostate and zonal segmentations were evaluated using the dice coefficient. prostate size measurements (transverse, anterior–posterior, and cranio–caudal lengths), as well as whole-prostate and zonal volumes, were evaluated using the abs%err; the ground-truth lengths and volumes used in the calculation of abs%err were derived from the manually-drawn whole-prostate and zonal contours. the psad estimated by autoprostate was evaluated using absolute error (abserr), since the absolute value of psad has a meaning relative to risk definitions [',
#  ']; the ground-truth psad value used in the calculation of abserr was obtained by dividing psa by the whole-prostate volume calculated using the manually-drawn whole-prostate contour. the aforementioned evaluation metrics were calculated over the 80 patients from the picture dataset for which manually drawn whole-prostate and zonal segmentations were available.',
#  'receiver operating characteristic (roc) area under the curve (auc) and precision-recall (pr) auc were calculated to quantify autoprostate’s ability to differentiate between cspca lesions and ncspca lesions. after thresholding and false-positive reduction, sensitivity, specificity, and precision were calculated at lesion-level and average false positives were calculated at patient-level. for the picture dataset, the calculation of average false positives was made using 93 patients who were biopsy-negative for cspca, due to limitations in the ground-truth prohibiting false-positive determination in biopsy positive patients. in addition, cspca lesion dice and abs%err of lesion area were calculated on slices containing a contour.',
#  'prostate volume, psad, and lesion detection metrics computed for autoprostate were compared to the same metrics calculated for an experienced radiologist (s.p., 10 years’ experience in scoring prostate mpmri) who prospectively filled out a case report for each patient. prostate volume was estimated using the ellipsoid formula and lesions were scored using a five-point likert scale [',
#  ']. statistical tests were used to compare the performances of autoprostate and the experienced radiologist. the wilcoxon’s signed-rank test [',
#  '] was used to statistically compare precision, and wilcoxon’s signed-rank test was used to statistically compare average false positives.',
#  ' 4. results',
#  'autoprostate, trained using the prostatex dataset, was externally validated using the picture dataset. this section presents the results of the cross-validation of zone-u-net and cspca-u-net (the building blocks of autoprostate) and a detailed analysis of the external validation of autoprostate using the picture dataset, with comparisons made to the performance of an experienced radiologist with 10 years’ experience in reading prostate mpmri, where possible.',
#  '., cspca-u-net achieved a mean roc auc of 0.85 and a mean pr auc of 0.70. after thresholding, cspca-u-net achieved a mean sensitivity of 93%, a mean specificity of 37%, a mean precision of 34%, and a mean false-positive count per patient of 6.9. following false-positive reduction, mean sensitivity dropped marginally to 92%, mean specificity increased to 46%, mean precision increased to 37%, and mean false positives per patient dropped significantly to 3.3 (',
#  ' 4.2. autoprostate external validation analysis: whole-prostate and zonal segmentations, prostate size measurements, and psa density',
#  ' present summaries of the distribution of dice coefficients for whole-prostate and zonal segmentations, the distribution of abs%err for prostate size measurements, and the distribution of abserr for psad calculation, for 80 patients from the picture dataset for which ground-truth segmentations were available.',
#  'mean dice coefficients of 0.75, 0.80, and 0.89 were obtained for the pz, cg, and whole-prostate, respectively. autoprostate’s zone-segmenter module found pz segmentation a more difficult task than cg segmentation, while whole-prostate segmentation had a higher mean dice coefficient than both zonal segmentations, suggesting an ease of distinguishing prostate tissue from background tissues, but a difficulty in distinguishing between pz and cg tissue. as expected, the mean dice coefficients for the pz, cg, and whole-prostate segmentations were lower than those obtained on the prostatex dataset during the tenfold cross-validation of zone-u-net (0.78, 0.86, and 0.91 for pz, cg, and whole-prostate segmentation, respectively) which may be indicative of a generalization gap due to acquisition/population differences.',
#  'the transverse, anterior–posterior, and cranio–caudal lengths of the prostate were estimated using the whole-prostate segmentation output by zone-segmenter. mean abs%err of 3%, 5%, and 20% were obtained for transverse, anterior–posterior, and cranio–caudal lengths, respectively. in addition to the lowest mean abs%err, the transverse length had a smaller standard deviation than anterior–posterior and cranio–caudal lengths. through visual inspection of segmentation outputs, we attribute the variability in the accuracy of the anterior–posterior measurement to the difficulty of determining prostate extent in the anterior fibromuscular stroma, and similarly, we attribute the variability in the accuracy of the cranio–caudal measurement to the difficulty of determining prostate extent at the base and apex regions of the prostate. strikingly, a large maximum abs%err of 100% was observed for the cranio–caudal measurement, due to under-segmentation of the base region in the ground-truth.',
#  'pz, cg, and whole-prostate volumes were calculated using the pz, cg, and whole-prostate segmentations output by zone-segmenter. mean abs%errs of 12%, 18%, and 9% were obtained for pz, cg, and whole-prostate volumes, respectively. strikingly, a large maximum abs%err of 112% was observed for the cg, which was found to be due to over-segmentation of the cg in the base region.',
#  'we compare the abs%err of the whole-prostate volume calculated by autoprostate to the same calculated by the experienced radiologist who used the ellipsoid formula, which is clinically advocated. autoprostate had a mean abs%err of 9%, while the experienced radiologist’s mean abs%err was 13%; the difference was statistically significant (',
#  ' 0.05). using the whole-prostate volumes computed by autoprostate and the experienced radiologist, psad was calculated. autoprostate achieved a mean abserr of 0.019, while the experienced radiologist’s mean abserr was 0.031; again, the difference was statistically significant (',
#  ' 4.3. autoprostate external validation analysis: clinically significant prostate cancer lesion detection and segmentation',
#  'autoprostate achieved a mean roc auc of 0.70 and a mean pr auc of 0.84, calculated using output cspca probability maps prior to thresholding. after thresholding the cspca probability maps using a cut-off value equal to 4.5%, the following were obtained: a sensitivity of 78%, a specificity of 49%, a precision of 78%, and a mean false-positive count of 6.1. following false-positive reduction, mean sensitivity dropped marginally to 76%, mean specificity increased to 57%, mean precision increased marginally to 80%, and the mean false-positive count per patient dropped to 2.5.',
#  'likert scores assigned to suspicious lesions by the experienced radiologist were used to calculate roc and pr curves; radiologist likert scoring gave a roc auc of 0.64 and pr auc of 0.78. after thresholding at cut-off score likert ≥ 4, the following were obtained: a sensitivity of 78%, a specificity of 48%, a precision of 78%, and a mean false-positive count of 0.3. differences between the roc auc, pr auc, sensitivity, specificity, and precision of autoprostate and the experienced radiologist were not statistically significant. however, the difference between mean false positives was statistically significant (',
#  'a further analysis was completed to assess the level of agreement between autoprostate and the experienced radiologist’s likert scores, on annotated lesions, as shown in ',
#  '. for cspca lesions, there was a 78% (114/147) concordance between autoprostate and the experienced radiologist, while for ncspca lesions, there was a 62% (39/63) concordance.',
#  'autoprostate’s lesion segmentations enable the calculation of lesion volume and lesion minimum adc. lesion segmentation accuracy, evaluated using the dice coefficient, was calculated using slices containing a corresponding ground-truth cspca lesion contour. the following dice coefficient metrics were obtained: a mean of 0.46 (sd: 0.32), a median of 0.58 (iqr: 0.10–0.72), and a min–max range of 0.00–0.90. several example cspca lesion segmentations are presented in ',
#  '. examples are shown in the pz and cg, and in the base, midgland, and apex regions of the prostate. in addition, examples have been included to demonstrate autoprostate’s robustness to magnetic susceptibility artifacts. furthermore, an example automatic report generated by autoprostate is shown in ',
#  ' 5. discussion',
#  'in this work, we introduced autoprostate, a deep learning-powered framework for automatic mri-based prostate cancer assessment. autoprostate consists of three modules: zone-segmenter, cspca-segmenter, and report-generator. the output of autoprostate is an automatic web-based report that presents patient details, prostate size measurements and psad, a listing of candidate cspca lesions with derived characteristics, and a findings summary. autoprostate, trained using the publicly available prostatex dataset, was externally validated using the picture dataset. during the external validation, the performance of autoprostate was compared to the performance of an experienced radiologist with 10 years’ experience in reading prostate mpmri, who prospectively estimated prostate volume and psad using the ellipsoid formula, and scored lesions using a five-point likert scale.',
#  'pz, cg, and whole-prostate segmentations are output by autoprostate’s zone-segmenter module. during the experimental setup phase, we tested zone-u-net, prior to ensembling of zone-u-nets to form zone-u-net-e. zone-u-net achieved mean dice coefficients of 0.78, 0.86, and 0.91 for pz, cg, and whole-prostate segmentation, respectively, in tenfold cross-validation using the prostatex dataset. our result compares well to recent works by aldoj et al. [',
#  '], where their proposed dense-2 u-net cnn was evaluated using fourfold cross-validation of a 188-patient subset from the prostatex dataset, and to a recent work by cuocolo et al. [',
#  '] was evaluated using a 105-patient test set from the prostatex dataset. aldoj et al. obtained mean dice coefficients of 0.78, 0.91, and 0.92, and cuocolo et al. obtained mean dice coefficients of 0.71, 0.87, and 0.91, for pz, cg, and whole-prostate segmentation, respectively. however, direct comparison between our work and the works of aldoj et al. and cuocolo et al. is not possible due to the use of different subsets of data for testing. during the external validation of autoprostate using the picture dataset, where zone-u-net-e was used for pz, cg, and whole-prostate segmentation, autoprostate achieved mean dice coefficients of 0.75, 0.80, and 0.89, respectively, on 80 patients for which ground-truth segmentations were available. antonelli et al. [',
#  '] previously reported segmentation results for the picture dataset. a multi-atlas segmentation approach featuring a novel genetic atlas selection strategy was proposed; mean dice coefficients of 0.72 and 0.83 were reported for pz and cg segmentation, using leave-one-out cross-validation, and a mean dice coefficient of 0.83 was reported for whole-prostate segmentation, using atlases from the promise12 dataset [',
#  ']. autoprostate’s estimate of prostate volume was compared to an estimate obtained using the ellipsoid formula, which is clinically advocated [',
#  ']. autoprostate achieved a mean abs%err of 9%, while the radiologist computed ellipsoid formula estimate had a mean abs%err of 13%. notably, the difference in mean abs%err was statistically significant (',
#  '. furthermore, we compared psad estimates obtained using the volume estimates; we found a mean abserr of 0.019 for autoprostate and a mean abserr of 0.031 for the radiologist; again, the difference was statistically significant (',
#  'autoprostate’s foremost purpose is to detect and segment cspca lesions. during the experimental setup phase, we tested cspca-u-net, prior to ensembling of cspca-u-nets to form cspca-u-net-e. markedly, cspca-u-net achieved a lesion-level mean roc auc of 0.85 in tenfold cross-validation using the prostatex dataset, while previous studies have reported a lesion-level mean roc auc of 0.81 on the same subset of prostatex data used in this study, using the same input modalities. during the external validation of autoprostate using the picture dataset, where cspca-u-net-e was used to segment cspca lesions, autoprostate achieved a lesion-level roc auc of 0.70. notably, we observed a large reduction in roc auc on the picture dataset from that seen during the prostatex dataset tenfold cross-validation. we believe that the main reason for the reduction in roc auc is the use of ttpm biopsy in the picture study, which allowed lesions that were not prospectively identified by the radiologist, to be retrospectively contoured using ttpm biopsy findings. other reasons may include a high occurrence of magnetic susceptibility artifacts on dwi in the picture dataset and a possible generalization gap between training data and external testing data due to population/acquisition differences. on the picture dataset, radiologist likert assessment achieved a lesion-level roc auc of 0.64; the difference in roc auc between autoprostate and the experienced radiologist was not statistically significant. following thresholding and false-positive reduction, autoprostate achieved a lesion-level sensitivity of 76%, a lesion-level specificity of 57%, and 2.5 false positives per patient (calculated over patients without cspca, only). in comparison, radiologist likert assessment thresholded at likert ≥ 4, achieved a lesion-level sensitivity of 78%, a lesion-level specificity of 48%, and 0.3 false positives per patient (calculated over patients without cspca, only); only the difference between the number of false positive detections by autoprostate and the experienced radiologist was statistically significant (',
#  '). while autoprostate has demonstrated an ability to differentiate between cspca lesions and low-grade/benign lesions at the level of an experienced radiologist, further work is needed to reduce the number of false positives produced. interestingly, autoprostate achieved a similar sensitivity and improved specificity compared to the radiologist on annotated cspca and ncspca lesions but had a higher overall false-positive count. therefore, it’s possible that the additional false positives produced by autoprostate, that were not prospectively scored by the radiologist, may be easy for radiologists to rule-out.',
#  'several aspects of this study have been guided by the set of nine key considerations for authors, reviewers, and readers of artificial intelligence studies in radiology by bluemke et al. [',
#  ']. as recommended, we maintained a clear separation between training data and testing data. in particular, we avoided a common pitfall observed in previous studies [',
#  '], by determining the probability cut-off value using training data, rather than a biased approach involving the test data itself. in line with further recommendations by bluemke et al., we were able to externally validate autoprostate using the picture dataset. furthermore, the picture dataset was acquired using phillips’ scanners, while the prostatex dataset, used to train autoprostate, was acquired using siemens’ scanners, meaning a further recommendation on using multivendor data for evaluation was met. moreover, we compared autoprostate to an expert radiologist who prospectively reported picture dataset patients, and both autoprostate and the radiologist were compared to an accepted reference standard which combined ttpm and mr-guided targeted biopsies; ttpm biopsy is highly accurate and avoids biases associated to mr-guided targeted biopsy, transrectal ultrasound-guided (trus) biopsy, and prostatectomy [',
#  'cad system studies should describe how the cad system will be deployed clinically, so future prospective trials can be planned accordingly. our goal in this study was to understand the strengths, weaknesses, and idiosyncrasies of autoprostate through a comparison against an experienced radiologist. in the clinical workflow, we envision autoprostate as a radiologist companion system during clinical reads to allow enhanced clinical reporting. it should be acknowledged that current cad systems for mri-based prostate cancer diagnosis contain varying degrees of error in terms of producing too many false positives, false negatives, or both. since the automatic report produced by autoprostate presents visual segmentation outputs, as well as derived measurements, all outputs produced by autoprostate can be rapidly verified by the radiologist. in particular, automatic report information deemed to be accurate can be used to prepare the patient’s clinical report, while erroneous information can be recalculated using current clinical methods or ignored if not required.',
#  'there were three limitations in our study. firstly, our training data was limited to 76 cspca lesions and 223 ncspca lesions; we may expect improved detection sensitivity and reduced false positives if a bigger training dataset with more lesions is available. secondly, our external validation was limited to a single external site. thirdly, lesion contours for each picture dataset patient were drawn by a single radiologist only. while the location and gleason score of lesions was confirmed by a combination of ttpm and mr-guided targeted biopsies, we were not able to overcome the inter-reader variation known to exist in lesion boundary determination [',
#  'our future work will be to perform a prospective validation of autoprostate. in particular, we will plan a clinical trial that investigates the impact of the automatic report on the prospective clinical read of radiologists of varying levels of experience. in preparation for the prospective validation, we will seek a larger multi-centre and multi-vendor training dataset.',
#  ' 6. conclusions',
#  'in this work, we presented autoprostate for automatic mri-based prostate cancer assessment. external validation using the picture dataset demonstrated statistically significant improvements in prostate volume and psa density estimation and no statistically significant differences in cspca lesion detection performance, when compared to an experienced radiologist with over 10 years’ experience in reading prostate mpmri. however, further work is needed to reduce the number of false positives produced by autoprostate, prior to prospective validation.',
#  ' supplementary materials',
#  ', section s1: zone-u-net architecture, section s2: cspca-u-net architecture, table s1: prostatex dataset characteristics, table s2: picture dataset characteristics, table s3: ten-fold cross-validation fold split of the prostatex dataset. lesion significance, size, and zone were used for fold stratification.',
#  'conceptualization, p.m., m.a. and s.o.; methodology, p.m. and m.a.; software, p.m.; formal analysis, p.m. and m.a.; data curation, p.m., m.a., s.s., n.g., e.w.j., h.u.a., m.e. and s.p.; writing—original draft preparation, p.m.; writing—review and editing, p.m., m.a., s.s., n.g., e.w.j., h.u.a., m.e., s.p. and s.o.; supervision, m.a., s.p. and s.o. all authors have read and agreed to the published version of the manuscript.',
#  'our institutional review board approved the study and waived the requirement for individual consent for retrospective analysis of prospectively acquired patient data collected as part of clinical trials/routine care (rd no: 12/0195, 16 july 2012).',
#  'prostatex dataset data citation: geert litjens, oscar debats, jelle barentsz, nico karssemeijer, and henkjan huisman. “prostatex challenge data”, the cancer imaging archive (2017). doi: 10.7937/k9tcia.2017.murs5cl. prostatex dataset masks citation: r. cuocolo, a. stanzione, a. castaldo, d.r. de lucia, m. imbriaco, quality control and whole-gland, zonal and lesion annotations for the prostatex challenge public dataset, eur. j. radiol. (2021).',
#  'p.m.’s research is supported by the engineering and physical sciences research council (epsrc) [ep/r512400/1]. p.m.’s work was additionally supported by the epsrc-funded ucl centre for doctoral training in intelligent, integrated imaging in healthcare (i4health) [ep/s021930/1]. m.a.’s research is supported by the wellcome/epsrc centre for medical engineering king’s college london and by the london medical imaging and ai centre for value-based healthcare. h.u.a.’s research is supported by core funding from the uk’s national institute of health research (nihr) imperial biomedical research centre. hua currently also receives funding from the wellcome trust, medical research council (uk), cancer research uk, prostate cancer uk, the urology foundation, bma foundation, imperial health charity, sonacare inc., trod medical and sophiris biocorp for trials in prostate cancer. m.e. and s.p. receive research support from the university college london/university college london hospital (ucl/uclh) biomedical research centre.',
#  'h.u.a. is a paid consultant to boston scientific for teaching and training on rezum for benign prostate hyperplasia treatment and cryotherapy for prostate cancer treatment and is paid for teaching and proctoring hifu for treating prostate cancer. m.e. receives honoraria from consulting, educational activities, and training from: sonacare inc.; nina medical; and angiodynamics inc. all other authors declare no conflicts of interest.',
#  'ahmed, h.u.; el-shater bosaily, a.; brown, l.c.; gabe, r.; kaplan, r.; parmar, m.k.; collaco-moraes, y.; ward, k.; hindley, r.g.; freeman, a.; et al. diagnostic accuracy of multi-parametric mri and trus biopsy in prostate cancer (promis): a paired validating confirmatory study. ',
#  'brembilla, g.; dell’oglio, p.; stabile, a.; damascelli, a.; brunetti, l.; ravelli, s.; cristel, g.; schiani, e.; venturini, e.; grippaldi, d.; et al. interreader variability in prostate mri reporting using prostate imaging reporting and data system version 2.1. ',
#  'stanzione, a.; ponsiglione, a.; di fiore, g.a.; picchi, s.g.; di stasi, m.; verde, f.; petretta, m.; imbriaco, m.; cuocolo, r. prostate volume estimation on mri: accuracy and effects of ellipsoid and bullet-shaped measurements on psa density. ',
#  'distler, f.a.; radtke, j.p.; bonekamp, d.; kesch, c.; schlemmer, h.-p.; wieczorek, k.; kirchner, m.; pahernik, s.; hohenfellner, m.; hadaschik, b.a. the value of psa density in combination with pi-rads',
# ...
#  'milletari, f.; navab, n.; ahmadi, s. v-net: fully convolutional neural networks for volumetric medical image segmentation. in proceedings of the fourth international conference on 3d vision (3dv), stanford, ca, usa, 25–28 october 2016. [',
#  'comelli, a.; dahiya, n.; stefano, a.; vernuccio, f.; portoghese, m.; cutaia, g.; bruno, a.; salvaggio, g.; yezzi, a. deep learning-based methods for prostate segmentation in magnetic resonance imaging. ',
#  'lee, d.k.; sung, d.j.; kim, c.-s.; heo, y.; lee, j.y.; park, b.j.; kim, m.j. three-dimensional convolutional neural network for prostate mri segmentation and comparison of prostate volume measurements by use of artificial neural network and ellipsoid formula. ',
#  'litjens, g.; toth, r.; van de ven, w.; hoeks, c.; kerkstra, s.; van ginneken, b.; vincent, g.; guillard, g.; birbeck, n.; zhang, j.; et al. evaluation of prostate segmentation algorithms for mri: the promise12 challenge. ',
#  'cao, r.; mohammadian bajgiran, a.; afshari mirak, s.; shakeri, s.; zhong, x.; enzmann, d.; raman, s.; sung, k. joint prostate cancer detection and gleason score prediction in mp-mri via focalnet. ',
#  'giannini, v.; mazzetti, s.; armando, e.; carabalona, s.; russo, f.; giacobbe, a.; muto, g.; regge, d. multiparametric magnetic resonance imaging of the prostate with computer-aided detection: experienced observer performance study. ',
#  'schelb, p.; kohl, s.; radtke, j.p.; wiesenfarth, m.; kickingereder, p.; bickelhaupt, s.; kuder, t.a.; stenzinger, a.; hohenfellner, m.; schlemmer, h.-p.; et al. classification of cancer at prostate mri: deep learning versus clinical pi-rads assessment. ',
#  'thon, a.; teichgraber, u.; tennstedt-schenk, c.; hadjidemetriou, s.; winzler, s.; malich, a.; papageorgiou, i. computer aided detection in prostate cancer diagnostics: a promising alternative to biopsy? a retrospective study from 104 lesions with histological ground truth. ',
#  'greer, m.d.; lay, n.; shih, j.h.; barrett, t.; bittencourt, l.k.; borofsky, s.; kabakus, i.; law, y.m.; marko, j.; shebel, h.; et al. computer-aided diagnosis prior to conventional interpretation of prostate mpmri: an international multi-reader study. ',
#  'gaur, s.; lay, n.; harmon, s.a.; doddakashi, s.; mehralivand, s.; argun, b.; barrett, t.; bednarova, s.; girometti, r.; karaarslan, e.; et al. can computer-aided diagnosis assist in the identification of prostate cancer on prostate mri? a multi-center, multi-reader investigation. ',
#  'zhu, l.; gao, g.; liu, y.; han, c.; liu, j.; zhang, x.; wang, x. feasibility of integrating computer-aided diagnosis with structured reports of prostate multiparametric mri. ',
#  'ronneberger, o.; fischer, p.; brox, t. u-net: convolutional networks for biomedical image segmentation. in proceedings of the international conference on medical image computing and computer-assisted intervention, munich, germany, 5–9 october 2015; springer: cham, switzerland, 2015; pp. 234–241. [',
#  'zhu, w.; huang, y.; zeng, l.; chen, x.; liu, y.; qian, z.; du, n.; fan, w.; xie, x. anatomynet: deep learning for fast and fully automated whole-volume segmentation of head and neck anatomy. ',
#  'gal, y.; ghahramani, z. dropout as a bayesian approximation: representing model uncertainty in deep learning. in proceedings of the 33rd international conference on machine learning, icml 2016, new york, ny, usa, 20–22 june 2016; volume 48, pp. 1651–1660. [',
#  'wang, g.; li, w.; aertsen, m.; deprest, j.; ourselin, s.; vercauteren, t. aleatoric uncertainty estimation with test-time augmentation for medical image segmentation with convolutional neural networks. ',
#  'simmons, l.a.m.; kanthabalan, a.; arya, m.; briggs, t.; barratt, d.; charman, s.c.; freeman, a.; gelister, j.; hawkes, d.; hu, y.; et al. the picture study: diagnostic accuracy of multiparametric mri in men requiring a repeat prostate biopsy. ',
#  'bluemke, d.a.; moy, l.; bredella, m.a.; ertl-wagner, b.b.; fowler, k.j.; goh, v.j.; halpern, e.f.; hess, c.p.; schiebler, m.l.; weiss, c.r. assessing radiology research on artificial intelligence: a brief guide for authors, reviewers, and readers-from the radiology editorial board. ',
#  'verma, s.; sarkar, s.; young, j.; venkataraman, r.; yang, x.; bhavsar, a.; patil, n.; donovan, j.; gaitonde, k. evaluation of the impact of computed high b-value diffusion-weighted imaging on prostate cancer detection. ',
#  'blackledge, m.d.; leach, m.o.; collins, d.j.; koh, d.-m.; may, i.; tumor, i.; blackledge, m.d.; leach, m.o.; collins, d.j. computed diffusion-weighted mr imaging may improve tumor detection. ',
#  'modat, m.; ridgway, g.r.; taylor, z.a.; lehmann, m.; barnes, j.; hawkes, d.j.; fox, n.c.; ourselin, s. fast free-form deformation using graphics processing units. ',
#  'comput. methods programs biomed.',
#  'bonekamp, d.; kohl, s.; wiesenfarth, m.; schelb, p.; radtke, j.p.; gotz, m.; kickingereder, p.; yaqubi, k.; hitthaler, b.; gahlert, n.; et al. radiomic machine learning for characterization of prostate lesions with mri: comparison to adc values. ',
#  'isensee, f.; petersen, j.; klein, a.; zimmerer, d.; jaeger, p.f.; kohl, s.; wasserthal, j.; koehler, g.; norajitra, t.; wirkert, s.; et al. nnu-net: self-adapting framework for u-net-based medical image segmentation. ',
#  'hosseinzadeh, m.; brand, p.; huisman, h. effect of adding probabilistic zonal prior in deep learning-based prostate cancer detection. in proceedings of the medical imaging with deep learning (midl), london, uk, 8–10 july 2019. [',
#  'kendall, a.; badrinarayanan, v.; cipolla, r. bayesian segnet: model uncertainty in deep convolutional encoder-decoder architectures for scene understanding. in proceedings of the proceedings of the british machine vision conference (bmvc), london, uk, 4–7 september 2017. [',
#  'zadrozny, b.; elkan, c. transforming classifier scores into accurate multiclass probability estimates. in proceedings of the proceedings of the acm sigkdd international conference on knowledge discovery and data mining, edmonton, ab, canada, 23–26 july 2002; pp. 694–699. [',
#  'cuocolo, r.; stanzione, a.; castaldo, a.; de lucia, d.r.; imbriaco, m. quality control and whole-gland, zonal and lesion annotations for the prostatex challenge public dataset. ',
#  'picture: prostate imaging (multi-sequence mri and prostate histoscanning tm ) compared to transperineal ultrasound guided biopsy for significant prostate cancer risk evaluation case report form',
#  'dickinson, l.; ahmed, h.u.; allen, c.; barentsz, j.o.; carey, b.; futterer, j.j.; heijmink, s.w.; hoskin, p.j.; kirkham, a.; padhani, a.r.; et al. magnetic resonance imaging for the detection, localisation, and characterisation of prostate cancer: recommendations from a european consensus meeting. ',
#  'wang, n.n.; fan, r.e.; leppert, j.t.; ghanouni, p.; kunder, c.a.; brooks, j.d.; chung, b.i.; sonn, g.a. performance of multiparametric mri appears better when measured in patients who undergo radical prostatectomy. ',
#  'kingma, d.p.; ba, j. adam: a method for stochastic optimization. in proceedings of the international conference on learning representations, san diego, ca, usa, 7–9 may 2015. [',
#  'litjens, g.j.; barentsz, j.o.; karssemeijer, n.; huisman, h.j. clinical evaluation of a computer-aided diagnosis system for determining cancer aggressiveness in prostate mri. ',
#  'nice prostate cancer: diagnosis and management. national institute of health and care excellence: guidelines. 2019. available online: ',
#  'delong, e.r.; delong, d.m.; clarke-pearson, d.l. comparing the areas under two or more correlated receiver operating characteristic curves : a nonparametric approach. ',
#  'antonelli, m.; cardoso, m.j.; johnston, e.w.; appayya, m.b.; presles, b.; modat, m.; punwani, s.; ourselin, s. gas: a genetic atlas selection strategy in multi-atlas segmentation framework. ',
#  'borofsky, s.; george, a.k.; gaur, s.; bernardo, m.; greer, m.d.; mertan, f.v.; taffel, m.; moreno, v.; merino, m.j.; wood, b.j.; et al. what are we missing? false-negative cancers at multiparametric mr imaging of the prostate. ',
#  'littrup, p.j.; williams, c.r.; egglin, t.k.; kane, r.a. determination of prostate volume with transrectal us for cancer screening: part ii. accuracy of in vitro and in vivo techniques. ',
#  'brizmohun appayya, m.; adshead, j.; ahmed, h.u.; allen, c.; bainbridge, a.; barrett, t.; giganti, f.; graham, j.; haslam, p.; johnston, e.w.; et al. national implementation of multi-parametric magnetic resonance imaging for prostate cancer detection – recommendations from a uk consensus meeting. ',
#  'steenbergen, p.; haustermans, k.; lerut, e.; oyen, r.; de wever, l.; van den bergh, l.; kerkmeijer, l.g.w.; pameijer, f.a.; veldhuis, w.b.; van der voort van zyp, j.r.n.; et al. prostate tumor delineation using multiparametric magnetic resonance imaging: inter-observer variability and pathology validation. ',
#  ' autoprostate framework diagram. autoprostate consists of three modules: zone-segmenter (green), cspca-segmenter (blue), and report-generator (purple); solid boxes correspond to module computations, while dashed boxes correspond to module outputs. yellow boxes indicate autoprostate inputs from external sources. ',
#  ' autoprostate framework diagram. autoprostate consists of three modules: zone-segmenter (green), cspca-segmenter (blue), and report-generator (purple); solid boxes correspond to module computations, while dashed boxes correspond to module outputs. yellow boxes indicate autoprostate inputs from external sources.',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available: (',
#  ') distribution of abserr for psad calculated by autoprostate and the experienced radiologist; the ground-truth psad value used to compute the abserr for autoprostate and the experienced radiologist was calculated by dividing psa by the whole-prostate volume derived from the ground-truth whole-prostate segmentation. ',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available: (',
#  ') distribution of abserr for psad calculated by autoprostate and the experienced radiologist; the ground-truth psad value used to compute the abserr for autoprostate and the experienced radiologist was calculated by dividing psa by the whole-prostate volume derived from the ground-truth whole-prostate segmentation.',
#  ' picture dataset axial t2wi, adc map, cb2000 dwi, ground-truth lesion contour overlaid on t2wi, probability map overlaid on t2wi, and segmentation overlaid on t2wi: (a) 79-year-old man, psa 12.57 ng/ml, midgland pz gs 4 + 3 lesion, likert 5, autoprostate probability of cspca 100%; (b) 66-year-old man, psa 7.50 ng/ml, midgland pz gs 3 + 4 lesion, likert 3, autoprostate probability of cspca 65%; (c) 64-year-old man, psa 10.53 ng/ml, apex cg gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 95%; (d) 56-year-old man, psa 7.91 ng/ml, base cg gs 3 + 4 lesion, likert 4, autoprostate probability of cspca 66%; (e) 60-year-old man with stable rectal gas-induced magnetic susceptibility artefact on dwi, psa 6.15 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 88%; and (f) 73-year-old man with bowel peristalsis-induced magnetic susceptibility artifact, psa 4.09 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 49%. ',
#  ' picture dataset axial t2wi, adc map, cb2000 dwi, ground-truth lesion contour overlaid on t2wi, probability map overlaid on t2wi, and segmentation overlaid on t2wi: (a) 79-year-old man, psa 12.57 ng/ml, midgland pz gs 4 + 3 lesion, likert 5, autoprostate probability of cspca 100%; (b) 66-year-old man, psa 7.50 ng/ml, midgland pz gs 3 + 4 lesion, likert 3, autoprostate probability of cspca 65%; (c) 64-year-old man, psa 10.53 ng/ml, apex cg gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 95%; (d) 56-year-old man, psa 7.91 ng/ml, base cg gs 3 + 4 lesion, likert 4, autoprostate probability of cspca 66%; (e) 60-year-old man with stable rectal gas-induced magnetic susceptibility artefact on dwi, psa 6.15 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 88%; and (f) 73-year-old man with bowel peristalsis-induced magnetic susceptibility artifact, psa 4.09 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 49%.',
#  ' autoprostate report for a 64-year-old man with psa equal to 10.53 ng/ml who participated in the picture study. lesion 1 (probability of cspca equal to 95%) corresponds to a biopsy-proven gs 3+4 lesion, while lesion 2 and lesion 3 (probabilities of cspca equal to 46% and 7%, respectively) are false positives. ',
#  ' autoprostate report for a 64-year-old man with psa equal to 10.53 ng/ml who participated in the picture study. lesion 1 (probability of cspca equal to 95%) corresponds to a biopsy-proven gs 3+4 lesion, while lesion 2 and lesion 3 (probabilities of cspca equal to 46% and 7%, respectively) are false positives.',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available. ',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available.',
#  'abserr: absolute error; abs%err: absolute percentage error; iqr: interquartile range; max: maximum; min: minimum; psa: prostate-specific antigen; sd: standard deviation. ',
#  ' picture dataset cspca lesion detection metrics for the experienced radiologist and autoprostate. mean and standard deviation of false positives per patient were calculated using the 93 picture dataset patients who were biopsy-negative for cspca, rather than over all patients, due to limitations in the ground-truth. all other metrics shown are calculated at the lesion level for the 147 cspca lesions and 63 ncspca lesions. ',
#  ' picture dataset cspca lesion detection metrics for the experienced radiologist and autoprostate. mean and standard deviation of false positives per patient were calculated using the 93 picture dataset patients who were biopsy-negative for cspca, rather than over all patients, due to limitations in the ground-truth. all other metrics shown are calculated at the lesion level for the 147 cspca lesions and 63 ncspca lesions.',
#  '© 2021 by the authors. licensee mdpi, basel, switzerland. this article is an open access article distributed under the terms and conditions of the creative commons attribution (cc by) license (',
#  ' are solely those of the individual authors and contributors and not of the publisher and the editor(s). mdpi stays neutral with regard to jurisdictional claims in published maps and institutional affiliations. ',
#  'construction materials',
#  'electronic materials',
#  'materials',
#  'materials proceedings',
#  'methods and protocols',
#  'nanomaterials',
#  ' the statements, opinions and data contained in the journals are solely those of the individual authors and contributors and not of the publisher and the editor(s). mdpi stays neutral with regard to jurisdictional claims in published maps and institutional affiliations. ',
#  "(function(){window['__cf$cv$params']={r:'717ab4d6bb577697',m:'pugpch2z0ujqjtpqibdzr.vkizvcmd4jdho3_hetd94-1654618735-0-acjo/plnr+nbsdravaugjmqcs+smbpetas45yzd9m7uyxopyghgmq8w7hf1xeu7adj7hktapshcotkuud0gh/9jz2obx1gwncvftkb5leslq6z3vyt1qzr3wouz5bq+vdlykf5yqrmw1dzezriai9am=',s:[0x6b4cb4bde8,0x523482f19e],}})();"]

# %%
def lbracketcount(x): return x.count('{') < 4
def rbracketcount(x): return x.count('}') < 4
def tagcount(x): return x.count('"."') < 4
def hashcount(x): return x.count('#') < 4
def divcount(x): return x.count('</') < 4
def linecount(x): return x.count('||') < 4

# %%
cull_text = []

for x in keep_text:
    if lbracketcount(x) and rbracketcount(x) and tagcount(x) and hashcount(x) and divcount(x) and linecount(x):
        cull_text.append(x)
    else:
        continue
        
cull_text
# Out:
# [' all articles published by mdpi are made immediately available worldwide under an open access license. no special permission is required to reuse all or part of the article published by mdpi, including figures and tables. for articles published under an open access creative common cc by license, any part of the article may be reused without permission provided that the original article is clearly cited. ',
#  ' feature papers represent the most advanced research with significant potential for high impact in the field. feature papers are submitted upon individual invitation or recommendation by the scientific editors and undergo peer review prior to publication. ',
#  ' the feature paper can be either an original research article, a substantial novel research study that often involves several techniques or approaches, or a comprehensive review paper with concise and precise updates on the latest progress in the field that systematically reviews the most exciting advances in scientific literature. this type of paper provides an outlook on future directions of research or possible applications. ',
#  ' editor’s choice articles are based on recommendations by the scientific editors of mdpi journals from around the world. editors select a small number of articles recently published in the journal that they believe will be particularly interesting to authors, or important in this field. the aim is to provide a snapshot of some of the most exciting work published in the various research areas of the journal. ',
#  "  you seem to have javascript disabled. please note that many of the page functionalities won't work as expected without javascript enabled. ",
#  ' construction materials ',
#  ' electronic materials ',
#  ' materials ',
#  ' materials proceedings ',
#  ' methods and protocols (mps) ',
#  ' nanomaterials ',
#  'discussion',
#  'supplementary material',
#  'division of surgery and interventional science, faculty of medical sciences, university college london, london wc1e 6bt, uk',
#  ' international guidelines recommend multiparametric magnetic resonance imaging (mpmri) of the prostate for use by radiologists to identify lesions containing clinically significant prostate cancer, prior to confirmatory biopsy. automatic assessment of prostate mpmri using artificial intelligence algorithms holds a currently unrealized potential to improve the diagnostic accuracy achievable by radiologists alone, improve the reporting consistency between radiologists, and enhance reporting quality. in this work, we introduce autoprostate: a deep learning-powered framework for automatic mri-based prostate cancer assessment. in particular, autoprostate utilizes patient data and biparametric mri to populate an automatic web-based report which includes segmentations of the whole prostate, prostatic zones, and candidate clinically significant prostate cancer lesions, and in addition, several derived characteristics with clinical value are presented. notably, autoprostate performed well in external validation using the picture study dataset, suggesting value in prospective multicentre validation, with a view towards future deployment into the prostate cancer diagnostic pathway. ',
#  ' multiparametric magnetic resonance imaging (mpmri) of the prostate is used by radiologists to identify, score, and stage abnormalities that may correspond to clinically significant prostate cancer (cspca). automatic assessment of prostate mpmri using artificial intelligence algorithms may facilitate a reduction in missed cancers and unnecessary biopsies, an increase in inter-observer agreement between radiologists, and an improvement in reporting quality. in this work, we introduce autoprostate, a deep learning-powered framework for automatic mri-based prostate cancer assessment. autoprostate comprises of three modules: zone-segmenter, cspca-segmenter, and report-generator. zone-segmenter segments the prostatic zones on t2-weighted imaging, cspca-segmenter detects and segments cspca lesions using biparametric mri, and report-generator generates an automatic web-based report containing four sections: ',
#  '. in our experiment, autoprostate was trained using the publicly available prostatex dataset, and externally validated using the picture dataset. moreover, the performance of autoprostate was compared to the performance of an experienced radiologist who prospectively read picture dataset cases. in comparison to the radiologist, autoprostate showed statistically significant improvements in prostate volume and prostate-specific antigen density estimation. furthermore, autoprostate matched the cspca lesion detection sensitivity of the radiologist, which is paramount, but produced more false positive detections. ',
#  'automatic report; computer-aided diagnosis; convolutional neural network; deep learning; lesion detection; lesion classification; magnetic resonance imaging; prostate cancer; segmentation',
#  'radiologists use prostate multiparametric magnetic resonance imaging (mpmri) to detect, score, and stage lesions that may correspond to clinically significant prostate cancer (cspca), whose status can later be confirmed using mr-guided targeted biopsy and histopathological grading [',
#  ']. however, the current diagnostic approach must be improved to reduce the small proportion of men with cspca who are missed by mpmri, to reduce the large number of men who undergo unnecessary biopsies, and to increase the inter-observer agreement between readers [',
#  ']. in addition to lesion assessment, radiologists use prostate mpmri to estimate prostate volume using the ellipsoid formula [',
#  ']. primarily, prostate volume is required for calculating prostate-specific antigen density (psad), which has been shown to be a predictor of cspca [',
#  '], therefore more accurate volume estimation methods are sought. computer-aided diagnosis (cad) systems that use mpmri for prostate volume estimation and cspca lesion detection and/or segmentation may provide the desired performance improvements over current clinical practice.',
#  'automatic segmentation of the prostate may enable accurate prostate volume estimation. several automatic methods for prostate segmentation have been published [',
#  ']. foremost, the promise12 challenge has driven consistent improvements in the performance of prostate segmentation algorithms over the past decade [',
#  ']; an unpublished deep learning method named msd-net currently tops the leader board with a mean dice coefficient of 0.92 for whole-prostate segmentation. to the best of our knowledge, only the work by lee et al. [',
#  '] has compared prostate volume estimation using an automatic segmentation method to the clinically utilized ellipsoid formula. on a 70-patient test set, their 3d cnn for whole-prostate segmentation achieved a mean dice coefficient of 0.87 and a mean absolute percentage error (abs%err) of 11.78% for volume estimation, while the mean abs%err for the ellipsoid formula was 11.92%. in the discussion section of their paper, lee et al. mention the potential benefit of more accurate volume estimation methods on the calculation of psad, but their study stopped short of providing a quantitative comparison.',
#  'cad systems for lesion detection and segmentation are actively being investigated, as demonstrated by a vast and growing literature [',
#  '] directly compared cad systems for cspca lesion detection against radiologist mpmri assessment. cao et al. showed that their proposed focalnet convolutional neural network (cnn), trained using biparametric mri (bpmri), had a cspca lesion detection sensitivity of 87.9%, which was only 1.5% lower than pi-rads v2 scoring by three experienced radiologists who read a subset of cases each. their result was obtained from a fivefold cross-validation of 417 preoperative patients who later underwent radical prostatectomy. similarly, the study by schelb et al. showed that a u-net cnn [',
#  '] produced similar cspca detection performance to pi-rads v2 scoring by eight radiologists who each read a subset of cases. on the held-out test cohort of 62 men sampled from the same study cohort as the training data, their method achieved a patient-level sensitivity of 92% and specificity of 47%, while radiologist assessment yielded a sensitivity of 88% and a specificity of 50%; differences in sensitivity and specificity between the proposed cnn approach and radiologist scoring were not statistically significant. while the studies by cao et al. and schelb et al. evaluated cad systems using test data sampled from the same study cohort as the training data, the study by thon et al. [',
#  ' did not perform satisfactorily on external test data due to differences in the instrumentation and acquisition parameters used to collect training and test data. moreover, they remarked that optimistic performances of cad systems reported in other studies may be dataset-specific, and therefore advocated for the necessity of external validation of cad systems.',
#  'this work has two aims. the first aim is to introduce autoprostate: a deep learning-powered framework for automatic mri-based prostate cancer detection and assessment that we have developed. in particular, autoprostate segments the prostatic zones on t2-weighted imaging (t2wi), detects and segments cspca lesions using bpmri, and generates a novel automatic web-based report containing four sections: ',
#  ', which posits it close to clinical deployment. notably, autoprostate uses up-to-date deep learning techniques for training and inference, such as hybrid losses [',
#  '], and model ensembling, to enhance performance. the second aim of this work is to perform a high-quality single-centre external validation of autoprostate, as a first step towards clinical deployment, ahead of multicentre external validation and prospective validation in a clinical setting. in our experiment, autoprostate is trained using the publicly available prostatex dataset [',
#  '], and externally validated using the prostate imaging compared to transperineal ultrasound-guided biopsy for significant prostate cancer risk evaluation (picture) trial dataset [',
#  ']. the external validation follows the key considerations for authors, reviewers, and readers of ai manuscripts in radiology by bluemke et al. [',
#  ']. in particular, the external test set contains mris acquired using scanners manufactured by a different vendor to the scanners used to acquire the training set and is confirmed using transperineal template prostate-mapping (ttpm) biopsy, which avoids the biases associated with mr-guided targeted biopsy and prostatectomy [',
#  ']. furthermore, we compare the performance of autoprostate to the performance of an experienced radiologist who, at the time of the picture trial, had 10 years’ experience in reading prostate mpmri.',
#  ' 2. methods',
#  ', consists of three modules: zone-segmenter, cspca-segmenter, and report-generator. methodological aspects of each module are described in detail in the subsections to follow, while specific experimental parameters used to collect results are described in ',
#  't2w images are first resampled to a common in-plane resolution and cropped to a common in-plane shape, and then normalized by whitening of image voxel intensities.',
#  'after pre-processing, each t2wi slice is segmented by an ensemble of 2d nnu-nets with task-specific hyperparameter modifications; we refer to each constituent 2d nnu-net as zone-u-net and the ensemble of zone-u-nets as zone-u-net-e. a detailed description of the zone-u-net architecture is given in ',
#  '. the output of each zone-u-net is slice-wise pz, cg, and background probability maps. per-voxel averaging is used to combine the probability map outputs of each zone-u-net ∈ zone-u-net-e, followed by restacking of slices to form pz, cg, and background probability map volumes.',
#  'the pz, cg, and background probability maps output by zone-u-net-e are transformed to the original t2wi shape and voxel resolution using padding and resampling operations. as a final step, a zonal segmentation map is obtained from the pz, cg, and background probability maps using a per-voxel argmax operation.',
#  'the cspca-segmenter module detects and segments cspca lesions using each patient’s t2wi, apparent diffusion coefficient (adc) map, low b-value diffusion-weighted imaging (dwi), and pz and cg probability maps output by zone-segmenter.',
#  'image registration is used to align adc maps and computed high b-value dwi to t2wi to account for voluntary/involuntary patient movement between t2wi and dwi acquisitions and differences in resolution. first, adc maps are affinely registered to t2wi using the symmetric block matching algorithm [',
#  '], with the convolution-based fast local normalized correlation coefficient (lncc) similarity measure to enable robustness to bias field inhomogeneity [',
#  ']. finally, the transformation obtained from the composition of both types of registration is used to register computed high b-value dwi to t2wi.',
#  't2wi, registered adc map and computed high b-value dwi, and pz and cg probability maps are resampled to a common in-plane resolution and cropped to a common in-plane shape, centred on the prostate; image cropping is used for memory efficiency. then, t2wi and computed high b-value dwi are normalized by dividing voxel intensities by the interquartile mean of cg voxel intensities. our approach is a modification of the normalization approach suggested by bonekamp et al. [',
#  '], where voxel intensities were divided by the mean of pz voxel intensities. we opt for normalization using cg voxel intensities since cg segmentations are typically more reliable than pz segmentations [',
#  '], and we opt for the interquartile mean of cg voxel intensities as opposed to the mean of all cg voxel intensities, to remove extremes that may correspond to abnormalities unique to a patient. adc maps were not normalized as they contain a quantitative measurement.',
#  'after pre-processing, each slice of a patient’s t2wi, adc map, computed high b-value dwi, and pz and cg probability maps are input channel-wise to an ensemble of 2d nnu-nets for cspca lesion segmentation; the addition of pz and cg guidance as input has been shown to increase cspca lesion detection performance as the occurrence and appearance of prostate cancer is dependent on its zonal location [',
#  ']. we refer to each constituent 2d nnu-net as cspca-u-net and the ensemble of cspca-u-nets as cspca-u-net-e. a detailed description of the cspca-u-net architecture is given in ',
#  '], i.e., dropout layers are inserted after the central three encoder units and two decoder units, with dropout probability equal to p. we model aleatoric uncertainty using test-time augmentation as in wang et al. [',
#  'the output of each cspca-u-net is slice-wise cspca probability maps. per-voxel averaging is used to combine the probability map outputs of each cspca-u-net ∈ cspca-u-net-e, followed by restacking of slices to form a probability map volume.',
#  'the cspca probability map output by cspca-u-net-e is transformed to the original t2wi shape and voxel resolution using padding and resampling operations. next, probabilities are calibrated using an isotonic regression calibration module [',
#  '], to allow more interpretable cspca likelihoods. cspca lesion segmentations are obtained by thresholding cspca probability maps using a cut-off value c; c is chosen during experimentation using training data to match autoprostate’s detection sensitivity and specificity to that of an experienced radiologist. finally, a false-positive reduction step is applied to remove connected components smaller than minsize mm',
#  'the report-generator module generates an automatic report using input bpmri and clinical data, and the outputs of the zone-segmenter and cspca-segmenter modules; the report template is shown in ',
#  'the left-hand pane contains interactive report elements including a patient selector and transverse, frontal, and sagittal views of zone and cspca lesion segmentation outputs overlaid on t2wi, with associated widgets for slice selection.',
#  ' lengths of the prostate, in cm, are calculated using the maximum extents of the prostate on the whole-prostate segmentation, where the whole-prostate segmentation is the union of the pz and cg segmentations. ',
#  ' (base, midgland, or apex) are determined based on the location of the lesion centroid; our region determination follows the methodology outlined by litjens et al. [',
#  '] for evaluating the promise12 challenge, where the apex is defined as the caudal-most third of the prostate, the base is the cranio-most third of the prostate, and the midgland is the remaining portion. the ',
#  'in this section, we describe the datasets used for training and testing autoprostate, the methodological settings employed, and the evaluation measures used to assess performance.',
#  '], and externally validated using the prostate imaging compared to transperineal ultrasound-guided biopsy for significant prostate cancer risk evaluation (picture) study dataset [',
#  'mpmri was acquired using two 3-tesla magnetic field scanners (magnetom trio and skyra, siemens) and a pelvic-phased array coil. sequences collected included t2wi, adc map computed from dwi acquired at multiple b-values (50, 400, 800), and dcei with a temporal resolution of 3.5 s. all mpmri studies were reported by an experienced radiologist with over 20 years’ experience in reading prostate mpmri, who highlighted areas of suspicion per modality with a point marker and scored them using pi-rads v1. mr-guided targeted biopsies of marked points with pi-rads v1 score ≥ 3 were performed, while marked points with pi-rads v1 score 3 (unlikely for cspca) were not biopsied and assumed to be clinically insignificant (5% incidence of cspca in pi-rads v1 3 lesions at radboud university medical center). subsequently, biopsy specimens were graded by a histopathologist. the marked point coordinate and a ground-truth label (clinically significant equal to true or false) for each marked lesion was released publicly for 204 of the 346 patients, hence only these 204 patients feature in our work; clinical and histopathological characteristics are shown in ',
#  ']. in summary, contours were produced in consensus by radiology residents (2 years’ experience in reading prostate mpmri) and board-certified radiologists (5 years’ experience in reading prostate mpmri) at the university of naples. radiology residents and board-certified radiologists worked in pairs for quality control and annotation. whole-prostate and zonal contours (pz and cg) were drawn for each patient. in addition, 299 lesions were delineated, including 76 cspca lesions and 223 low-grade or benign lesions (ncspca).',
#  ']. men were examined at university college london hospital between 2012 and 2014. inclusion criteria for the picture study were: (i) men who had undergone an initial standard transrectal ultrasound-guided (trus) biopsy, but concern remained over the accuracy of the subsequent diagnosis; and (ii) men suitable for further characterization using transperineal template prostate-mapping (ttpm) biopsy. exclusion criteria were: (i) previous history of prostate cancer treatment; and (ii) lack of complete gland sampling or inadequate sampling density at ttpm.',
#  'mpmri was acquired using a 3-tesla magnetic field scanner (achieva, philips healthcare) and a pelvic-phased array coil. sequences collected included t2wi, dwi with high b-value (2000), adc map computed from dwi acquired at multiple b-values (0, 150, 500, 1000), and dcei with a temporal resolution of 13 s.',
#  'all mpmri studies were reported by an experienced radiologist with 10 years’ experience in reading prostate mpmri, using a five-point likert impression scale for the likelihood of cspca [',
#  ']; cspca was defined as gleason score ≥ 3 + 4. scoring was completed at the lesion, sector, and patient-levels. clinical information, including the referral psa (ng/ml), was available to the radiologist during scoring to reflect clinical practice. men underwent mr-guided targeted biopsy of focal index lesions and ttpm biopsy with 5 mm sampling as the reference standard. ttpm biopsy was used to overcome the inaccuracies of trus biopsy [',
#  'in this work, two patients were removed due to missing mri data. clinical and histopathological characteristics for the 247 included patients are shown in ',
#  'whole-prostate and zonal contours were drawn by a board-certified radiologist (e.w.j., 3 years’ experience in the quantitative analysis of prostate mpmri), for 80 patients. lesions were delineated by two board-certified radiologists (s.s. and n.g., 5 and 4-years’ experience in scoring prostate mpmri using likert assessment and pi-rads v2, respectively), who drew contours on a subset of cases each. the protocol for lesion contouring was agreed between the radiologists beforehand. first, histopathology reports from mr-guided targeted and ttpm biopsies were reviewed alongside mpmri to locate the highest gleason grade focal lesion; if there were multiple focal lesions with the maximum gleason grade, the highest scoring focal lesion according to likert or pi-rads v2 was identified. next, a single axial t2wi slice was selected corresponding to the centre of the identified lesion. then, all focal lesions on the selected slice were contoured. additionally, focal benign lesions that were scored likert or pi-rads v2 ≥ 4 were contoured in patients that were biopsy-negative for cancer. a total of 210 lesions were delineated, including 147 cspca lesions and 63 ncspca lesions.',
#  ' 3.2. methodological settings',
#  'a tenfold cross-validation analysis of zone-u-net was conducted using the prostatex dataset to optimize training hyperparameters, loss function, and augmentations. fold splits are shown in ',
#  '. zone-u-net performed optimally when trained for 50 epochs with learning rate equal to 0.0001, batch size equal to eight, adam optimization [',
#  'following the tenfold cross-validation, the ten trained zone-u-nets were used to construct zone-u-net-e; cross-validation ensembles have been shown to be an effective ensembling strategy [',
#  'the registration of adc maps to t2wi employed default parameters for affine registration via symmetric block-matching. the subsequent non-rigid ffd registration used a gaussian kernel with standard deviation equal to 5 mm for lncc calculation, control point spacing equal to 10 mm, and bending energy constraint equal to 0.1. registrations were run using niftyreg (version 1.3; available online: ',
#  ' (accessed on 1 october 2018). through visual inspection, satisfactory registration was observed for the majority of prostatex and picture dataset cases. no manual steps were taken to correct any instances of misregistration, and cases with misregistration were not excluded from our analysis.',
#  't2wi, registered adc maps and computed b2000 (cb2000) dwi, and pz and cg probability maps, were resampled to a common in-plane resolution of 0.4018 mm × 0.4018 mm and cropped to a common in-plane shape of 256 × 256, centred on the prostate.',
#  'like zone-u-net, the training settings for cspca-u-net were determined through tenfold cross-validation using the prostatex dataset with the fold splits shown in ',
#  '. cspca-u-net performed optimally when trained for 50 epochs with learning rate equal to 0.0001, batch size equal to 12, adam optimization, a dropout probability of ',
#  ' for central dropout, a hybrid loss composed of the sum of dice loss multiplied by 0.5 and focal loss multiplied by 1.0, and horizontal flip (probability = 0.5), rotation (−20°, 20°), and scaling (−10%, +20%) augmentations. the same dropout probability and augmentation settings were used for test-time dropout and test-time augmentation.',
#  'cspca probability maps output by cspca-u-net for each fold were calibrated using separate isotonic calibration modules for each fold. following calibration, cspca probability maps were thresholded using cut-off values determined for each fold, corresponding to a lesion-level sensitivity of 93% and specificity of 37%, in the fold’s training set. the aforementioned sensitivity and specificity correspond to reference radiologist performance at pi-rads v1 cut-off ≥ 4 on a separate patient cohort from radboud medical center, reported on in litjens et al. [',
#  '], which was used since prospective radiologist performance was not available for the prostatex dataset. as a final post-processing step, connected components smaller than 40 mm',
#  'following the tenfold cross-validation, the ten trained cspca-u-nets were used to construct cspca-u-net-e. cspca-u-net-e was calibrated using isotonic calibration. for thresholding, a cut-off value c = 4.5% was determined to match radiologist performance in the training set for cspca-u-net-e i.e., the entire prostatex dataset. for false-positive reduction, connected components smaller than 40 mm',
#  'whole-prostate and zonal segmentations were evaluated using the dice coefficient. prostate size measurements (transverse, anterior–posterior, and cranio–caudal lengths), as well as whole-prostate and zonal volumes, were evaluated using the abs%err; the ground-truth lengths and volumes used in the calculation of abs%err were derived from the manually-drawn whole-prostate and zonal contours. the psad estimated by autoprostate was evaluated using absolute error (abserr), since the absolute value of psad has a meaning relative to risk definitions [',
#  ']; the ground-truth psad value used in the calculation of abserr was obtained by dividing psa by the whole-prostate volume calculated using the manually-drawn whole-prostate contour. the aforementioned evaluation metrics were calculated over the 80 patients from the picture dataset for which manually drawn whole-prostate and zonal segmentations were available.',
#  'receiver operating characteristic (roc) area under the curve (auc) and precision-recall (pr) auc were calculated to quantify autoprostate’s ability to differentiate between cspca lesions and ncspca lesions. after thresholding and false-positive reduction, sensitivity, specificity, and precision were calculated at lesion-level and average false positives were calculated at patient-level. for the picture dataset, the calculation of average false positives was made using 93 patients who were biopsy-negative for cspca, due to limitations in the ground-truth prohibiting false-positive determination in biopsy positive patients. in addition, cspca lesion dice and abs%err of lesion area were calculated on slices containing a contour.',
#  'prostate volume, psad, and lesion detection metrics computed for autoprostate were compared to the same metrics calculated for an experienced radiologist (s.p., 10 years’ experience in scoring prostate mpmri) who prospectively filled out a case report for each patient. prostate volume was estimated using the ellipsoid formula and lesions were scored using a five-point likert scale [',
#  ']. statistical tests were used to compare the performances of autoprostate and the experienced radiologist. the wilcoxon’s signed-rank test [',
#  '] was used to statistically compare precision, and wilcoxon’s signed-rank test was used to statistically compare average false positives.',
#  ' 4. results',
#  'autoprostate, trained using the prostatex dataset, was externally validated using the picture dataset. this section presents the results of the cross-validation of zone-u-net and cspca-u-net (the building blocks of autoprostate) and a detailed analysis of the external validation of autoprostate using the picture dataset, with comparisons made to the performance of an experienced radiologist with 10 years’ experience in reading prostate mpmri, where possible.',
#  '., cspca-u-net achieved a mean roc auc of 0.85 and a mean pr auc of 0.70. after thresholding, cspca-u-net achieved a mean sensitivity of 93%, a mean specificity of 37%, a mean precision of 34%, and a mean false-positive count per patient of 6.9. following false-positive reduction, mean sensitivity dropped marginally to 92%, mean specificity increased to 46%, mean precision increased to 37%, and mean false positives per patient dropped significantly to 3.3 (',
#  ' 4.2. autoprostate external validation analysis: whole-prostate and zonal segmentations, prostate size measurements, and psa density',
#  ' present summaries of the distribution of dice coefficients for whole-prostate and zonal segmentations, the distribution of abs%err for prostate size measurements, and the distribution of abserr for psad calculation, for 80 patients from the picture dataset for which ground-truth segmentations were available.',
#  'mean dice coefficients of 0.75, 0.80, and 0.89 were obtained for the pz, cg, and whole-prostate, respectively. autoprostate’s zone-segmenter module found pz segmentation a more difficult task than cg segmentation, while whole-prostate segmentation had a higher mean dice coefficient than both zonal segmentations, suggesting an ease of distinguishing prostate tissue from background tissues, but a difficulty in distinguishing between pz and cg tissue. as expected, the mean dice coefficients for the pz, cg, and whole-prostate segmentations were lower than those obtained on the prostatex dataset during the tenfold cross-validation of zone-u-net (0.78, 0.86, and 0.91 for pz, cg, and whole-prostate segmentation, respectively) which may be indicative of a generalization gap due to acquisition/population differences.',
#  'the transverse, anterior–posterior, and cranio–caudal lengths of the prostate were estimated using the whole-prostate segmentation output by zone-segmenter. mean abs%err of 3%, 5%, and 20% were obtained for transverse, anterior–posterior, and cranio–caudal lengths, respectively. in addition to the lowest mean abs%err, the transverse length had a smaller standard deviation than anterior–posterior and cranio–caudal lengths. through visual inspection of segmentation outputs, we attribute the variability in the accuracy of the anterior–posterior measurement to the difficulty of determining prostate extent in the anterior fibromuscular stroma, and similarly, we attribute the variability in the accuracy of the cranio–caudal measurement to the difficulty of determining prostate extent at the base and apex regions of the prostate. strikingly, a large maximum abs%err of 100% was observed for the cranio–caudal measurement, due to under-segmentation of the base region in the ground-truth.',
#  'pz, cg, and whole-prostate volumes were calculated using the pz, cg, and whole-prostate segmentations output by zone-segmenter. mean abs%errs of 12%, 18%, and 9% were obtained for pz, cg, and whole-prostate volumes, respectively. strikingly, a large maximum abs%err of 112% was observed for the cg, which was found to be due to over-segmentation of the cg in the base region.',
#  'we compare the abs%err of the whole-prostate volume calculated by autoprostate to the same calculated by the experienced radiologist who used the ellipsoid formula, which is clinically advocated. autoprostate had a mean abs%err of 9%, while the experienced radiologist’s mean abs%err was 13%; the difference was statistically significant (',
#  ' 0.05). using the whole-prostate volumes computed by autoprostate and the experienced radiologist, psad was calculated. autoprostate achieved a mean abserr of 0.019, while the experienced radiologist’s mean abserr was 0.031; again, the difference was statistically significant (',
#  ' 4.3. autoprostate external validation analysis: clinically significant prostate cancer lesion detection and segmentation',
#  'autoprostate achieved a mean roc auc of 0.70 and a mean pr auc of 0.84, calculated using output cspca probability maps prior to thresholding. after thresholding the cspca probability maps using a cut-off value equal to 4.5%, the following were obtained: a sensitivity of 78%, a specificity of 49%, a precision of 78%, and a mean false-positive count of 6.1. following false-positive reduction, mean sensitivity dropped marginally to 76%, mean specificity increased to 57%, mean precision increased marginally to 80%, and the mean false-positive count per patient dropped to 2.5.',
#  'likert scores assigned to suspicious lesions by the experienced radiologist were used to calculate roc and pr curves; radiologist likert scoring gave a roc auc of 0.64 and pr auc of 0.78. after thresholding at cut-off score likert ≥ 4, the following were obtained: a sensitivity of 78%, a specificity of 48%, a precision of 78%, and a mean false-positive count of 0.3. differences between the roc auc, pr auc, sensitivity, specificity, and precision of autoprostate and the experienced radiologist were not statistically significant. however, the difference between mean false positives was statistically significant (',
#  'a further analysis was completed to assess the level of agreement between autoprostate and the experienced radiologist’s likert scores, on annotated lesions, as shown in ',
#  '. for cspca lesions, there was a 78% (114/147) concordance between autoprostate and the experienced radiologist, while for ncspca lesions, there was a 62% (39/63) concordance.',
#  'autoprostate’s lesion segmentations enable the calculation of lesion volume and lesion minimum adc. lesion segmentation accuracy, evaluated using the dice coefficient, was calculated using slices containing a corresponding ground-truth cspca lesion contour. the following dice coefficient metrics were obtained: a mean of 0.46 (sd: 0.32), a median of 0.58 (iqr: 0.10–0.72), and a min–max range of 0.00–0.90. several example cspca lesion segmentations are presented in ',
#  '. examples are shown in the pz and cg, and in the base, midgland, and apex regions of the prostate. in addition, examples have been included to demonstrate autoprostate’s robustness to magnetic susceptibility artifacts. furthermore, an example automatic report generated by autoprostate is shown in ',
#  ' 5. discussion',
#  'in this work, we introduced autoprostate, a deep learning-powered framework for automatic mri-based prostate cancer assessment. autoprostate consists of three modules: zone-segmenter, cspca-segmenter, and report-generator. the output of autoprostate is an automatic web-based report that presents patient details, prostate size measurements and psad, a listing of candidate cspca lesions with derived characteristics, and a findings summary. autoprostate, trained using the publicly available prostatex dataset, was externally validated using the picture dataset. during the external validation, the performance of autoprostate was compared to the performance of an experienced radiologist with 10 years’ experience in reading prostate mpmri, who prospectively estimated prostate volume and psad using the ellipsoid formula, and scored lesions using a five-point likert scale.',
#  'pz, cg, and whole-prostate segmentations are output by autoprostate’s zone-segmenter module. during the experimental setup phase, we tested zone-u-net, prior to ensembling of zone-u-nets to form zone-u-net-e. zone-u-net achieved mean dice coefficients of 0.78, 0.86, and 0.91 for pz, cg, and whole-prostate segmentation, respectively, in tenfold cross-validation using the prostatex dataset. our result compares well to recent works by aldoj et al. [',
#  '], where their proposed dense-2 u-net cnn was evaluated using fourfold cross-validation of a 188-patient subset from the prostatex dataset, and to a recent work by cuocolo et al. [',
#  '] was evaluated using a 105-patient test set from the prostatex dataset. aldoj et al. obtained mean dice coefficients of 0.78, 0.91, and 0.92, and cuocolo et al. obtained mean dice coefficients of 0.71, 0.87, and 0.91, for pz, cg, and whole-prostate segmentation, respectively. however, direct comparison between our work and the works of aldoj et al. and cuocolo et al. is not possible due to the use of different subsets of data for testing. during the external validation of autoprostate using the picture dataset, where zone-u-net-e was used for pz, cg, and whole-prostate segmentation, autoprostate achieved mean dice coefficients of 0.75, 0.80, and 0.89, respectively, on 80 patients for which ground-truth segmentations were available. antonelli et al. [',
#  '] previously reported segmentation results for the picture dataset. a multi-atlas segmentation approach featuring a novel genetic atlas selection strategy was proposed; mean dice coefficients of 0.72 and 0.83 were reported for pz and cg segmentation, using leave-one-out cross-validation, and a mean dice coefficient of 0.83 was reported for whole-prostate segmentation, using atlases from the promise12 dataset [',
#  ']. autoprostate’s estimate of prostate volume was compared to an estimate obtained using the ellipsoid formula, which is clinically advocated [',
#  ']. autoprostate achieved a mean abs%err of 9%, while the radiologist computed ellipsoid formula estimate had a mean abs%err of 13%. notably, the difference in mean abs%err was statistically significant (',
#  '. furthermore, we compared psad estimates obtained using the volume estimates; we found a mean abserr of 0.019 for autoprostate and a mean abserr of 0.031 for the radiologist; again, the difference was statistically significant (',
#  'autoprostate’s foremost purpose is to detect and segment cspca lesions. during the experimental setup phase, we tested cspca-u-net, prior to ensembling of cspca-u-nets to form cspca-u-net-e. markedly, cspca-u-net achieved a lesion-level mean roc auc of 0.85 in tenfold cross-validation using the prostatex dataset, while previous studies have reported a lesion-level mean roc auc of 0.81 on the same subset of prostatex data used in this study, using the same input modalities. during the external validation of autoprostate using the picture dataset, where cspca-u-net-e was used to segment cspca lesions, autoprostate achieved a lesion-level roc auc of 0.70. notably, we observed a large reduction in roc auc on the picture dataset from that seen during the prostatex dataset tenfold cross-validation. we believe that the main reason for the reduction in roc auc is the use of ttpm biopsy in the picture study, which allowed lesions that were not prospectively identified by the radiologist, to be retrospectively contoured using ttpm biopsy findings. other reasons may include a high occurrence of magnetic susceptibility artifacts on dwi in the picture dataset and a possible generalization gap between training data and external testing data due to population/acquisition differences. on the picture dataset, radiologist likert assessment achieved a lesion-level roc auc of 0.64; the difference in roc auc between autoprostate and the experienced radiologist was not statistically significant. following thresholding and false-positive reduction, autoprostate achieved a lesion-level sensitivity of 76%, a lesion-level specificity of 57%, and 2.5 false positives per patient (calculated over patients without cspca, only). in comparison, radiologist likert assessment thresholded at likert ≥ 4, achieved a lesion-level sensitivity of 78%, a lesion-level specificity of 48%, and 0.3 false positives per patient (calculated over patients without cspca, only); only the difference between the number of false positive detections by autoprostate and the experienced radiologist was statistically significant (',
#  '). while autoprostate has demonstrated an ability to differentiate between cspca lesions and low-grade/benign lesions at the level of an experienced radiologist, further work is needed to reduce the number of false positives produced. interestingly, autoprostate achieved a similar sensitivity and improved specificity compared to the radiologist on annotated cspca and ncspca lesions but had a higher overall false-positive count. therefore, it’s possible that the additional false positives produced by autoprostate, that were not prospectively scored by the radiologist, may be easy for radiologists to rule-out.',
#  'several aspects of this study have been guided by the set of nine key considerations for authors, reviewers, and readers of artificial intelligence studies in radiology by bluemke et al. [',
#  ']. as recommended, we maintained a clear separation between training data and testing data. in particular, we avoided a common pitfall observed in previous studies [',
#  '], by determining the probability cut-off value using training data, rather than a biased approach involving the test data itself. in line with further recommendations by bluemke et al., we were able to externally validate autoprostate using the picture dataset. furthermore, the picture dataset was acquired using phillips’ scanners, while the prostatex dataset, used to train autoprostate, was acquired using siemens’ scanners, meaning a further recommendation on using multivendor data for evaluation was met. moreover, we compared autoprostate to an expert radiologist who prospectively reported picture dataset patients, and both autoprostate and the radiologist were compared to an accepted reference standard which combined ttpm and mr-guided targeted biopsies; ttpm biopsy is highly accurate and avoids biases associated to mr-guided targeted biopsy, transrectal ultrasound-guided (trus) biopsy, and prostatectomy [',
#  'cad system studies should describe how the cad system will be deployed clinically, so future prospective trials can be planned accordingly. our goal in this study was to understand the strengths, weaknesses, and idiosyncrasies of autoprostate through a comparison against an experienced radiologist. in the clinical workflow, we envision autoprostate as a radiologist companion system during clinical reads to allow enhanced clinical reporting. it should be acknowledged that current cad systems for mri-based prostate cancer diagnosis contain varying degrees of error in terms of producing too many false positives, false negatives, or both. since the automatic report produced by autoprostate presents visual segmentation outputs, as well as derived measurements, all outputs produced by autoprostate can be rapidly verified by the radiologist. in particular, automatic report information deemed to be accurate can be used to prepare the patient’s clinical report, while erroneous information can be recalculated using current clinical methods or ignored if not required.',
#  'there were three limitations in our study. firstly, our training data was limited to 76 cspca lesions and 223 ncspca lesions; we may expect improved detection sensitivity and reduced false positives if a bigger training dataset with more lesions is available. secondly, our external validation was limited to a single external site. thirdly, lesion contours for each picture dataset patient were drawn by a single radiologist only. while the location and gleason score of lesions was confirmed by a combination of ttpm and mr-guided targeted biopsies, we were not able to overcome the inter-reader variation known to exist in lesion boundary determination [',
#  'our future work will be to perform a prospective validation of autoprostate. in particular, we will plan a clinical trial that investigates the impact of the automatic report on the prospective clinical read of radiologists of varying levels of experience. in preparation for the prospective validation, we will seek a larger multi-centre and multi-vendor training dataset.',
#  ' 6. conclusions',
#  'in this work, we presented autoprostate for automatic mri-based prostate cancer assessment. external validation using the picture dataset demonstrated statistically significant improvements in prostate volume and psa density estimation and no statistically significant differences in cspca lesion detection performance, when compared to an experienced radiologist with over 10 years’ experience in reading prostate mpmri. however, further work is needed to reduce the number of false positives produced by autoprostate, prior to prospective validation.',
#  ' supplementary materials',
#  ', section s1: zone-u-net architecture, section s2: cspca-u-net architecture, table s1: prostatex dataset characteristics, table s2: picture dataset characteristics, table s3: ten-fold cross-validation fold split of the prostatex dataset. lesion significance, size, and zone were used for fold stratification.',
#  'conceptualization, p.m., m.a. and s.o.; methodology, p.m. and m.a.; software, p.m.; formal analysis, p.m. and m.a.; data curation, p.m., m.a., s.s., n.g., e.w.j., h.u.a., m.e. and s.p.; writing—original draft preparation, p.m.; writing—review and editing, p.m., m.a., s.s., n.g., e.w.j., h.u.a., m.e., s.p. and s.o.; supervision, m.a., s.p. and s.o. all authors have read and agreed to the published version of the manuscript.',
#  'our institutional review board approved the study and waived the requirement for individual consent for retrospective analysis of prospectively acquired patient data collected as part of clinical trials/routine care (rd no: 12/0195, 16 july 2012).',
#  'prostatex dataset data citation: geert litjens, oscar debats, jelle barentsz, nico karssemeijer, and henkjan huisman. “prostatex challenge data”, the cancer imaging archive (2017). doi: 10.7937/k9tcia.2017.murs5cl. prostatex dataset masks citation: r. cuocolo, a. stanzione, a. castaldo, d.r. de lucia, m. imbriaco, quality control and whole-gland, zonal and lesion annotations for the prostatex challenge public dataset, eur. j. radiol. (2021).',
#  'p.m.’s research is supported by the engineering and physical sciences research council (epsrc) [ep/r512400/1]. p.m.’s work was additionally supported by the epsrc-funded ucl centre for doctoral training in intelligent, integrated imaging in healthcare (i4health) [ep/s021930/1]. m.a.’s research is supported by the wellcome/epsrc centre for medical engineering king’s college london and by the london medical imaging and ai centre for value-based healthcare. h.u.a.’s research is supported by core funding from the uk’s national institute of health research (nihr) imperial biomedical research centre. hua currently also receives funding from the wellcome trust, medical research council (uk), cancer research uk, prostate cancer uk, the urology foundation, bma foundation, imperial health charity, sonacare inc., trod medical and sophiris biocorp for trials in prostate cancer. m.e. and s.p. receive research support from the university college london/university college london hospital (ucl/uclh) biomedical research centre.',
#  'h.u.a. is a paid consultant to boston scientific for teaching and training on rezum for benign prostate hyperplasia treatment and cryotherapy for prostate cancer treatment and is paid for teaching and proctoring hifu for treating prostate cancer. m.e. receives honoraria from consulting, educational activities, and training from: sonacare inc.; nina medical; and angiodynamics inc. all other authors declare no conflicts of interest.',
#  'ahmed, h.u.; el-shater bosaily, a.; brown, l.c.; gabe, r.; kaplan, r.; parmar, m.k.; collaco-moraes, y.; ward, k.; hindley, r.g.; freeman, a.; et al. diagnostic accuracy of multi-parametric mri and trus biopsy in prostate cancer (promis): a paired validating confirmatory study. ',
#  'brembilla, g.; dell’oglio, p.; stabile, a.; damascelli, a.; brunetti, l.; ravelli, s.; cristel, g.; schiani, e.; venturini, e.; grippaldi, d.; et al. interreader variability in prostate mri reporting using prostate imaging reporting and data system version 2.1. ',
#  'stanzione, a.; ponsiglione, a.; di fiore, g.a.; picchi, s.g.; di stasi, m.; verde, f.; petretta, m.; imbriaco, m.; cuocolo, r. prostate volume estimation on mri: accuracy and effects of ellipsoid and bullet-shaped measurements on psa density. ',
#  'distler, f.a.; radtke, j.p.; bonekamp, d.; kesch, c.; schlemmer, h.-p.; wieczorek, k.; kirchner, m.; pahernik, s.; hohenfellner, m.; hadaschik, b.a. the value of psa density in combination with pi-rads',
# ...
#  'milletari, f.; navab, n.; ahmadi, s. v-net: fully convolutional neural networks for volumetric medical image segmentation. in proceedings of the fourth international conference on 3d vision (3dv), stanford, ca, usa, 25–28 october 2016. [',
#  'comelli, a.; dahiya, n.; stefano, a.; vernuccio, f.; portoghese, m.; cutaia, g.; bruno, a.; salvaggio, g.; yezzi, a. deep learning-based methods for prostate segmentation in magnetic resonance imaging. ',
#  'lee, d.k.; sung, d.j.; kim, c.-s.; heo, y.; lee, j.y.; park, b.j.; kim, m.j. three-dimensional convolutional neural network for prostate mri segmentation and comparison of prostate volume measurements by use of artificial neural network and ellipsoid formula. ',
#  'litjens, g.; toth, r.; van de ven, w.; hoeks, c.; kerkstra, s.; van ginneken, b.; vincent, g.; guillard, g.; birbeck, n.; zhang, j.; et al. evaluation of prostate segmentation algorithms for mri: the promise12 challenge. ',
#  'cao, r.; mohammadian bajgiran, a.; afshari mirak, s.; shakeri, s.; zhong, x.; enzmann, d.; raman, s.; sung, k. joint prostate cancer detection and gleason score prediction in mp-mri via focalnet. ',
#  'giannini, v.; mazzetti, s.; armando, e.; carabalona, s.; russo, f.; giacobbe, a.; muto, g.; regge, d. multiparametric magnetic resonance imaging of the prostate with computer-aided detection: experienced observer performance study. ',
#  'schelb, p.; kohl, s.; radtke, j.p.; wiesenfarth, m.; kickingereder, p.; bickelhaupt, s.; kuder, t.a.; stenzinger, a.; hohenfellner, m.; schlemmer, h.-p.; et al. classification of cancer at prostate mri: deep learning versus clinical pi-rads assessment. ',
#  'thon, a.; teichgraber, u.; tennstedt-schenk, c.; hadjidemetriou, s.; winzler, s.; malich, a.; papageorgiou, i. computer aided detection in prostate cancer diagnostics: a promising alternative to biopsy? a retrospective study from 104 lesions with histological ground truth. ',
#  'greer, m.d.; lay, n.; shih, j.h.; barrett, t.; bittencourt, l.k.; borofsky, s.; kabakus, i.; law, y.m.; marko, j.; shebel, h.; et al. computer-aided diagnosis prior to conventional interpretation of prostate mpmri: an international multi-reader study. ',
#  'gaur, s.; lay, n.; harmon, s.a.; doddakashi, s.; mehralivand, s.; argun, b.; barrett, t.; bednarova, s.; girometti, r.; karaarslan, e.; et al. can computer-aided diagnosis assist in the identification of prostate cancer on prostate mri? a multi-center, multi-reader investigation. ',
#  'zhu, l.; gao, g.; liu, y.; han, c.; liu, j.; zhang, x.; wang, x. feasibility of integrating computer-aided diagnosis with structured reports of prostate multiparametric mri. ',
#  'ronneberger, o.; fischer, p.; brox, t. u-net: convolutional networks for biomedical image segmentation. in proceedings of the international conference on medical image computing and computer-assisted intervention, munich, germany, 5–9 october 2015; springer: cham, switzerland, 2015; pp. 234–241. [',
#  'zhu, w.; huang, y.; zeng, l.; chen, x.; liu, y.; qian, z.; du, n.; fan, w.; xie, x. anatomynet: deep learning for fast and fully automated whole-volume segmentation of head and neck anatomy. ',
#  'gal, y.; ghahramani, z. dropout as a bayesian approximation: representing model uncertainty in deep learning. in proceedings of the 33rd international conference on machine learning, icml 2016, new york, ny, usa, 20–22 june 2016; volume 48, pp. 1651–1660. [',
#  'wang, g.; li, w.; aertsen, m.; deprest, j.; ourselin, s.; vercauteren, t. aleatoric uncertainty estimation with test-time augmentation for medical image segmentation with convolutional neural networks. ',
#  'simmons, l.a.m.; kanthabalan, a.; arya, m.; briggs, t.; barratt, d.; charman, s.c.; freeman, a.; gelister, j.; hawkes, d.; hu, y.; et al. the picture study: diagnostic accuracy of multiparametric mri in men requiring a repeat prostate biopsy. ',
#  'bluemke, d.a.; moy, l.; bredella, m.a.; ertl-wagner, b.b.; fowler, k.j.; goh, v.j.; halpern, e.f.; hess, c.p.; schiebler, m.l.; weiss, c.r. assessing radiology research on artificial intelligence: a brief guide for authors, reviewers, and readers-from the radiology editorial board. ',
#  'verma, s.; sarkar, s.; young, j.; venkataraman, r.; yang, x.; bhavsar, a.; patil, n.; donovan, j.; gaitonde, k. evaluation of the impact of computed high b-value diffusion-weighted imaging on prostate cancer detection. ',
#  'blackledge, m.d.; leach, m.o.; collins, d.j.; koh, d.-m.; may, i.; tumor, i.; blackledge, m.d.; leach, m.o.; collins, d.j. computed diffusion-weighted mr imaging may improve tumor detection. ',
#  'modat, m.; ridgway, g.r.; taylor, z.a.; lehmann, m.; barnes, j.; hawkes, d.j.; fox, n.c.; ourselin, s. fast free-form deformation using graphics processing units. ',
#  'comput. methods programs biomed.',
#  'bonekamp, d.; kohl, s.; wiesenfarth, m.; schelb, p.; radtke, j.p.; gotz, m.; kickingereder, p.; yaqubi, k.; hitthaler, b.; gahlert, n.; et al. radiomic machine learning for characterization of prostate lesions with mri: comparison to adc values. ',
#  'isensee, f.; petersen, j.; klein, a.; zimmerer, d.; jaeger, p.f.; kohl, s.; wasserthal, j.; koehler, g.; norajitra, t.; wirkert, s.; et al. nnu-net: self-adapting framework for u-net-based medical image segmentation. ',
#  'hosseinzadeh, m.; brand, p.; huisman, h. effect of adding probabilistic zonal prior in deep learning-based prostate cancer detection. in proceedings of the medical imaging with deep learning (midl), london, uk, 8–10 july 2019. [',
#  'kendall, a.; badrinarayanan, v.; cipolla, r. bayesian segnet: model uncertainty in deep convolutional encoder-decoder architectures for scene understanding. in proceedings of the proceedings of the british machine vision conference (bmvc), london, uk, 4–7 september 2017. [',
#  'zadrozny, b.; elkan, c. transforming classifier scores into accurate multiclass probability estimates. in proceedings of the proceedings of the acm sigkdd international conference on knowledge discovery and data mining, edmonton, ab, canada, 23–26 july 2002; pp. 694–699. [',
#  'cuocolo, r.; stanzione, a.; castaldo, a.; de lucia, d.r.; imbriaco, m. quality control and whole-gland, zonal and lesion annotations for the prostatex challenge public dataset. ',
#  'picture: prostate imaging (multi-sequence mri and prostate histoscanning tm ) compared to transperineal ultrasound guided biopsy for significant prostate cancer risk evaluation case report form',
#  'dickinson, l.; ahmed, h.u.; allen, c.; barentsz, j.o.; carey, b.; futterer, j.j.; heijmink, s.w.; hoskin, p.j.; kirkham, a.; padhani, a.r.; et al. magnetic resonance imaging for the detection, localisation, and characterisation of prostate cancer: recommendations from a european consensus meeting. ',
#  'wang, n.n.; fan, r.e.; leppert, j.t.; ghanouni, p.; kunder, c.a.; brooks, j.d.; chung, b.i.; sonn, g.a. performance of multiparametric mri appears better when measured in patients who undergo radical prostatectomy. ',
#  'kingma, d.p.; ba, j. adam: a method for stochastic optimization. in proceedings of the international conference on learning representations, san diego, ca, usa, 7–9 may 2015. [',
#  'litjens, g.j.; barentsz, j.o.; karssemeijer, n.; huisman, h.j. clinical evaluation of a computer-aided diagnosis system for determining cancer aggressiveness in prostate mri. ',
#  'nice prostate cancer: diagnosis and management. national institute of health and care excellence: guidelines. 2019. available online: ',
#  'delong, e.r.; delong, d.m.; clarke-pearson, d.l. comparing the areas under two or more correlated receiver operating characteristic curves : a nonparametric approach. ',
#  'antonelli, m.; cardoso, m.j.; johnston, e.w.; appayya, m.b.; presles, b.; modat, m.; punwani, s.; ourselin, s. gas: a genetic atlas selection strategy in multi-atlas segmentation framework. ',
#  'borofsky, s.; george, a.k.; gaur, s.; bernardo, m.; greer, m.d.; mertan, f.v.; taffel, m.; moreno, v.; merino, m.j.; wood, b.j.; et al. what are we missing? false-negative cancers at multiparametric mr imaging of the prostate. ',
#  'littrup, p.j.; williams, c.r.; egglin, t.k.; kane, r.a. determination of prostate volume with transrectal us for cancer screening: part ii. accuracy of in vitro and in vivo techniques. ',
#  'brizmohun appayya, m.; adshead, j.; ahmed, h.u.; allen, c.; bainbridge, a.; barrett, t.; giganti, f.; graham, j.; haslam, p.; johnston, e.w.; et al. national implementation of multi-parametric magnetic resonance imaging for prostate cancer detection – recommendations from a uk consensus meeting. ',
#  'steenbergen, p.; haustermans, k.; lerut, e.; oyen, r.; de wever, l.; van den bergh, l.; kerkmeijer, l.g.w.; pameijer, f.a.; veldhuis, w.b.; van der voort van zyp, j.r.n.; et al. prostate tumor delineation using multiparametric magnetic resonance imaging: inter-observer variability and pathology validation. ',
#  ' autoprostate framework diagram. autoprostate consists of three modules: zone-segmenter (green), cspca-segmenter (blue), and report-generator (purple); solid boxes correspond to module computations, while dashed boxes correspond to module outputs. yellow boxes indicate autoprostate inputs from external sources. ',
#  ' autoprostate framework diagram. autoprostate consists of three modules: zone-segmenter (green), cspca-segmenter (blue), and report-generator (purple); solid boxes correspond to module computations, while dashed boxes correspond to module outputs. yellow boxes indicate autoprostate inputs from external sources.',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available: (',
#  ') distribution of abserr for psad calculated by autoprostate and the experienced radiologist; the ground-truth psad value used to compute the abserr for autoprostate and the experienced radiologist was calculated by dividing psa by the whole-prostate volume derived from the ground-truth whole-prostate segmentation. ',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available: (',
#  ') distribution of abserr for psad calculated by autoprostate and the experienced radiologist; the ground-truth psad value used to compute the abserr for autoprostate and the experienced radiologist was calculated by dividing psa by the whole-prostate volume derived from the ground-truth whole-prostate segmentation.',
#  ' picture dataset axial t2wi, adc map, cb2000 dwi, ground-truth lesion contour overlaid on t2wi, probability map overlaid on t2wi, and segmentation overlaid on t2wi: (a) 79-year-old man, psa 12.57 ng/ml, midgland pz gs 4 + 3 lesion, likert 5, autoprostate probability of cspca 100%; (b) 66-year-old man, psa 7.50 ng/ml, midgland pz gs 3 + 4 lesion, likert 3, autoprostate probability of cspca 65%; (c) 64-year-old man, psa 10.53 ng/ml, apex cg gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 95%; (d) 56-year-old man, psa 7.91 ng/ml, base cg gs 3 + 4 lesion, likert 4, autoprostate probability of cspca 66%; (e) 60-year-old man with stable rectal gas-induced magnetic susceptibility artefact on dwi, psa 6.15 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 88%; and (f) 73-year-old man with bowel peristalsis-induced magnetic susceptibility artifact, psa 4.09 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 49%. ',
#  ' picture dataset axial t2wi, adc map, cb2000 dwi, ground-truth lesion contour overlaid on t2wi, probability map overlaid on t2wi, and segmentation overlaid on t2wi: (a) 79-year-old man, psa 12.57 ng/ml, midgland pz gs 4 + 3 lesion, likert 5, autoprostate probability of cspca 100%; (b) 66-year-old man, psa 7.50 ng/ml, midgland pz gs 3 + 4 lesion, likert 3, autoprostate probability of cspca 65%; (c) 64-year-old man, psa 10.53 ng/ml, apex cg gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 95%; (d) 56-year-old man, psa 7.91 ng/ml, base cg gs 3 + 4 lesion, likert 4, autoprostate probability of cspca 66%; (e) 60-year-old man with stable rectal gas-induced magnetic susceptibility artefact on dwi, psa 6.15 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 88%; and (f) 73-year-old man with bowel peristalsis-induced magnetic susceptibility artifact, psa 4.09 ng/ml, midgland pz gs 3 + 4 lesion, likert 5, autoprostate probability of cspca 49%.',
#  ' autoprostate report for a 64-year-old man with psa equal to 10.53 ng/ml who participated in the picture study. lesion 1 (probability of cspca equal to 95%) corresponds to a biopsy-proven gs 3+4 lesion, while lesion 2 and lesion 3 (probabilities of cspca equal to 46% and 7%, respectively) are false positives. ',
#  ' autoprostate report for a 64-year-old man with psa equal to 10.53 ng/ml who participated in the picture study. lesion 1 (probability of cspca equal to 95%) corresponds to a biopsy-proven gs 3+4 lesion, while lesion 2 and lesion 3 (probabilities of cspca equal to 46% and 7%, respectively) are false positives.',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available. ',
#  ' autoprostate external validation analysis of whole-prostate and zonal segmentations, prostate size measurements, and psad, using 80 patients from the picture dataset for which ground-truth segmentations were available.',
#  'abserr: absolute error; abs%err: absolute percentage error; iqr: interquartile range; max: maximum; min: minimum; psa: prostate-specific antigen; sd: standard deviation. ',
#  ' picture dataset cspca lesion detection metrics for the experienced radiologist and autoprostate. mean and standard deviation of false positives per patient were calculated using the 93 picture dataset patients who were biopsy-negative for cspca, rather than over all patients, due to limitations in the ground-truth. all other metrics shown are calculated at the lesion level for the 147 cspca lesions and 63 ncspca lesions. ',
#  ' picture dataset cspca lesion detection metrics for the experienced radiologist and autoprostate. mean and standard deviation of false positives per patient were calculated using the 93 picture dataset patients who were biopsy-negative for cspca, rather than over all patients, due to limitations in the ground-truth. all other metrics shown are calculated at the lesion level for the 147 cspca lesions and 63 ncspca lesions.',
#  '© 2021 by the authors. licensee mdpi, basel, switzerland. this article is an open access article distributed under the terms and conditions of the creative commons attribution (cc by) license (',
#  ' are solely those of the individual authors and contributors and not of the publisher and the editor(s). mdpi stays neutral with regard to jurisdictional claims in published maps and institutional affiliations. ',
#  'construction materials',
#  'electronic materials',
#  'materials',
#  'materials proceedings',
#  'methods and protocols',
#  'nanomaterials',
#  ' the statements, opinions and data contained in the journals are solely those of the individual authors and contributors and not of the publisher and the editor(s). mdpi stays neutral with regard to jurisdictional claims in published maps and institutional affiliations. ',
#  "(function(){window['__cf$cv$params']={r:'717ab4d6bb577697',m:'pugpch2z0ujqjtpqibdzr.vkizvcmd4jdho3_hetd94-1654618735-0-acjo/plnr+nbsdravaugjmqcs+smbpetas45yzd9m7uyxopyghgmq8w7hf1xeu7adj7hktapshcotkuud0gh/9jz2obx1gwncvftkb5leslq6z3vyt1qzr3wouz5bq+vdlykf5yqrmw1dzezriai9am=',s:[0x6b4cb4bde8,0x523482f19e],}})();"]

# %%
method_candidates = []

for i, x in enumerate(keep_text):
    
    method_following = []
    method_text = []
    
    if methodtitle(x) == True:
        method_following = keep_text[i:] #list of all elements following and including methods title
        
        for i, x in enumerate(method_following):
            if 'esult' in x and sum(l.isalpha() for l in x) <  30:
                #print("result title!")
                method_text = method_following[:i]
                break
            elif 'iscussion' in x and sum(l.isalpha() for l in x) <  30:
                #print("discussion title!")
                method_text = method_following[:i]
                break
            elif 'onclusion' in x and sum(l.isalpha() for l in x) <  30:
                #print("conclusion title!")
                method_text = method_following[:i]
                break
            else:
                method_text = method_following
        
        method = ' '.join(method_text)
        method_candidates.append(method)
        
    else:
        continue

len(method_candidates)
# Out:
# 17

# %%
method_candidates[7]
# Out:
# ' 2. methods , consists of three modules: zone-segmenter, cspca-segmenter, and report-generator. methodological aspects of each module are described in detail in the subsections to follow, while specific experimental parameters used to collect results are described in  t2w images are first resampled to a common in-plane resolution and cropped to a common in-plane shape, and then normalized by whitening of image voxel intensities. after pre-processing, each t2wi slice is segmented by an ensemble of 2d nnu-nets with task-specific hyperparameter modifications; we refer to each constituent 2d nnu-net as zone-u-net and the ensemble of zone-u-nets as zone-u-net-e. a detailed description of the zone-u-net architecture is given in  . the output of each zone-u-net is slice-wise pz, cg, and background probability maps. per-voxel averaging is used to combine the probability map outputs of each zone-u-net ∈ zone-u-net-e, followed by restacking of slices to form pz, cg, and background probability map volumes. the pz, cg, and background probability maps output by zone-u-net-e are transformed to the original t2wi shape and voxel resolution using padding and resampling operations. as a final step, a zonal segmentation map is obtained from the pz, cg, and background probability maps using a per-voxel argmax operation. the cspca-segmenter module detects and segments cspca lesions using each patient’s t2wi, apparent diffusion coefficient (adc) map, low b-value diffusion-weighted imaging (dwi), and pz and cg probability maps output by zone-segmenter. image registration is used to align adc maps and computed high b-value dwi to t2wi to account for voluntary/involuntary patient movement between t2wi and dwi acquisitions and differences in resolution. first, adc maps are affinely registered to t2wi using the symmetric block matching algorithm [ ], with the convolution-based fast local normalized correlation coefficient (lncc) similarity measure to enable robustness to bias field inhomogeneity [ ]. finally, the transformation obtained from the composition of both types of registration is used to register computed high b-value dwi to t2wi. t2wi, registered adc map and computed high b-value dwi, and pz and cg probability maps are resampled to a common in-plane resolution and cropped to a common in-plane shape, centred on the prostate; image cropping is used for memory efficiency. then, t2wi and computed high b-value dwi are normalized by dividing voxel intensities by the interquartile mean of cg voxel intensities. our approach is a modification of the normalization approach suggested by bonekamp et al. [ ], where voxel intensities were divided by the mean of pz voxel intensities. we opt for normalization using cg voxel intensities since cg segmentations are typically more reliable than pz segmentations [ ], and we opt for the interquartile mean of cg voxel intensities as opposed to the mean of all cg voxel intensities, to remove extremes that may correspond to abnormalities unique to a patient. adc maps were not normalized as they contain a quantitative measurement. after pre-processing, each slice of a patient’s t2wi, adc map, computed high b-value dwi, and pz and cg probability maps are input channel-wise to an ensemble of 2d nnu-nets for cspca lesion segmentation; the addition of pz and cg guidance as input has been shown to increase cspca lesion detection performance as the occurrence and appearance of prostate cancer is dependent on its zonal location [ ]. we refer to each constituent 2d nnu-net as cspca-u-net and the ensemble of cspca-u-nets as cspca-u-net-e. a detailed description of the cspca-u-net architecture is given in  ], i.e., dropout layers are inserted after the central three encoder units and two decoder units, with dropout probability equal to p. we model aleatoric uncertainty using test-time augmentation as in wang et al. [ the output of each cspca-u-net is slice-wise cspca probability maps. per-voxel averaging is used to combine the ...

# %% [markdown]
# # scrape urls - loop

# %%
#test_doi = doi_list[1950:2000]
#test_pmid = pmid_list[1950:2000]
#test_url = url_list[1950:2000]

# %%
## conditions

def alphachars(x): return sum(a.isalpha() for a in x) > 4
def charchar(x): return bool(re.match(r".*[a-zA-Z][a-zA-Z].*", x)) == True
def istitle(x): return ((('method' in x) or ('material' in x) or ('result' in x) or ('discussion' in x) or ('conclusion' in x)
                        or ('references' in x) or ('bibliography' in x)) 
                        and (sum(l.isalpha() for l in x) < 30))
def istextblock(x): return sum(l.isalpha() for l in x) > 100
def methodtitle(x): return ((('method' in x)) and (sum(l.isalpha() for l in x)<30)) #or ('material' in x)

## symbol cleaning

def lbracketcount(x): return x.count('{') < 4
def rbracketcount(x): return x.count('}') < 4
def tagcount(x): return x.count('"."') < 4
def hashcount(x): return x.count('#') < 4
def divcount(x): return x.count('</') < 4
def linecount(x): return x.count('||') < 4

# %%
methods_list = []

for url in tqdm(url_list):
    
    ## refresh lists
    keep_text = []
    cull_text = []
    method_candidates = []
    
    ## set up chrome driver and get link
    driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver\chromedriver.exe')
    driver.get(url)

    ## get page source and xpath extract all body text
    page = driver.page_source
    tree = html.fromstring(page)
    body_text = tree.xpath('//body/descendant-or-self::*/text()')
    
    ## stop driver
    driver.quit()
    
    ## cleaning and convert to lower case
    body_text = [x.replace('\n', ' ') for x in body_text]
    body_text = [x.replace('    ', ' ') for x in body_text]
    body_text = [x.replace('   ', ' ') for x in body_text]
    body_text = [x.replace('  ', ' ') for x in body_text]
    body_text = [x.lower() for x in body_text]
    
    ## keep list elements if conforms to conditions
    for x in body_text:
        if (charchar(x) and alphachars(x)) and (istitle(x) or istextblock(x)):
            keep_text.append(x)
        else:
            continue

    for x in keep_text:
        if (lbracketcount(x) and rbracketcount(x) and tagcount(x) and hashcount(x) and divcount(x) and linecount(x)):
            cull_text.append(x)
        else:
            continue
                 
    #########
    #########
    #########
    
    ## now pull out methods titles and text that follows, up to first occurance of 'results/discussion/conclusion title'
    ## all candidates joined as strings, and held in method_candidates
    
    for i, x in enumerate(cull_text):    
        method_following = [] #list of all elements following and including methods title
        method_only = [] #list of all elements inbetween 'method' title and next section title

        if methodtitle(x) == True:
            method_following = cull_text[i:] 
            
            for i, x in enumerate(method_following):
                if 'result' in x and sum(l.isalpha() for l in x) <  30:
                    #print("result title!")
                    method_only = method_following[:i]
                    break
                elif 'discussion' in x and sum(l.isalpha() for l in x) <  30:
                    #print("discussion title!")
                    method_only = method_following[:i]                
                    break
                elif 'conclusion' in x and sum(l.isalpha() for l in x) <  30:
                    #print("conclusion title!")
                    method_only = method_following[:i]               
                    break
                elif 'references' in x and sum(l.isalpha() for l in x) <  30:
                    #print("reference title!")
                    method_only = method_following[:i]            
                    break
                elif 'bibliography' in x and sum(l.isalpha() for l in x) <  30:
                    #print("reference title!")
                    method_only = method_following[:i]                 
                    break                      
                else:
                    method_only = method_following #if none of these are found to end text block, then take the whole text block
    
            method_string = ' '.join(method_only)        
            method_candidates.append(method_string)
            
        else:
            continue
        
    methods_list.append(method_candidates) # each paper now has a list of method candidates (each is a string)

print(len(methods_list))
# Out:
#   0%|          | 0/3437 [00:00<?, ?it/s]
# C:\Users\Joe Z\anaconda3\envs\scraper\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8924\3471445015.py in <module>
#      10     ## set up chrome driver and get link
#      11     driver = webdriver.Chrome(options=options, executable_path=r'C:\chromedriver\chromedriver.exe')
# ---> 12     driver.get(url)
#      13
#      14     ## get page source and xpath extract all body text
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\envs\scraper\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: session deleted because of page crash
# from tab crashed
#   (Session info: chrome=102.0.5005.63)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0073D953+2414931]
# 	Ordinal0 [0x006CF5E1+1963489]
# 	Ordinal0 [0x005BC580+836992]
# 	Ordinal0 [0x005AD517+775447]
# 	Ordinal0 [0x005AC565+771429]
# 	Ordinal0 [0x005ACB68+772968]
# 	Ordinal0 [0x005ACAF8+772856]
# 	Ordinal0 [0x005B2D5A+798042]
# 	Ordinal0 [0x005ADD3B+777531]
# 	Ordinal0 [0x005AE265+778853]
# 	Ordinal0 [0x005AE04F+778319]
# 	Ordinal0 [0x005AD646+775750]
# 	Ordinal0 [0x005AC565+771429]
# 	Ordinal0 [0x005ACB68+772968]
# 	Ordinal0 [0x005ACAF8+772856]
# 	Ordinal0 [0x005B2D5A+798042]
# 	Ordinal0 [0x005ADD3B+777531]
# 	Ordinal0 [0x005AE265+778853]
# 	Ordinal0 [0x005AE04F+778319]
# 	Ordinal0 [0x005AD646+775750]
# 	Ordinal0 [0x005ACEBC+773820]
# 	Ordinal0 [0x005C2197+860567]
# 	Ordinal0 [0x00614B55+1198933]
# 	Ordinal0 [0x006042B6+1131190]
# 	Ordinal0 [0x005DE860+976992]
# 	Ordinal0 [0x005DF756+980822]
# 	GetHandleVerifier [0x009ACC62+2510274]
# 	GetHandleVerifier [0x0099F760+2455744]
# 	GetHandleVerifier [0x007CEABA+551962]
# 	GetHandleVerifier [0x007CD916+547446]
# 	Ordinal0 [0x006D5F3B+1990459]
# 	Ordinal0 [0x006DA898+2009240]
# 	Ordinal0 [0x006DA985+2009477]
# 	Ordinal0 [0x006E3AD1+2046673]
# 	BaseThreadInitThunk [0x75DEFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77407A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77407A4E+238]

# %%
len(methods_list)
# Out:
# 2440

# %%
temp_doi_list = doi_list[0:2440]
temp_pmid_list = pmid_list[0:2440]

# %%
results_df = pd.DataFrame({'doi':temp_doi_list, 'pmid':temp_pmid_list, 'methods_candidates':methods_list})

results_df.to_csv('output/html_parse_raw.csv')

# %%
explode_df = pd.DataFrame(results_df['methods_candidates'].tolist())
explode_df['pmid'] = temp_pmid_list
explode_df.to_csv('output/html_explode_raw.csv')

# %%
STOP
